# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.linalg as la
import sys
sys.path.append("../../")
from structured_random_features.src.models.weights import V1_weights

# Package for importing image representation
from PIL import Image, ImageOps

from src.compress_sensing_library import generate_Y, reconstruct, filter_reconstruction
import pandas as pd
import seaborn as sns
import time
import os.path

# %%
image_nm = 'cameraman.tif'
img = Image.open('../../image/' + image_nm)
img = ImageOps.grayscale(img)
img_arr = np.asarray(img)
plt.imshow(img)
orig_dim = img_arr.shape

# %%
mid_cell_res = filter_reconstruction(50, img_arr, 7, 2)

n,m = img_arr.shape
plt.figure(figsize=(12, 12))
# ax = plt.imshow(np.abs(img_arr - mid_cell_res), vmax=255, cmap = 'Blues')
# plt.title('Abs Error Iamge: 200 cells with 30 X 30 filter')
# plt.colorbar(ax)
# np.linalg.norm(img - high_cell_res, 'fro') / np.sqrt(m*n)
# plt.show()

n,m = img_arr.shape
plt.figure(figsize=(12, 12))
ax = plt.imshow(img_arr - mid_cell_res, vmin=-100, vmax=100, cmap='RdBu')
plt.colorbar(ax)
plt.title('Diverging Error Iamge: 200 cells with 30 X 30 filter')
np.linalg.norm(img - mid_cell_res, 'fro') / np.sqrt(m*n)

plt.show()
# Out:
# (540, 540)
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 100922.06002582153, tolerance: 15545.693118248857
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 108588.19488592811, tolerance: 21753.10167107776
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 108862.05626848189, tolerance: 21554.83402609747
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 121750.17392717731, tolerance: 31304.102453128755
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 54521.96729701177, tolerance: 21983.057885687413
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 385763.66370453814, tolerance: 331308.9783408916
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34483.993732177354, tolerance: 16003.36283865639
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 122804.59868058453, tolerance: 100484.41325654862
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 311741.8542937759, tolerance: 231671.69662620942
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 69645.39147636606, tolerance: 31616.072761876465
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 167441.04354708194, tolerance: 141280.82591351622
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 219064.26826078995, tolerance: 213689.56341067265
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 262931.5042067223, tolerance: 194020.52273752904
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 46895.569277563154, tolerance: 15874.996834328065
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 72884.82650453468, tolerance: 45215.766675662475
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 204250.56606681686, tolerance: 133843.83812185164
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 64478.82667747828, tolerance: 34634.55361504891
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 292733.50168874324, tolerance: 222985.92784216237
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 83866.06160128432, tolerance: 63677.5381410903
#   model = cd_fast.enet_coordinate_descent(
