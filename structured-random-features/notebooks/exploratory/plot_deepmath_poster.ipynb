# %%
import numpy as np
import numpy.linalg as la
import matplotlib.pyplot as plt
import pickle5 as pickle

# %% [markdown]
# ## Vision

# %% [markdown]
# ### Random feature network (RFN) full MNIST

# %%
n_features = sorted(set(np.logspace(0, 3.5, 100).astype('int')))
t, l = 5, 2
models = ['V1', 'classical']
labels = {'V1': 'V1-inspired', 'classical': 'classical'}
with open('results/mnist_clf/mnist_clf_t=%0.2f_l=%0.2f_svc.pickle' % (t, l), 'rb') as handle:
    results = pickle.load(handle)
    
fig = plt.figure(figsize=(10.6, 8))
ax = fig.add_subplot(111)
for m in models:
    avg_err = results[m]['avg_test_err']
    std_err = results[m]['std_test_err']
    plt.plot(n_features, avg_err, markersize=4, lw=5, label=labels[m])
    plt.fill_between(n_features, avg_err - std_err, avg_err + std_err, alpha=0.2)
plt.xlabel('Hidden layer width', fontsize=40)
plt.ylabel('Classification error', fontsize=40)
plt.yticks(np.arange(0, 1.01, 0.2))
plt.xticks(np.arange(0, 2200, 200))
plt.ylim([-0.05, 1.00])
plt.xlim([0, 1010])
ax.tick_params(axis = 'both', which = 'major', labelsize = 40, width=2, length=6)
plt.legend(loc = 'upper right', fontsize=30)
plt.savefig('results/deepmath_poster/mnist_clf_t=%0.2f_l=%0.2f.png' % (t, l))

print('V1 test err: %0.3f, RF test err: %0.3f' % (results['V1']['avg_test_err'][-1], 
                                                  results['classical']['avg_test_err'][-1]))
# Out:
# V1 test err: 0.018, RF test err: 0.035

# %%
list(zip(n_features, results['classical']['avg_test_err'] * 100))[-15:]
# Out:
# [(1011, 28.305999999999997),
#  (1097, 25.461999999999996),
#  (1190, 27.168000000000003),
#  (1291, 25.3),
#  (1401, 24.466),
#  (1519, 22.212),
#  (1648, 22.614),
#  (1788, 21.669999999999998),
#  (1940, 20.591999999999995),
#  (2104, 19.354),
#  (2283, 19.66),
#  (2477, 18.459999999999997),
#  (2687, 18.844),
#  (2915, 17.35),
#  (3162, 17.534)]

# %%
list(zip(n_features, results['V1']['avg_test_err'] * 100))[-40:]
# Out:
# [(132, 34.721999999999994),
#  (143, 34.33800000000001),
#  (155, 34.762),
#  (168, 33.391999999999996),
#  (183, 29.709999999999997),
#  (198, 28.08),
#  (215, 26.246000000000002),
#  (233, 30.729999999999997),
#  (253, 23.642000000000003),
#  (275, 28.058),
#  (298, 22.291999999999994),
#  (323, 25.088),
#  (351, 23.502000000000002),
#  (380, 21.869999999999997),
#  (413, 19.264),
#  (448, 18.936),
#  (486, 19.09),
#  (527, 17.03),
#  (572, 21.272000000000002),
#  (620, 15.046000000000001),
#  (673, 14.549999999999997),
#  (730, 14.275999999999996),
#  (792, 13.813999999999998),
#  (859, 14.138),
#  (932, 14.613999999999999),
#  (1011, 13.127999999999998),
#  (1097, 12.131999999999998),
#  (1190, 12.466),
#  (1291, 11.435999999999998),
#  (1401, 10.513999999999998),
#  (1519, 10.244000000000002),
#  (1648, 9.911999999999999),
#  (1788, 9.608),
#  (1940, 10.53),
#  (2104, 9.298000000000002),
#  (2283, 9.081999999999999),
#  (2477, 8.964),
#  (2687, 10.85),
# ...

# %% [markdown]
# ### RFN kMNIST

# %%
n_features = sorted(set(np.logspace(0, 3.5, 100).astype('int')))
t, l = 5, 2
models = ['V1', 'classical']
labels = {'V1': 'V1-inspired', 'classical': 'classical'}
with open('results/kmnist_clf/kmnist_clf_t=%0.2f_l=%0.3f.pickle' % (t, l), 'rb') as handle:
    results = pickle.load(handle)
    
fig = plt.figure(figsize=(10.6, 8))
ax = fig.add_subplot(111)
for m in models:
    avg_err = results[m]['avg_test_err']
    std_err = results[m]['std_test_err']
    plt.plot(n_features, avg_err, markersize=4, lw=5, label=labels[m])
    plt.fill_between(n_features, avg_err - std_err, avg_err + std_err, alpha=0.2)
plt.xlabel('Hidden layer width', fontsize=40)
plt.ylabel('Classification error', fontsize=40)
plt.yticks(np.arange(0, 1.01, 0.2))
plt.xticks(np.arange(0, 2200, 200))
plt.ylim([-0.05, 1.0])
plt.xlim([0, 1010])
ax.tick_params(axis = 'both', which = 'major', labelsize = 40, width=2, length=6)

plt.legend(loc = 'upper right', fontsize=30)
plt.savefig('results/deepmath_poster/kmnist_clf_t=%0.2f_l=%0.2f.png' % (t, l))

print('V1 test err: %0.3f, RF test err: %0.3f' % (results['V1']['avg_test_err'][-1], 
                                                  results['classical']['avg_test_err'][-1]))
# Out:
# V1 test err: 0.084, RF test err: 0.175

# %% [markdown]
# ### RFN fewshot MNIST

# %%
t, l = 5, 2
models = ['V1', 'classical']
labels = {'V1': 'V1-inspired', 'classical': 'classical'}
with open('results/mnist_clf/mnist_clf_t=%0.2f_l=%0.3f_few_shot_svc.pickle' % (t, l), 'rb') as handle:
    results = pickle.load(handle)
fig = plt.figure(figsize=(10.6, 8))
ax = fig.add_subplot(111)
for m in models:
    avg_err = results[m]['avg_test_err']
    std_err = results[m]['std_test_err']
    plt.plot(n_features, avg_err, markersize=4, lw=5, label=labels[m])
    plt.fill_between(n_features, avg_err - std_err, avg_err + std_err, alpha=0.2)
plt.xlabel('Hidden layer width', fontsize=40)
plt.ylabel('Classification error', fontsize=40)
plt.yticks(np.arange(0, 1.01, 0.2))
plt.xticks(np.arange(0, 2200, 200))
plt.ylim([0.15, 1.00])
plt.xlim([0, 1010])
ax.tick_params(axis = 'both', which = 'major', labelsize = 40, width=2, length=6)
plt.legend(loc = 'upper right', fontsize=30)
plt.savefig('results/deepmath_poster/mnist_clf_t=%0.2f_l=%0.2f_fewshot.png' % (t, l))

print('V1 test err: %0.3f, RF test err: %0.3f' % (results['V1']['avg_test_err'][-1], 
                                                  results['classical']['avg_test_err'][-1]))
# Out:
# V1 test err: 0.269, RF test err: 0.324

# %% [markdown]
# ### RFN fewshot kMNIST

# %%
models = ['V1', 'classical']
labels = {'V1': 'V1-inspired', 'classical': 'classical'}
with open('results/kmnist_clf/kmnist_clf_t=%0.2f_l=%0.3f_few_shot.pickle' % (t, l), 'rb') as handle:
    results = pickle.load(handle)

fig = plt.figure(figsize=(10.6, 8))
ax = fig.add_subplot(111)
for m in models:
    avg_err = results[m]['avg_test_err']
    std_err = results[m]['std_test_err']
    plt.plot(n_features, avg_err, markersize=4, lw=5, label=labels[m])
    plt.fill_between(n_features, avg_err - std_err, avg_err + std_err, alpha=0.2)
plt.xlabel('Hidden layer width', fontsize=40)
plt.ylabel('Classification error', fontsize=40)
plt.yticks(np.arange(0, 1.01, 0.1))
plt.xticks(np.arange(0, 2200, 200))
plt.ylim([0.57, 1.0])
plt.xlim([0, 1010])
ax.tick_params(axis = 'both', which = 'major', labelsize = 40, width=2, length=6)
plt.legend(loc = 'upper right', fontsize=30)
plt.savefig('results/deepmath_poster/kmnist_clf_t=%0.2f_l=%0.2f_fewshot.png' % (t, l))

# plt.savefig('results/mnist_clf/mnist_clf_t=%0.2f_l=%0.2f_fewshot.png' % (t, l))

# %% [markdown]
# ### Initialize fully trained network full MNIST

# %%
h, lr, n_epochs = 1000, 0.1, 3001
t, l = 5, 2
models = ['V1', 'He']
labels = {'V1': 'V1-inspired', 'He': 'standard'}
with open('results/initialize_mnist/full_data/clf_t=%0.2f_l=%0.2f.pickle' % (t, l), 'rb') as handle:
    sims = pickle.load(handle)
    
fig = plt.figure(figsize=(10.6, 8))
ax = fig.add_subplot(111)
for m in models:
    avg_test_err = np.mean(sims['test_err'][m][h][lr], axis=0)
    std_test_err = np.std(sims['test_err'][m][h][lr], axis=0)
    plt.plot(np.arange(n_epochs), avg_test_err, label=labels[m], markersize=5, lw=5)
    plt.fill_between(np.arange(n_epochs), avg_test_err - std_test_err, avg_test_err + std_test_err, alpha=0.2)
    print('%s, %0.4f' % (m, avg_test_err[-1] * 100))

plt.xlabel('epochs', fontsize=40)
plt.ylabel('Classification error', fontsize=40)
plt.yticks(np.arange(0, 1.01, 0.1))
plt.xticks(np.arange(0, 3001, 1000))
plt.xlim([0, 3001])
plt.ylim([-0.03, 0.5])
ax.tick_params(axis = 'both', which = 'major', labelsize = 40, width=2, length=6)
plt.legend(loc = 'upper right', fontsize=30)
# plt.yscale('log')
plt.savefig('results/deepmath_poster/init_mnist_clf_t=%0.2f_l=%0.2f.png' % (t, l))
# Out:
# V1, 2.2470
# He, 3.4730

# %% [markdown]
# ### Initialize fully trained network full kMNIST

# %%
h, lr, n_epochs = 1000, 0.1, 3001
t, l = 5, 2
models = ['V1', 'He']
labels = {'V1': 'V1-inspired', 'He': 'standard'}
with open('results/initialize_kmnist/full_data/clf_t=%0.2f_l=%0.2f.pickle' % (t, l), 'rb') as handle:
    sims = pickle.load(handle)
    
fig = plt.figure(figsize=(10.6, 8))
ax = fig.add_subplot(111)
for m in models:
    avg_test_err = np.mean(sims['test_err'][m][h][lr], axis=0)
    std_test_err = np.std(sims['test_err'][m][h][lr], axis=0)
    plt.plot(np.arange(n_epochs), avg_test_err, label=labels[m], lw=5)
    plt.fill_between(np.arange(n_epochs), avg_test_err - std_test_err, avg_test_err + std_test_err, alpha=0.2)
    print('%s, %0.4f' % (m, avg_test_err[-1] * 100))

plt.xlabel('epochs', fontsize=40)
plt.ylabel('Classification error', fontsize=40)
plt.yticks(np.arange(0, 1.01, 0.1))
plt.xticks(np.arange(0, 3001, 1000))
plt.xlim([0, 3001])
plt.ylim([0.05, 0.6])
ax.tick_params(axis = 'both', which = 'major', labelsize = 40, width=2, length=6)
plt.legend(loc = 'upper right', fontsize=30)
# plt.yscale('log')
plt.savefig('results/deepmath_poster/init_kmnist_clf_t=%0.2f_l=%0.2f.png' % (t, l))
# Out:
# V1, 9.9520
# He, 13.4490

# %% [markdown]
# ### Initialize fully trained network on fewshot MNIST

# %%
h, lr, n_epochs = 1000, 0.1, 7001
t, l = 5, 2
models = ['V1', 'He']
labels = {'V1': 'V1-inspired', 'He': 'standard'}
with open('results/initialize_mnist/fewshot_data/clf_t=%0.2f_l=%0.2f.pickle' % (t, l), 'rb') as handle:
    sims = pickle.load(handle)
    
fig = plt.figure(figsize=(10.6, 8))
ax = fig.add_subplot(111)
for m in models:
    avg_test_err = np.mean(sims['test_err'][m][h][lr], axis=0)
    std_test_err = np.std(sims['test_err'][m][h][lr], axis=0)
    plt.plot(np.arange(n_epochs), avg_test_err, label=labels[m], lw=5)
    plt.fill_between(np.arange(n_epochs), avg_test_err - std_test_err, avg_test_err + std_test_err, alpha=0.2)
    print('%s, %0.4f' % (m, avg_test_err[-1] * 100))
    
plt.xlabel('epochs', fontsize=40)
plt.ylabel('Classification error', fontsize=40)
plt.yticks(np.arange(0, 1.01, 0.1))
plt.xticks(np.arange(0, 7001, 1000))
plt.xlim([0, 3020])
plt.ylim([0.2, 0.6])
ax.tick_params(axis = 'both', which = 'major', labelsize = 40, width=2, length=6)
plt.legend(loc = 'upper right', fontsize=30)
# plt.yscale('log')
plt.savefig('results/deepmath_poster/init_mnist_clf_t=%0.2f_l=%0.2f_fewshot.png' % (t, l))
# Out:
# V1, 26.7890
# He, 31.3110

# %% [markdown]
# ### Initialize fully trained network on fewshot kMNIST

# %%
h, lr, n_epochs = 1000, 0.1, 7001
t, l = 5, 2
models = ['V1', 'He']
labels = {'V1': 'V1-inspired', 'He': 'standard'}
with open('results/initialize_kmnist/fewshot_data/clf_t=%0.2f_l=%0.2f.pickle' % (t, l), 'rb') as handle:
    sims = pickle.load(handle)
    
fig = plt.figure(figsize=(10.6, 8))
ax = fig.add_subplot(111)
for m in models:
    avg_test_err = np.mean(sims['test_err'][m][h][lr], axis=0)
    std_test_err = np.std(sims['test_err'][m][h][lr], axis=0)
    plt.plot(np.arange(n_epochs), avg_test_err, label=labels[m], lw=5)
    plt.fill_between(np.arange(n_epochs), avg_test_err - std_test_err, avg_test_err + std_test_err, alpha=0.2)
    print('%s, %0.4f' % (m, avg_test_err[-1] * 100))
    
plt.xlabel('epochs', fontsize=40)
plt.ylabel('Classification error', fontsize=40)
plt.yticks(np.arange(0, 1.01, 0.05))
plt.xticks(np.arange(0, 7001, 1000))
plt.xlim([0, 3001])
plt.ylim([0.58, 0.8])
ax.tick_params(axis = 'both', which = 'major', labelsize = 40, width=2, length=6)
plt.legend(loc = 'upper right', fontsize=30)
# plt.yscale('log')   
plt.savefig('results/deepmath_poster/init_kmnist_clf_t=%0.2f_l=%0.2f_fewshot.png' % (t, l))
# Out:
# V1, 60.3940
# He, 63.1080

# %% [markdown]
# ### Initialize fully trained network full fashion MNIST

# %%
h, lr, n_epochs = 1000, 0.1, 3001
t, l = 5, 2
models = ['V1', 'He']
with open('results/initialize_fashion_mnist/full_data/clf_t=%0.2f_l=%0.2f.pickle' % (t, l), 'rb') as handle:
    sims = pickle.load(handle)
    
fig = plt.figure(figsize=(10.6, 8))
ax = fig.add_subplot(111)
for m in models:
    avg_test_err = np.mean(sims['test_err'][m][h][lr], axis=0)
    std_test_err = np.std(sims['test_err'][m][h][lr], axis=0)
    plt.plot(np.arange(n_epochs), avg_test_err, label=m, lw=5)
    plt.fill_between(np.arange(n_epochs), avg_test_err - std_test_err, avg_test_err + std_test_err, alpha=0.2)
    print('%s, %0.4f' % (m, avg_test_err[-1] * 100))
    
plt.xlabel('epochs', fontsize=40)
plt.ylabel('Classification error', fontsize=40)
plt.yticks(np.arange(0, 1.01, 0.2))
plt.xticks(np.arange(0, 3001, 1000))
plt.xlim([0, 3001])
plt.ylim([0, 0.61])
ax.tick_params(axis = 'both', which = 'major', labelsize = 40, width=2, length=6)
plt.legend(loc = 'upper right', fontsize=30)
plt.savefig('results/deepmath_poster/init_fashion_mnist_clf_t=%0.2f_l=%0.2f.png' % (t, l))
# plt.yscale('log')
# Out:
# V1, 12.0090
# He, 13.1190

# %% [markdown]
# ## time-series

# %% [markdown]
# ### Frequency detection

# %%
n_features = sorted(set(np.logspace(0, 3, 50).astype('int')))
models = ['halteres', 'classical']
labels = {'halteres': 'haltere-inspired', 'classical': 'classical'}
with open('results/freq_detection/freq_clf.pickle', 'rb') as handle:
    results = pickle.load(handle) 
    
fig = plt.figure(figsize=(10.6, 8))
ax = fig.add_subplot(111)
for m in models:
    avg_test_err = results[m]['avg_test_err']
    std_test_err = results[m]['std_test_err']
    plt.plot(n_features, avg_test_err, label=labels[m], lw=5)
    plt.fill_between(n_features, avg_test_err - std_test_err, avg_test_err + std_test_err, alpha=0.2)
    print('%s, %0.4f' % (m, avg_test_err[-1] * 100))
ax.set_xlim([0, 255])
plt.yticks(np.arange(0, 0.6, 0.1))
plt.ylim([-0.03, 0.5])
plt.xlabel('Hidden layer width', fontsize=40)
plt.ylabel('Classification error', fontsize=40)
plt.xticks(np.arange(0, 255, 50))
ax.tick_params(axis = 'both', which = 'major', labelsize = 40, width=2, length=6)
plt.legend(loc = 'upper right', fontsize=30)
plt.savefig('results/deepmath_poster/freq_detection.png')
# Out:
# halteres, 0.0000
# classical, 0.1939

# %% [markdown]
# ### frequency XOR

# %%
n_features = sorted(set(np.logspace(0, 3, 50).astype('int')))
models = ['halteres', 'classical']
labels = {'halteres': 'haltere-inspired', 'classical': 'classical'}
with open('results/freq_XOR/freq_XOR.pickle', 'rb') as handle:
    results = pickle.load(handle) 
    
fig = plt.figure(figsize=(10.6, 8))
ax = fig.add_subplot(111)
for m in models:
    avg_test_err = results[m]['avg_test_err']
    std_test_err = results[m]['std_test_err']
    plt.plot(n_features, avg_test_err, label=labels[m], lw=5)
    plt.fill_between(n_features, avg_test_err - std_test_err, avg_test_err + std_test_err, alpha=0.2)
    print('%s, %0.4f' % (m, avg_test_err[-1] * 100))
    
ax.set_xlim([0, 255])
plt.yticks(np.arange(0, 0.6, 0.1))
plt.ylim([-0.03, 0.5])
# ax.set_yscale('log')
plt.xlabel('Hidden layer width', fontsize=40)
plt.ylabel('Classification error', fontsize=40)
plt.xticks(np.arange(0, 255, 50))
ax.tick_params(axis = 'both', which = 'major', labelsize = 40, width=2, length=6)
plt.legend(loc = 'upper right', fontsize=30)
plt.savefig('results/deepmath_poster/freq_XOR.png')
# Out:
# halteres, 0.0400
# classical, 0.1333

# %% [markdown]
# ## frequency XOR data

# %%
from data_fns import frequency_detection
n_samples, fs, signal_duration, k, a = 5000, 1500, 0.1, 5, 0.99
X, y = frequency_detection(n_samples, fs, k, signal_duration, a, random_state=20)
freq = int(k / signal_duration)
N = int(fs * signal_duration)
t = np.arange(N) / fs * 1000

fig = plt.figure(figsize=(10.6, 8))
ax = fig.add_subplot(211)
plt.plot(t, X[y == 1][0], 'k-', lw=3, alpha=0.6, label='$\omega_1=$%d Hz' % freq)
plt.plot(t, X[y == -1][0], 'r-', lw=3, alpha=0.6,label=r'white noise')
plt.legend(loc='lower right', fontsize=35)
# plt.xlabel('time (ms)', fontsize=20)
# plt.ylabel('Amplitude', fontsize=20)
plt.ylim([-2, 2])
ax.set_yticks([-1.5, 0, 1.5])
ax.set_xticks(np.arange(0, 125, 25))
plt.xlim([-5, 105])
ax.tick_params(direction='out', length=10, width=2, colors='k',
           grid_color='k', grid_alpha=0.5, labelsize=40)
plt.savefig('results/deepmath_poster/freq_detection_data.png')

# %% [markdown]
# ## frequency XOR data

# %%
from data_fns import frequency_XOR

nPoints, fs, sig_dur = 5000, 1500, 0.1
k1, k2 = 5, 8
a = 0.99
freq = [int(k1/ sig_dur), int(k2  / sig_dur)]
X, y = frequency_XOR(nPoints, fs, k1, k2, sig_dur, a, random_state=20)

# plot
snr = a ** 2 / (1 - a ** 2)
N = int(fs * sig_dur)
t = np.arange(N) / fs * 1000
nPoints_quarter = int(nPoints / 4)

fig = plt.figure(figsize=(10.6, 5))
# plt.suptitle('XOR data: SNR=%0.2f' % snr, fontsize=16)
ax = fig.add_subplot(211)
plt.plot(t, X[0], 'k-', lw=3, alpha=0.6, label='$\omega_1=$%d Hz' % freq[0])
plt.plot(t, X[1250], 'k', lw=5, label=r'$\omega_2=$%d Hz' % freq[1])
plt.legend(loc='lower right', fontsize=30)
# plt.xlabel('time (ms)', fontsize=20)
# plt.ylabel('Amplitude', fontsize=20)
plt.ylim([-2, 2])
ax.set_yticks([-1.5, 0, 1.5])
ax.tick_params(direction='out', length=10, width=2, colors='k',
           grid_color='k', grid_alpha=0.5, labelsize=40)


ax = fig.add_subplot(212)
plt.plot(t, X[2501], 'r', lw=5, label=r'mixed $%d$ & $%d$ Hz' % (freq[0], freq[1]))
plt.plot(t, X[-1], 'r-', lw=2, alpha=0.6, label='white noise')
plt.legend(loc='lower right', fontsize=30)
# plt.xlabel('time (ms)', fontsize=20)
# plt.ylabel('Amplitude', fontsize=20)
plt.ylim([-2, 2])
ax.set_yticks([-1.5, 0, 1.5])
ax.tick_params(direction='out', length=10, width=2, colors='k',
           grid_color='k', grid_alpha=0.5, labelsize=40)
plt.tight_layout()
# plt.subplots_adjust(top=0.85)
plt.savefig('results/deepmath_poster/freq_XOR_data.png')

# %% [markdown]
# ## plot results from fashion_mnist cross validation simulations

# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

params = np.arange(0.1, 10.1, 0.5)
n_features = np.arange(1, 1050, 50)

for t in params:
    for l in params:
        print(t, l)
        with open('results/fashion_mnist_clf/fashion_mnist_clf_t=%0.3f_l=%0.3f_sgd.pickle' % (t, l), 'rb') as handle:
            results = pickle.load(handle) 

        fig = plt.figure(figsize=(10.6, 8))
        ax = fig.add_subplot(111)
        ax.errorbar(n_features, results['V1']['avg_test_err'], yerr=results['V1']['std_test_err'], fmt='-', 
                    label='V1-inspired',  markersize=4, lw=5, elinewidth=3)
        ax.errorbar(n_features, results['classical']['avg_test_err'], yerr=results['classical']['std_test_err'], 
                    fmt='-', label='classical', markersize=4, lw=5, elinewidth=3)
        plt.xlabel('Hidden layer width', fontsize=40)
        plt.ylabel('Classification error', fontsize=40)
        # plt.xticks(np.arange(0, 1020, 200))
        plt.xlim([0, 1020])
        plt.yticks(np.arange(0, 0.8, 0.1))
        plt.ylim([-0.05, 0.55])
        plt.xticks(np.arange(0, 1020, 200))
        ax.tick_params(axis = 'both', which = 'major', labelsize = 30, width=2, length=6)

        plt.legend(loc = 'upper right', fontsize=30)
        
        plt.savefig('results/fashion_mnist_clf/sgd_crossval/fashion_mnist_clf_t=%0.2f_l=%0.2f_sgd.pdf' % (t, l))
        plt.close()
# Out:
# 0.1 0.1
# 0.1 0.6
# 0.1 1.1
# 0.1 1.6
# 0.1 2.1
# 0.1 2.6
# 0.1 3.1
# 0.1 3.6
# 0.1 4.1
# 0.1 4.6
# 0.1 5.1
# 0.1 5.6
# 0.1 6.1
# 0.1 6.6
# 0.1 7.1
# 0.1 7.6
# 0.1 8.1
# 0.1 8.6
# 0.1 9.1
# 0.1 9.6
# 0.6 0.1
# 0.6 0.6
# 0.6 1.1
# 0.6 1.6
# 0.6 2.1
# 0.6 2.6
# 0.6 3.1
# 0.6 3.6
# 0.6 4.1
# 0.6 4.6
# 0.6 5.1
# 0.6 5.6
# 0.6 6.1
# 0.6 6.6
# 0.6 7.1
# 0.6 7.6
# 0.6 8.1
# 0.6 8.6
# 0.6 9.1
# 0.6 9.6
# 1.1 0.1
# 1.1 0.6
# 1.1 1.1
# 1.1 1.6
# 1.1 2.1
# 1.1 2.6
# 1.1 3.1
# 1.1 3.6
# 1.1 4.1
# 1.1 4.6
# 1.1 5.1
# 1.1 5.6
# 1.1 6.1
# 1.1 6.6
# 1.1 7.1
# 1.1 7.6
# 1.1 8.1
# 1.1 8.6
# 1.1 9.1
# 1.1 9.6
# 1.6 0.1
# 1.6 0.6
# 1.6 1.1
# 1.6 1.6
# 1.6 2.1
# 1.6 2.6
# 1.6 3.1
# 1.6 3.6
# 1.6 4.1
# 1.6 4.6
# 1.6 5.1
# 1.6 5.6
# 1.6 6.1
# 1.6 6.6
# 1.6 7.1
# 1.6 7.6
# 1.6 8.1
# 1.6 8.6
# 1.6 9.1
# 1.6 9.6
# 2.1 0.1
# 2.1 0.6
# 2.1 1.1
# 2.1 1.6
# 2.1 2.1
# 2.1 2.6
# 2.1 3.1
# 2.1 3.6
# 2.1 4.1
# 2.1 4.6
# 2.1 5.1
# 2.1 5.6
# 2.1 6.1
# 2.1 6.6
# 2.1 7.1
# 2.1 7.6
# 2.1 8.1
# 2.1 8.6
# 2.1 9.1
# 2.1 9.6
# ...

# %%
# plot gabor-type filter weights
from estimator import V1_inspired_weights
import matplotlib.pyplot as plt

t, l = 5, 1 # t = sigma_2, l is sigma_1
W = V1_inspired_weights(30, 625, t=t, l=l)

fig = plt.figure(figsize=(8, 6))
for i in range(25):
    ax = fig.add_subplot(5, 5, i + 1)
    plt.imshow(W[i].reshape(25, 25), cmap='seismic')
    plt.axis('off')
    plt.colorbar()

# %%
n_features = sorted(set(np.logspace(0, 3.2, 50).astype('int')))
n_features_sgd = np.arange(1, 1050, 50)
t, l = 4.1, 1.1
with open('results/fashion_mnist_clf/fashion_mnist_clf_t=%0.3f_l=%0.3f_sgd.pickle' % (t, l), 'rb') as handle:
    results_sgd = pickle.load(handle) 

with open('results/fashion_mnist_clf/fashion_mnist_clf_t=%0.2f_l=%0.2f.pickle' % (t, l), 'rb') as handle:
    results = pickle.load(handle) 
    

fig = plt.figure()
plt.plot(n_features, results['V1']['avg_test_err'], 'b')
plt.plot(n_features_sgd, results_sgd['V1']['avg_test_err'], '--b')
plt.plot(n_features_sgd, results_sgd['classical']['avg_test_err'], '--k')
plt.plot(n_features, results['classical']['avg_test_err'], 'k')
plt.xlim([0, 1020])
plt.yticks(np.arange(0, 0.8, 0.1))
plt.ylim([-0.05, 0.55])
plt.xticks(np.arange(0, 1020, 200))
ax.tick_params(axis = 'both', which = 'major', labelsize = 30, width=2, length=6)
