# %% [markdown]
# Initialize shallow feedforward fully-connected network with V1 type weights and classify __subset of fashion mnist__ dataset using __Gradient descent__. The partial dataset will have 5 samples/class.

# %%
import numpy as np
import numpy.linalg as la
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from estimator import classical_weights, V1_inspired_weights
from data_fns import load_fashion_mnist
from sklearn.model_selection import train_test_split
import pickle

# %%
torch.cuda.set_device(0)
train, train_labels, test, test_labels = load_fashion_mnist('./data/fashion_mnist/')

num_train = 50
train_few, _, train_labels_few, _ = train_test_split(train, train_labels, train_size=num_train, stratify=train_labels, 
                                          random_state=42)


X_train = torch.from_numpy(train_few).float().to('cuda')
X_test = torch.from_numpy(test).float().to('cuda')
y_train = torch.from_numpy(train_labels_few).long().to('cuda')
y_test = torch.from_numpy(test_labels).long().to('cuda')
n, d = X_train.shape

# %%
class V1_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(V1_inspired_weights(hidden_size, d, t=5, l=2, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class He_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class RF_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(classical_weights(hidden_size, d, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)

# %%
def predict(model, X):
    return model(X).data.max(1)[1]

def error(model, X, y):
    y_pred = predict(model, X)
    accuracy = 1.0 * torch.sum(y_pred == y) / len(y)
    return 1 - accuracy

# %%
n_trials, n_epochs = 10, 7001
models = {'V1': V1_net, 'He': He_net}
h_list = [50, 100, 400, 1000]
lr_list = [1e-3, 1e-2, 1e-1, 1e0]

train_err = {m: {h: {lr: np.zeros((n_trials, n_epochs)) for lr in lr_list} for h in h_list} for m in models.keys()}
test_err = {m: {h: {lr: np.zeros((n_trials, n_epochs)) for lr in lr_list} for h in h_list} for m in models.keys()}
loss_list = {m: {h: {lr: np.zeros((n_trials, n_epochs)) for lr in lr_list} for h in h_list} for m in models.keys()}

# %%
scale = 2/d
t, l = 5, 2
loss_func = nn.CrossEntropyLoss()

for h in h_list:
    for lr in lr_list:
        for m, network in models.items():
            for i in range(n_trials):
                model = network(h, scale).to('cuda')
                optim = torch.optim.SGD(model.parameters(), lr=lr)
                for j in range(n_epochs):
                    optim.zero_grad()
                    loss = loss_func(model(X_train), y_train)
                    loss.backward()
                    optim.step()

                    train_err[m][h][lr][i, j] = error(model, X_train, y_train)
                    test_err[m][h][lr][i, j] = error(model, X_test, y_test)
                    loss_list[m][h][lr][i, j] = loss.data

                    if (j % 1000 == 0):
                        print('Trial %d, Epoch: %d, %s model, h=%d, lr=%0.5f, Loss=%0.5f, test err=%0.3f' % (i,j, m, h, lr, loss.data, 
                                                                                                  test_err[m][h][lr][i, j]))
results = {'test_err': test_err, 'train_err': train_err, 'loss': loss_list}
with open('results/initialize_fashion_mnist/fewshot_data/clf_t=%0.2f_l=%0.2f.pickle' % (t, l), 'wb') as handle:
    pickle.dump(results, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.60254, test err=0.890
# Trial 0, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.41886, test err=0.499
# Trial 0, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.02083, test err=0.446
# Trial 0, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.76788, test err=0.424
# Trial 0, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.58785, test err=0.413
# Trial 0, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.45563, test err=0.404
# Trial 0, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.35841, test err=0.398
# Trial 0, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.28743, test err=0.394
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=3.40404, test err=0.900
# Trial 1, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.35016, test err=0.560
# Trial 1, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.98314, test err=0.481
# Trial 1, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.74642, test err=0.448
# Trial 1, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.57738, test err=0.433
# Trial 1, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.45387, test err=0.418
# Trial 1, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.36172, test err=0.407
# Trial 1, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.29230, test err=0.400
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.52529, test err=0.895
# Trial 2, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.17136, test err=0.498
# Trial 2, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.83186, test err=0.435
# Trial 2, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.63652, test err=0.411
# Trial 2, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.50418, test err=0.397
# Trial 2, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.40703, test err=0.392
# Trial 2, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.33360, test err=0.384
# Trial 2, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.27687, test err=0.380
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=3.25029, test err=0.904
# Trial 3, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.20416, test err=0.525
# Trial 3, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.82194, test err=0.464
# Trial 3, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.61006, test err=0.429
# Trial 3, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.47255, test err=0.411
# Trial 3, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.37765, test err=0.401
# Trial 3, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.30936, test err=0.396
# Trial 3, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.25803, test err=0.393
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=3.30012, test err=0.859
# Trial 4, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.23922, test err=0.442
# Trial 4, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.86238, test err=0.389
# Trial 4, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.64240, test err=0.374
# Trial 4, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.49204, test err=0.368
# Trial 4, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.38377, test err=0.364
# Trial 4, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.30401, test err=0.363
# Trial 4, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.24509, test err=0.363
# Trial 5, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.99823, test err=0.955
# Trial 5, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.22717, test err=0.480
# Trial 5, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.89068, test err=0.439
# Trial 5, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.68716, test err=0.427
# Trial 5, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.53941, test err=0.416
# Trial 5, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.43043, test err=0.407
# Trial 5, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.34864, test err=0.398
# Trial 5, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.28630, test err=0.391
# Trial 6, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.79850, test err=0.931
# Trial 6, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.36421, test err=0.507
# Trial 6, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.97521, test err=0.436
# Trial 6, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.72876, test err=0.413
# Trial 6, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.55836, test err=0.397
# Trial 6, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.43553, test err=0.385
# Trial 6, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.34614, test err=0.376
# Trial 6, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.27978, test err=0.373
# Trial 7, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.63907, test err=0.908
# Trial 7, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.20336, test err=0.425
# Trial 7, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.84963, test err=0.380
# Trial 7, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.63911, test err=0.371
# Trial 7, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.49615, test err=0.365
# Trial 7, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.39263, test err=0.360
# Trial 7, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.31664, test err=0.358
# Trial 7, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.26013, test err=0.356
# Trial 8, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.93724, test err=0.899
# Trial 8, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.20135, test err=0.444
# Trial 8, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.85598, test err=0.400
# Trial 8, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.65148, test err=0.383
# Trial 8, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.50862, test err=0.377
# Trial 8, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.40421, test err=0.375
# Trial 8, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.32555, test err=0.372
# Trial 8, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.26549, test err=0.370
# Trial 9, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=3.47403, test err=0.901
# Trial 9, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.28209, test err=0.452
# Trial 9, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.92260, test err=0.409
# Trial 9, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.69227, test err=0.400
# Trial 9, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.53010, test err=0.400
# Trial 9, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.41531, test err=0.402
# Trial 9, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.33230, test err=0.400
# Trial 9, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.27140, test err=0.398
# Trial 0, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.37223, test err=0.908
# Trial 0, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.68149, test err=0.535
# Trial 0, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.23262, test err=0.417
# Trial 0, Epoch: 3000, He model, h=50, lr=0.00100, Loss=0.92135, test err=0.389
# Trial 0, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.69358, test err=0.387
# Trial 0, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.52672, test err=0.385
# Trial 0, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.40685, test err=0.381
# Trial 0, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.32147, test err=0.377
# Trial 1, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.37887, test err=0.915
# Trial 1, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.79362, test err=0.552
# Trial 1, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.30839, test err=0.481
# Trial 1, Epoch: 3000, He model, h=50, lr=0.00100, Loss=0.97662, test err=0.435
# Trial 1, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.73696, test err=0.415
# Trial 1, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.56090, test err=0.409
# Trial 1, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.43332, test err=0.402
# Trial 1, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.34114, test err=0.394
# Trial 2, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.49108, test err=0.892
# Trial 2, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.85638, test err=0.659
# Trial 2, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.36444, test err=0.457
# Trial 2, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.01689, test err=0.408
# Trial 2, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.76570, test err=0.387
# Trial 2, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.58472, test err=0.382
# Trial 2, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.45370, test err=0.381
# Trial 2, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.35886, test err=0.378
# Trial 3, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.36098, test err=0.848
# Trial 3, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.72507, test err=0.541
# Trial 3, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.27349, test err=0.431
# Trial 3, Epoch: 3000, He model, h=50, lr=0.00100, Loss=0.97063, test err=0.381
# Trial 3, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.74505, test err=0.369
# Trial 3, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.57262, test err=0.360
# Trial 3, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.44451, test err=0.357
# Trial 3, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.35065, test err=0.353
# Trial 4, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.32762, test err=0.905
# Trial 4, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.74723, test err=0.660
# Trial 4, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.28387, test err=0.480
# Trial 4, Epoch: 3000, He model, h=50, lr=0.00100, Loss=0.95679, test err=0.439
# Trial 4, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.71518, test err=0.423
# Trial 4, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.53956, test err=0.413
# Trial 4, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.41381, test err=0.407
# Trial 4, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.32474, test err=0.400
# Trial 5, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.34597, test err=0.894
# Trial 5, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.74607, test err=0.636
# Trial 5, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.29872, test err=0.509
# Trial 5, Epoch: 3000, He model, h=50, lr=0.00100, Loss=0.97651, test err=0.453
# Trial 5, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.73508, test err=0.415
# Trial 5, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.55877, test err=0.394
# Trial 5, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.43205, test err=0.381
# Trial 5, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.34114, test err=0.372
# Trial 6, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.34196, test err=0.936
# Trial 6, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.71998, test err=0.621
# Trial 6, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.24536, test err=0.501
# Trial 6, Epoch: 3000, He model, h=50, lr=0.00100, Loss=0.91903, test err=0.430
# Trial 6, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.68834, test err=0.404
# Trial 6, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.52362, test err=0.392
# Trial 6, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.40581, test err=0.386
# Trial 6, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.32093, test err=0.383
# Trial 7, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.29051, test err=0.829
# Trial 7, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.71823, test err=0.616
# Trial 7, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.25898, test err=0.483
# Trial 7, Epoch: 3000, He model, h=50, lr=0.00100, Loss=0.94901, test err=0.436
# Trial 7, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.72149, test err=0.414
# Trial 7, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.55211, test err=0.396
# Trial 7, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.42756, test err=0.382
# Trial 7, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.33690, test err=0.373
# Trial 8, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.35996, test err=0.895
# Trial 8, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.78294, test err=0.539
# Trial 8, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.28018, test err=0.405
# Trial 8, Epoch: 3000, He model, h=50, lr=0.00100, Loss=0.94374, test err=0.384
# Trial 8, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.70998, test err=0.377
# Trial 8, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.54192, test err=0.376
# Trial 8, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.42018, test err=0.375
# Trial 8, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.33221, test err=0.373
# Trial 9, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.31682, test err=0.894
# Trial 9, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.74228, test err=0.597
# Trial 9, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.30085, test err=0.488
# Trial 9, Epoch: 3000, He model, h=50, lr=0.00100, Loss=0.98549, test err=0.418
# Trial 9, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.74880, test err=0.390
# Trial 9, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.57076, test err=0.373
# Trial 9, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.44004, test err=0.366
# Trial 9, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.34519, test err=0.363
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=3.19842, test err=0.872
# Trial 0, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.17769, test err=0.383
# Trial 0, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.05592, test err=0.367
# Trial 0, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.02794, test err=0.365
# Trial 0, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.01743, test err=0.362
# Trial 0, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.01227, test err=0.361
# Trial 0, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00930, test err=0.360
# Trial 0, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00740, test err=0.361
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.92907, test err=0.928
# Trial 1, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.15987, test err=0.375
# Trial 1, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.05345, test err=0.370
# Trial 1, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.02754, test err=0.368
# Trial 1, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.01738, test err=0.366
# Trial 1, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.01230, test err=0.366
# Trial 1, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00934, test err=0.366
# Trial 1, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00745, test err=0.367
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.78845, test err=0.834
# Trial 2, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.17802, test err=0.388
# Trial 2, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.05743, test err=0.372
# Trial 2, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.02828, test err=0.369
# Trial 2, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.01744, test err=0.370
# Trial 2, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.01220, test err=0.368
# Trial 2, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00921, test err=0.369
# Trial 2, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00732, test err=0.369
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=3.80422, test err=0.839
# Trial 3, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.15149, test err=0.374
# Trial 3, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.04974, test err=0.367
# Trial 3, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.02566, test err=0.366
# Trial 3, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.01625, test err=0.366
# Trial 3, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.01153, test err=0.366
# Trial 3, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00880, test err=0.365
# Trial 3, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00705, test err=0.366
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.91836, test err=0.928
# Trial 4, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.15984, test err=0.375
# Trial 4, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.05045, test err=0.368
# Trial 4, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.02557, test err=0.366
# Trial 4, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.01616, test err=0.366
# Trial 4, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.01151, test err=0.364
# Trial 4, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00880, test err=0.363
# Trial 4, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00706, test err=0.365
# Trial 5, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=3.27483, test err=0.915
# Trial 5, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.15992, test err=0.373
# Trial 5, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.05045, test err=0.372
# Trial 5, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.02586, test err=0.374
# Trial 5, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.01641, test err=0.373
# Trial 5, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.01167, test err=0.372
# Trial 5, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00891, test err=0.372
# Trial 5, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00714, test err=0.372
# Trial 6, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.31488, test err=0.881
# Trial 6, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.17136, test err=0.366
# Trial 6, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.05658, test err=0.358
# Trial 6, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.02811, test err=0.357
# Trial 6, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.01738, test err=0.356
# Trial 6, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.01216, test err=0.354
# Trial 6, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00919, test err=0.354
# Trial 6, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00730, test err=0.354
# Trial 7, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.74107, test err=0.883
# Trial 7, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.15233, test err=0.391
# Trial 7, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.05040, test err=0.382
# Trial 7, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.02601, test err=0.380
# Trial 7, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.01643, test err=0.378
# Trial 7, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.01168, test err=0.377
# Trial 7, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00891, test err=0.376
# Trial 7, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00713, test err=0.376
# Trial 8, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=3.23652, test err=0.922
# Trial 8, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.18962, test err=0.361
# Trial 8, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.05606, test err=0.362
# Trial 8, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.02771, test err=0.360
# Trial 8, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.01717, test err=0.358
# Trial 8, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.01205, test err=0.359
# Trial 8, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00911, test err=0.358
# Trial 8, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00724, test err=0.359
# Trial 9, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.46797, test err=0.931
# Trial 9, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.17217, test err=0.387
# Trial 9, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.05546, test err=0.371
# Trial 9, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.02766, test err=0.368
# Trial 9, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.01720, test err=0.367
# Trial 9, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.01208, test err=0.366
# Trial 9, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00913, test err=0.365
# Trial 9, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00726, test err=0.365
# Trial 0, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.30086, test err=0.917
# Trial 0, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.18797, test err=0.372
# Trial 0, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.05555, test err=0.366
# Trial 0, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.02766, test err=0.365
# Trial 0, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.01726, test err=0.364
# Trial 0, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.01217, test err=0.365
# Trial 0, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00924, test err=0.364
# Trial 0, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00736, test err=0.364
# Trial 1, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.28043, test err=0.874
# Trial 1, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.18342, test err=0.374
# Trial 1, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.05446, test err=0.366
# Trial 1, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.02705, test err=0.361
# Trial 1, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.01690, test err=0.359
# Trial 1, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.01192, test err=0.359
# Trial 1, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00906, test err=0.359
# Trial 1, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00723, test err=0.359
# Trial 2, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.36384, test err=0.860
# Trial 2, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.21620, test err=0.358
# Trial 2, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.06060, test err=0.355
# Trial 2, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.02934, test err=0.353
# Trial 2, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.01803, test err=0.353
# Trial 2, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.01259, test err=0.353
# Trial 2, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00949, test err=0.353
# Trial 2, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00753, test err=0.353
# Trial 3, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.39987, test err=0.940
# Trial 3, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.20824, test err=0.389
# Trial 3, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.06089, test err=0.376
# Trial 3, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.02973, test err=0.374
# Trial 3, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.01836, test err=0.373
# Trial 3, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.01285, test err=0.371
# Trial 3, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00970, test err=0.371
# Trial 3, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00771, test err=0.372
# Trial 4, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.38158, test err=0.964
# Trial 4, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.18954, test err=0.371
# Trial 4, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.05417, test err=0.360
# Trial 4, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.02671, test err=0.358
# Trial 4, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.01664, test err=0.358
# Trial 4, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.01174, test err=0.358
# Trial 4, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00891, test err=0.358
# Trial 4, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00711, test err=0.357
# Trial 5, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.35613, test err=0.920
# Trial 5, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.18554, test err=0.383
# Trial 5, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.05455, test err=0.376
# Trial 5, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.02707, test err=0.371
# Trial 5, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.01689, test err=0.369
# Trial 5, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.01190, test err=0.368
# Trial 5, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00903, test err=0.368
# Trial 5, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00720, test err=0.368
# Trial 6, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.35658, test err=0.958
# Trial 6, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.19070, test err=0.378
# Trial 6, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.05479, test err=0.363
# Trial 6, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.02715, test err=0.360
# Trial 6, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.01695, test err=0.359
# Trial 6, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.01194, test err=0.358
# Trial 6, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00906, test err=0.358
# Trial 6, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00723, test err=0.359
# Trial 7, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.39716, test err=0.892
# Trial 7, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.20665, test err=0.362
# Trial 7, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.06139, test err=0.355
# Trial 7, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.02977, test err=0.353
# Trial 7, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.01819, test err=0.353
# Trial 7, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.01265, test err=0.353
# Trial 7, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00951, test err=0.353
# Trial 7, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00753, test err=0.353
# Trial 8, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.29696, test err=0.886
# Trial 8, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.17995, test err=0.385
# Trial 8, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.05368, test err=0.380
# Trial 8, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.02691, test err=0.377
# Trial 8, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.01686, test err=0.376
# Trial 8, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.01190, test err=0.375
# Trial 8, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00905, test err=0.375
# Trial 8, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00722, test err=0.375
# Trial 9, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.33007, test err=0.887
# Trial 9, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.19259, test err=0.363
# Trial 9, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.05754, test err=0.359
# Trial 9, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.02834, test err=0.360
# Trial 9, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.01751, test err=0.359
# Trial 9, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.01226, test err=0.359
# Trial 9, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00926, test err=0.360
# Trial 9, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00736, test err=0.360
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.87210, test err=0.884
# Trial 0, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00451, test err=0.355
# Trial 0, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00179, test err=0.354
# Trial 0, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00107, test err=0.355
# Trial 0, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00075, test err=0.355
# Trial 0, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00057, test err=0.355
# Trial 0, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00046, test err=0.355
# Trial 0, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00038, test err=0.356
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=3.12819, test err=0.816
# Trial 1, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00438, test err=0.352
# Trial 1, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00177, test err=0.353
# Trial 1, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00106, test err=0.353
# Trial 1, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00075, test err=0.353
# Trial 1, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00057, test err=0.354
# Trial 1, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00046, test err=0.354
# Trial 1, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00038, test err=0.354
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=3.10413, test err=0.897
# Trial 2, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00444, test err=0.373
# Trial 2, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00177, test err=0.372
# Trial 2, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00106, test err=0.372
# Trial 2, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00075, test err=0.372
# Trial 2, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00057, test err=0.371
# Trial 2, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00046, test err=0.371
# Trial 2, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00038, test err=0.371
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.88623, test err=0.862
# Trial 3, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00435, test err=0.366
# Trial 3, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00174, test err=0.365
# Trial 3, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00105, test err=0.365
# Trial 3, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00074, test err=0.366
# Trial 3, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00056, test err=0.367
# Trial 3, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00045, test err=0.366
# Trial 3, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00038, test err=0.365
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=3.26151, test err=0.928
# Trial 4, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00431, test err=0.376
# Trial 4, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00174, test err=0.374
# Trial 4, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00105, test err=0.373
# Trial 4, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00074, test err=0.373
# Trial 4, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00056, test err=0.373
# Trial 4, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00045, test err=0.374
# Trial 4, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00038, test err=0.374
# Trial 5, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=3.18021, test err=0.864
# Trial 5, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00418, test err=0.356
# Trial 5, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00169, test err=0.354
# Trial 5, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00102, test err=0.354
# Trial 5, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00072, test err=0.354
# Trial 5, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00055, test err=0.354
# Trial 5, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00045, test err=0.355
# Trial 5, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00037, test err=0.354
# Trial 6, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.63946, test err=0.807
# Trial 6, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00446, test err=0.375
# Trial 6, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00178, test err=0.373
# Trial 6, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00107, test err=0.372
# Trial 6, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00075, test err=0.371
# Trial 6, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00057, test err=0.371
# Trial 6, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00046, test err=0.371
# Trial 6, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00039, test err=0.370
# Trial 7, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=3.22667, test err=0.856
# Trial 7, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00451, test err=0.364
# Trial 7, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00179, test err=0.363
# Trial 7, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00107, test err=0.364
# Trial 7, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00075, test err=0.363
# Trial 7, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00058, test err=0.363
# Trial 7, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00046, test err=0.363
# Trial 7, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00039, test err=0.364
# Trial 8, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.71148, test err=0.888
# Trial 8, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00451, test err=0.369
# Trial 8, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00180, test err=0.368
# Trial 8, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00108, test err=0.367
# Trial 8, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00076, test err=0.366
# Trial 8, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00058, test err=0.366
# Trial 8, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00047, test err=0.366
# Trial 8, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00039, test err=0.365
# Trial 9, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.83688, test err=0.848
# Trial 9, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00453, test err=0.361
# Trial 9, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00180, test err=0.361
# Trial 9, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00108, test err=0.361
# Trial 9, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00076, test err=0.361
# Trial 9, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00058, test err=0.360
# Trial 9, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00047, test err=0.360
# Trial 9, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00039, test err=0.360
# Trial 0, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.27825, test err=0.773
# Trial 0, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00436, test err=0.351
# Trial 0, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00176, test err=0.353
# Trial 0, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00106, test err=0.353
# Trial 0, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00075, test err=0.354
# Trial 0, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00057, test err=0.353
# Trial 0, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00046, test err=0.353
# Trial 0, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00038, test err=0.354
# Trial 1, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.30978, test err=0.811
# Trial 1, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00451, test err=0.357
# Trial 1, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00178, test err=0.357
# Trial 1, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00106, test err=0.357
# Trial 1, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00075, test err=0.357
# Trial 1, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00057, test err=0.357
# Trial 1, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00046, test err=0.357
# Trial 1, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00038, test err=0.357
# Trial 2, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.30705, test err=0.812
# Trial 2, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00448, test err=0.362
# Trial 2, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00179, test err=0.361
# Trial 2, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00108, test err=0.362
# Trial 2, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00076, test err=0.360
# Trial 2, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00058, test err=0.362
# Trial 2, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00047, test err=0.362
# Trial 2, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00039, test err=0.362
# Trial 3, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.29323, test err=0.822
# Trial 3, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00435, test err=0.364
# Trial 3, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00174, test err=0.363
# Trial 3, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00105, test err=0.364
# Trial 3, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00074, test err=0.364
# Trial 3, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00057, test err=0.364
# Trial 3, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00046, test err=0.364
# Trial 3, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00038, test err=0.364
# Trial 4, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.41461, test err=0.914
# Trial 4, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00424, test err=0.355
# Trial 4, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00172, test err=0.356
# Trial 4, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00104, test err=0.357
# Trial 4, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00073, test err=0.356
# Trial 4, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00056, test err=0.357
# Trial 4, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00045, test err=0.357
# Trial 4, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00038, test err=0.357
# Trial 5, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.33645, test err=0.868
# Trial 5, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00421, test err=0.361
# Trial 5, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00171, test err=0.361
# Trial 5, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00104, test err=0.361
# Trial 5, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00073, test err=0.361
# Trial 5, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00056, test err=0.360
# Trial 5, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00045, test err=0.361
# Trial 5, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00038, test err=0.360
# Trial 6, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.33477, test err=0.830
# Trial 6, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00426, test err=0.359
# Trial 6, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00171, test err=0.359
# Trial 6, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00103, test err=0.358
# Trial 6, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00073, test err=0.358
# Trial 6, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00056, test err=0.358
# Trial 6, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00045, test err=0.358
# Trial 6, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00037, test err=0.359
# Trial 7, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.35412, test err=0.859
# Trial 7, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00432, test err=0.363
# Trial 7, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00173, test err=0.364
# Trial 7, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00104, test err=0.364
# Trial 7, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00073, test err=0.364
# Trial 7, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00056, test err=0.363
# Trial 7, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00045, test err=0.363
# Trial 7, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00038, test err=0.363
# Trial 8, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.39708, test err=0.869
# Trial 8, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00436, test err=0.365
# Trial 8, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00176, test err=0.364
# Trial 8, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00106, test err=0.364
# Trial 8, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00075, test err=0.364
# Trial 8, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00057, test err=0.364
# Trial 8, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00046, test err=0.364
# Trial 8, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00038, test err=0.364
# Trial 9, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.37511, test err=0.854
# Trial 9, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00435, test err=0.359
# Trial 9, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00174, test err=0.357
# Trial 9, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00105, test err=0.359
# Trial 9, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00074, test err=0.359
# Trial 9, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00057, test err=0.359
# Trial 9, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00046, test err=0.359
# Trial 9, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00038, test err=0.358
# Trial 0, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.90575, test err=0.819
# Trial 0, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=1.93310, test err=0.763
# Trial 0, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=1.93220, test err=0.759
# Trial 0, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=1.93198, test err=0.756
# Trial 0, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=1.93189, test err=0.754
# Trial 0, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=1.93183, test err=0.753
# Trial 0, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=1.93180, test err=0.753
# Trial 0, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=1.93177, test err=0.752
# Trial 1, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.81165, test err=0.898
# Trial 1, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=2.20196, test err=0.870
# Trial 1, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=2.20195, test err=0.868
# Trial 1, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=2.20195, test err=0.867
# Trial 1, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=2.20195, test err=0.867
# Trial 1, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=2.20195, test err=0.864
# Trial 1, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=2.20194, test err=0.867
# Trial 1, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=2.20194, test err=0.866
# Trial 2, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.82258, test err=0.803
# Trial 2, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=2.14296, test err=0.842
# Trial 2, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=2.14293, test err=0.841
# Trial 2, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=2.14293, test err=0.841
# Trial 2, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=2.14292, test err=0.841
# Trial 2, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=2.14292, test err=0.841
# Trial 2, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=2.14292, test err=0.841
# Trial 2, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=2.14292, test err=0.841
# Trial 3, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.58961, test err=0.775
# Trial 3, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=2.30258, test err=0.900
# Trial 3, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=2.30258, test err=0.900
# Trial 3, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=2.30258, test err=0.900
# Trial 3, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=2.30258, test err=0.900
# Trial 3, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=2.30258, test err=0.900
# Trial 3, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=2.30258, test err=0.900
# Trial 3, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=2.30258, test err=0.900
# Trial 4, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=3.09433, test err=0.899
# Trial 4, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=2.02761, test err=0.816
# Trial 4, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=2.02756, test err=0.803
# Trial 4, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=2.02755, test err=0.797
# Trial 4, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=2.02755, test err=0.809
# Trial 4, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=2.02755, test err=0.806
# Trial 4, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=2.02755, test err=0.802
# Trial 4, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=2.02755, test err=0.801
# Trial 5, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.96210, test err=0.899
# Trial 5, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=2.30258, test err=0.893
# Trial 5, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=2.30258, test err=0.893
# Trial 5, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=2.30258, test err=0.893
# Trial 5, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=2.30258, test err=0.893
# Trial 5, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=2.30258, test err=0.893
# Trial 5, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=2.30258, test err=0.893
# Trial 5, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=2.30258, test err=0.893
# Trial 6, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.54485, test err=0.720
# Trial 6, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=1.75856, test err=0.738
# Trial 6, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=1.75806, test err=0.731
# Trial 6, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=1.75986, test err=0.736
# Trial 6, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=1.75861, test err=0.737
# Trial 6, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=1.75823, test err=0.738
# Trial 6, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=1.75806, test err=0.740
# Trial 6, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=1.75827, test err=0.748
# Trial 7, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.73115, test err=0.888
# Trial 7, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=2.14294, test err=0.856
# Trial 7, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=2.14293, test err=0.855
# Trial 7, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=2.14292, test err=0.856
# Trial 7, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=2.14292, test err=0.856
# Trial 7, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=2.14292, test err=0.857
# Trial 7, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=2.14292, test err=0.856
# Trial 7, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=2.14292, test err=0.856
# Trial 8, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.88884, test err=0.828
# Trial 8, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=2.14294, test err=0.877
# Trial 8, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=2.14293, test err=0.874
# Trial 8, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=2.14292, test err=0.873
# Trial 8, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=2.14292, test err=0.873
# Trial 8, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=2.14292, test err=0.873
# Trial 8, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=2.14292, test err=0.873
# Trial 8, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=2.14292, test err=0.872
# Trial 9, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.79890, test err=0.809
# Trial 9, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=1.76042, test err=0.738
# Trial 9, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=1.75875, test err=0.739
# Trial 9, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=1.75829, test err=0.736
# Trial 9, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=1.75808, test err=0.736
# Trial 9, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=1.75798, test err=0.737
# Trial 9, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=1.75791, test err=0.737
# Trial 9, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=1.75785, test err=0.737
# Trial 0, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.35257, test err=0.668
# Trial 0, Epoch: 1000, He model, h=50, lr=1.00000, Loss=1.82535, test err=0.780
# Trial 0, Epoch: 2000, He model, h=50, lr=1.00000, Loss=1.82484, test err=0.772
# Trial 0, Epoch: 3000, He model, h=50, lr=1.00000, Loss=1.82468, test err=0.769
# Trial 0, Epoch: 4000, He model, h=50, lr=1.00000, Loss=1.82460, test err=0.769
# Trial 0, Epoch: 5000, He model, h=50, lr=1.00000, Loss=1.82456, test err=0.766
# Trial 0, Epoch: 6000, He model, h=50, lr=1.00000, Loss=1.82452, test err=0.766
# Trial 0, Epoch: 7000, He model, h=50, lr=1.00000, Loss=1.82450, test err=0.765
# Trial 1, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.33491, test err=0.776
# Trial 1, Epoch: 1000, He model, h=50, lr=1.00000, Loss=2.14294, test err=0.921
# Trial 1, Epoch: 2000, He model, h=50, lr=1.00000, Loss=2.14293, test err=0.925
# Trial 1, Epoch: 3000, He model, h=50, lr=1.00000, Loss=2.14292, test err=0.924
# Trial 1, Epoch: 4000, He model, h=50, lr=1.00000, Loss=2.14292, test err=0.925
# Trial 1, Epoch: 5000, He model, h=50, lr=1.00000, Loss=2.14292, test err=0.913
# Trial 1, Epoch: 6000, He model, h=50, lr=1.00000, Loss=2.14292, test err=0.914
# Trial 1, Epoch: 7000, He model, h=50, lr=1.00000, Loss=2.14292, test err=0.916
# Trial 2, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.30589, test err=0.796
# Trial 2, Epoch: 1000, He model, h=50, lr=1.00000, Loss=2.30258, test err=0.908
# Trial 2, Epoch: 2000, He model, h=50, lr=1.00000, Loss=2.30258, test err=0.908
# Trial 2, Epoch: 3000, He model, h=50, lr=1.00000, Loss=2.30258, test err=0.908
# Trial 2, Epoch: 4000, He model, h=50, lr=1.00000, Loss=2.30258, test err=0.908
# Trial 2, Epoch: 5000, He model, h=50, lr=1.00000, Loss=2.30258, test err=0.908
# Trial 2, Epoch: 6000, He model, h=50, lr=1.00000, Loss=2.30258, test err=0.908
# Trial 2, Epoch: 7000, He model, h=50, lr=1.00000, Loss=2.30258, test err=0.908
# Trial 3, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.31213, test err=0.737
# Trial 3, Epoch: 1000, He model, h=50, lr=1.00000, Loss=2.14294, test err=0.864
# Trial 3, Epoch: 2000, He model, h=50, lr=1.00000, Loss=2.14293, test err=0.862
# Trial 3, Epoch: 3000, He model, h=50, lr=1.00000, Loss=2.14292, test err=0.861
# Trial 3, Epoch: 4000, He model, h=50, lr=1.00000, Loss=2.14292, test err=0.860
# Trial 3, Epoch: 5000, He model, h=50, lr=1.00000, Loss=2.14292, test err=0.860
# Trial 3, Epoch: 6000, He model, h=50, lr=1.00000, Loss=2.14292, test err=0.859
# Trial 3, Epoch: 7000, He model, h=50, lr=1.00000, Loss=2.14292, test err=0.859
# Trial 4, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.36216, test err=0.811
# Trial 4, Epoch: 1000, He model, h=50, lr=1.00000, Loss=2.20197, test err=0.886
# Trial 4, Epoch: 2000, He model, h=50, lr=1.00000, Loss=2.20195, test err=0.883
# Trial 4, Epoch: 3000, He model, h=50, lr=1.00000, Loss=2.20195, test err=0.883
# Trial 4, Epoch: 4000, He model, h=50, lr=1.00000, Loss=2.20194, test err=0.883
# Trial 4, Epoch: 5000, He model, h=50, lr=1.00000, Loss=2.20194, test err=0.882
# Trial 4, Epoch: 6000, He model, h=50, lr=1.00000, Loss=2.20194, test err=0.882
# Trial 4, Epoch: 7000, He model, h=50, lr=1.00000, Loss=2.20194, test err=0.882
# Trial 5, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.32420, test err=0.621
# Trial 5, Epoch: 1000, He model, h=50, lr=1.00000, Loss=1.97736, test err=0.812
# Trial 5, Epoch: 2000, He model, h=50, lr=1.00000, Loss=1.97275, test err=0.808
# Trial 5, Epoch: 3000, He model, h=50, lr=1.00000, Loss=1.97117, test err=0.811
# Trial 5, Epoch: 4000, He model, h=50, lr=1.00000, Loss=1.97036, test err=0.811
# Trial 5, Epoch: 5000, He model, h=50, lr=1.00000, Loss=1.96973, test err=0.821
# Trial 5, Epoch: 6000, He model, h=50, lr=1.00000, Loss=2.14293, test err=0.896
# Trial 5, Epoch: 7000, He model, h=50, lr=1.00000, Loss=2.14292, test err=0.915
# Trial 6, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.31280, test err=0.646
# Trial 6, Epoch: 1000, He model, h=50, lr=1.00000, Loss=2.30258, test err=0.897
# ...
# Trial 5, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.00148, test err=0.350
# Trial 5, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.00091, test err=0.351
# Trial 5, Epoch: 4000, He model, h=1000, lr=0.10000, Loss=0.00065, test err=0.350
# Trial 5, Epoch: 5000, He model, h=1000, lr=0.10000, Loss=0.00050, test err=0.350
# Trial 5, Epoch: 6000, He model, h=1000, lr=0.10000, Loss=0.00041, test err=0.350
# Trial 5, Epoch: 7000, He model, h=1000, lr=0.10000, Loss=0.00034, test err=0.351
# Trial 6, Epoch: 0, He model, h=1000, lr=0.10000, Loss=2.39710, test err=0.853
# Trial 6, Epoch: 1000, He model, h=1000, lr=0.10000, Loss=0.00342, test err=0.354
# Trial 6, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.00148, test err=0.356
# Trial 6, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.00091, test err=0.356
# Trial 6, Epoch: 4000, He model, h=1000, lr=0.10000, Loss=0.00065, test err=0.356
# Trial 6, Epoch: 5000, He model, h=1000, lr=0.10000, Loss=0.00051, test err=0.356
# Trial 6, Epoch: 6000, He model, h=1000, lr=0.10000, Loss=0.00041, test err=0.357
# Trial 6, Epoch: 7000, He model, h=1000, lr=0.10000, Loss=0.00034, test err=0.356
# Trial 7, Epoch: 0, He model, h=1000, lr=0.10000, Loss=2.34047, test err=0.811
# Trial 7, Epoch: 1000, He model, h=1000, lr=0.10000, Loss=0.00345, test err=0.354
# Trial 7, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.00148, test err=0.353
# Trial 7, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.00091, test err=0.353
# Trial 7, Epoch: 4000, He model, h=1000, lr=0.10000, Loss=0.00065, test err=0.353
# Trial 7, Epoch: 5000, He model, h=1000, lr=0.10000, Loss=0.00050, test err=0.353
# Trial 7, Epoch: 6000, He model, h=1000, lr=0.10000, Loss=0.00041, test err=0.354
# Trial 7, Epoch: 7000, He model, h=1000, lr=0.10000, Loss=0.00034, test err=0.354
# Trial 8, Epoch: 0, He model, h=1000, lr=0.10000, Loss=2.32206, test err=0.667
# Trial 8, Epoch: 1000, He model, h=1000, lr=0.10000, Loss=0.00346, test err=0.347
# Trial 8, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.00149, test err=0.347
# Trial 8, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.00092, test err=0.347
# Trial 8, Epoch: 4000, He model, h=1000, lr=0.10000, Loss=0.00066, test err=0.348
# Trial 8, Epoch: 5000, He model, h=1000, lr=0.10000, Loss=0.00051, test err=0.348
# Trial 8, Epoch: 6000, He model, h=1000, lr=0.10000, Loss=0.00041, test err=0.348
# Trial 8, Epoch: 7000, He model, h=1000, lr=0.10000, Loss=0.00034, test err=0.348
# Trial 9, Epoch: 0, He model, h=1000, lr=0.10000, Loss=2.30380, test err=0.763
# Trial 9, Epoch: 1000, He model, h=1000, lr=0.10000, Loss=0.00343, test err=0.353
# Trial 9, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.00148, test err=0.352
# Trial 9, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.00091, test err=0.353
# Trial 9, Epoch: 4000, He model, h=1000, lr=0.10000, Loss=0.00065, test err=0.352
# Trial 9, Epoch: 5000, He model, h=1000, lr=0.10000, Loss=0.00050, test err=0.352
# Trial 9, Epoch: 6000, He model, h=1000, lr=0.10000, Loss=0.00041, test err=0.352
# Trial 9, Epoch: 7000, He model, h=1000, lr=0.10000, Loss=0.00034, test err=0.352
# Trial 0, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.86805, test err=0.804
# Trial 0, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=1.88638, test err=0.705
# Trial 0, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=1.88629, test err=0.689
# Trial 0, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=1.93276, test err=0.730
# Trial 0, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=1.93122, test err=0.700
# Trial 0, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=1.93122, test err=0.698
# Trial 0, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=1.93122, test err=0.697
# Trial 0, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=1.93122, test err=0.698
# Trial 1, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=3.03844, test err=0.840
# Trial 1, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=1.97668, test err=0.739
# Trial 1, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=1.75855, test err=0.734
# Trial 1, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=1.75919, test err=0.737
# Trial 1, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=1.75816, test err=0.734
# Trial 1, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=1.75794, test err=0.734
# Trial 1, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=1.75784, test err=0.733
# Trial 1, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=1.75778, test err=0.733
# Trial 2, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=3.23941, test err=0.769
# Trial 2, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=1.73284, test err=0.681
# Trial 2, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=1.91939, test err=0.758
# Trial 2, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=1.91937, test err=0.719
# Trial 2, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=1.91936, test err=0.717
# Trial 2, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=1.76394, test err=0.714
# Trial 2, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=1.75838, test err=0.712
# Trial 2, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=1.75801, test err=0.710
# Trial 3, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=3.16203, test err=0.845
# Trial 3, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=2.02760, test err=0.776
# Trial 3, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=2.02756, test err=0.761
# Trial 3, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=2.02755, test err=0.760
# Trial 3, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=2.02755, test err=0.758
# Trial 3, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=2.02755, test err=0.757
# Trial 3, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=2.02755, test err=0.757
# Trial 3, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=2.02755, test err=0.756
# Trial 4, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.55595, test err=0.900
# Trial 4, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=1.97745, test err=0.777
# Trial 4, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=1.75851, test err=0.714
# Trial 4, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=1.75804, test err=0.710
# Trial 4, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=1.75790, test err=0.707
# Trial 4, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=1.75781, test err=0.706
# Trial 4, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=1.75776, test err=0.705
# Trial 4, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=1.75773, test err=0.704
# Trial 5, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=3.03737, test err=0.860
# Trial 5, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=1.79150, test err=0.707
# Trial 5, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=1.75854, test err=0.689
# Trial 5, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=1.75805, test err=0.683
# Trial 5, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=1.75789, test err=0.680
# Trial 5, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=1.75781, test err=0.680
# Trial 5, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=1.75777, test err=0.678
# Trial 5, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=1.75774, test err=0.678
# Trial 6, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=3.03509, test err=0.706
# Trial 6, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=1.75901, test err=0.726
# Trial 6, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=1.97664, test err=0.751
# Trial 6, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=1.97663, test err=0.748
# Trial 6, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=1.97662, test err=0.747
# Trial 6, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=1.97662, test err=0.733
# Trial 6, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=2.02756, test err=0.745
# Trial 6, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=2.02755, test err=0.798
# Trial 7, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=3.29561, test err=0.900
# Trial 7, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=2.00878, test err=0.774
# Trial 7, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=2.02756, test err=0.772
# Trial 7, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=1.97670, test err=0.756
# Trial 7, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=1.97663, test err=0.709
# Trial 7, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=1.97663, test err=0.707
# Trial 7, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=1.97662, test err=0.707
# Trial 7, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=1.97662, test err=0.706
# Trial 8, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.72390, test err=0.795
# Trial 8, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=1.78837, test err=0.748
# Trial 8, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=1.75848, test err=0.693
# Trial 8, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=1.75804, test err=0.691
# Trial 8, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=1.75789, test err=0.690
# Trial 8, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=1.75781, test err=0.690
# Trial 8, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=1.75776, test err=0.689
# Trial 8, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=1.75773, test err=0.688
# Trial 9, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.82212, test err=0.809
# Trial 9, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=1.75899, test err=0.675
# Trial 9, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=1.75815, test err=0.667
# Trial 9, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=1.75794, test err=0.664
# Trial 9, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=1.75784, test err=0.662
# Trial 9, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=1.75778, test err=0.659
# Trial 9, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=1.75775, test err=0.658
# Trial 9, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=1.75772, test err=0.661
# Trial 0, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.37062, test err=0.816
# Trial 0, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=2.14294, test err=0.809
# Trial 0, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=2.14293, test err=0.808
# Trial 0, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=2.14292, test err=0.808
# Trial 0, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=2.14292, test err=0.808
# Trial 0, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=2.14292, test err=0.808
# Trial 0, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=2.14292, test err=0.808
# Trial 0, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=2.14292, test err=0.807
# Trial 1, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.27150, test err=0.660
# Trial 1, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=1.75941, test err=0.729
# Trial 1, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=1.75820, test err=0.727
# Trial 1, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=1.75795, test err=0.726
# Trial 1, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=1.75785, test err=0.726
# Trial 1, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=1.75786, test err=0.729
# Trial 1, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=1.75780, test err=0.731
# Trial 1, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=1.75775, test err=0.731
# Trial 2, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.37465, test err=0.798
# Trial 2, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=2.07387, test err=0.845
# Trial 2, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=2.07386, test err=0.845
# Trial 2, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=2.07386, test err=0.845
# Trial 2, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=2.07386, test err=0.844
# Trial 2, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=2.07386, test err=0.843
# Trial 2, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=2.07386, test err=0.843
# Trial 2, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=2.07386, test err=0.842
# Trial 3, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.33501, test err=0.661
# Trial 3, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=2.07390, test err=0.827
# Trial 3, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=2.08082, test err=0.761
# Trial 3, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=2.07387, test err=0.794
# Trial 3, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=2.07387, test err=0.794
# Trial 3, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=2.07386, test err=0.793
# Trial 3, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=2.07386, test err=0.814
# Trial 3, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=2.07386, test err=0.793
# Trial 4, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.28388, test err=0.633
# Trial 4, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=1.75841, test err=0.703
# Trial 4, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=1.75801, test err=0.702
# Trial 4, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=1.75787, test err=0.699
# Trial 4, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=1.75780, test err=0.698
# Trial 4, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=1.75776, test err=0.696
# Trial 4, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=1.75773, test err=0.696
# Trial 4, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=1.75771, test err=0.693
# Trial 5, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.32769, test err=0.758
# Trial 5, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=1.75888, test err=0.679
# Trial 5, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=1.75812, test err=0.678
# Trial 5, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=1.75792, test err=0.675
# Trial 5, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=1.75784, test err=0.675
# Trial 5, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=1.75778, test err=0.680
# Trial 5, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=1.75774, test err=0.677
# Trial 5, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=1.75772, test err=0.677
# Trial 6, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.33737, test err=0.895
# Trial 6, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=1.75860, test err=0.765
# Trial 6, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=1.75807, test err=0.762
# Trial 6, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=1.75790, test err=0.759
# Trial 6, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=1.75782, test err=0.756
# Trial 6, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=1.75777, test err=0.754
# Trial 6, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=1.75774, test err=0.754
# Trial 6, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=1.75771, test err=0.754
# Trial 7, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.37032, test err=0.735
# Trial 7, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=2.02771, test err=0.776
# Trial 7, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=2.02756, test err=0.753
# Trial 7, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=1.97663, test err=0.725
# Trial 7, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=1.97662, test err=0.722
# Trial 7, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=1.97662, test err=0.720
# Trial 7, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=1.97662, test err=0.717
# Trial 7, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=1.97662, test err=0.720
# Trial 8, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.34581, test err=0.633
# Trial 8, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=1.75919, test err=0.728
# Trial 8, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=1.75817, test err=0.721
# Trial 8, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=1.75794, test err=0.718
# Trial 8, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=1.75784, test err=0.716
# Trial 8, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=1.75778, test err=0.715
# Trial 8, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=1.75775, test err=0.714
# Trial 8, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=1.75772, test err=0.713
# Trial 9, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.35875, test err=0.771
# Trial 9, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=1.75908, test err=0.708
# Trial 9, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=1.75819, test err=0.715
# Trial 9, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=1.75794, test err=0.713
# Trial 9, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=1.75784, test err=0.711
# Trial 9, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=1.75778, test err=0.709
# Trial 9, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=1.75775, test err=0.708
# Trial 9, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=1.75773, test err=0.709

# %% [markdown]
# ## plot results

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

t, l, n_epochs= 5, 2, 7001
models = ['V1', 'He']
h_list = [50, 100, 400, 1000]
lr_list = [1e-3, 1e-2, 1e-1, 1e0]

for h in h_list:
    for lr in lr_list:
        with open('results/initialize_fashion_mnist/fewshot_data/clf_t=%0.2f_l=%0.2f.pickle' % (t, l), 'rb') as handle:
            sims = pickle.load(handle)

        fig = plt.figure(figsize=(12, 5))
        plt.suptitle(r'Shallow FFW FC net w/ GD. h=%d, lr=%0.4f, '% (h, lr), fontsize=16)
        
        # loss
        ax = fig.add_subplot(131)
        plt.title('Network loss', fontsize=16)
        for m in models:
            avg_loss = np.mean(sims['loss'][m][h][lr], axis=0)
            std_loss = np.std(sims['loss'][m][h][lr], axis=0)                       
            plt.plot(np.arange(n_epochs), avg_loss, label=m, lw=3)
            plt.fill_between(np.arange(n_epochs), avg_loss - std_loss, avg_loss + std_loss, alpha=0.2)
        plt.xlabel('Epoch', fontsize=20)
        plt.ylabel('Training loss', fontsize=20)
        ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
        plt.yscale('log')
        plt.legend(fontsize=18)
        
        # train err
        ax = fig.add_subplot(132)
        plt.title('Train error', fontsize=16)
        for m in models:
            avg_train_err = np.mean(sims['train_err'][m][h][lr], axis=0)
            std_train_err = np.std(sims['train_err'][m][h][lr], axis=0)
            plt.plot(np.arange(n_epochs), avg_train_err, label=m, lw=3)
            plt.fill_between(np.arange(n_epochs), avg_train_err - std_train_err, avg_train_err + std_train_err,  alpha=0.2)
        
        plt.xlabel('Epoch', fontsize=20)
        plt.ylabel('Training error', fontsize=20)
        ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
        plt.yticks(np.arange(0, 1, 0.2))
        plt.yscale('log')
        plt.legend(fontsize=18)

        # test err
        ax = fig.add_subplot(133)
        plt.title('Test error', fontsize=16)
        for m in models:
            avg_test_err = np.mean(sims['test_err'][m][h][lr], axis=0)
            std_test_err = np.std(sims['test_err'][m][h][lr], axis=0)
            plt.plot(np.arange(n_epochs), avg_test_err, label=m, lw=3)
            plt.fill_between(np.arange(n_epochs), avg_test_err - std_test_err, avg_test_err + std_test_err, alpha=0.2)

        plt.xlabel('Epoch', fontsize=20)
        plt.ylabel('Test error', fontsize=20)
        ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
        plt.yticks(np.arange(0, 1, 0.2))
        plt.yscale('log')
        plt.legend(fontsize=18)

        plt.tight_layout()
        plt.subplots_adjust(top=0.8)    

        print(h, lr, )
        plt.savefig('results/initialize_fashion_mnist/fewshot_data/init_t=%0.2f_l=%0.2f_h=%d_lr=%0.4f.png' % (t, l, h, lr))
        plt.close()
# Out:
# 50 0.001
# 50 0.01
# 50 0.1
# 50 1.0
# 100 0.001
# 100 0.01
# 100 0.1
# 100 1.0
# 400 0.001
# 400 0.01
# 400 0.1
# 400 1.0
# 1000 0.001
# 1000 0.01
# 1000 0.1
# 1000 1.0

# %%
# !nvidia-smi

# %%
ls results/initialize_fashion_mnist/fewshot_data/
