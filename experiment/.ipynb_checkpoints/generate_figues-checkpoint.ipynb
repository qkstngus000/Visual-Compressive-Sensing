# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.linalg as la

import sys
sys.path.append("../")

# Package for importing image representation
from PIL import Image, ImageOps

# from src.V1_reconst import generate_Y, reconstruct
import pandas as pd
import seaborn as sns
import time
import os.path
from src.figure_library import *
from src.utility_library import *

# %%
img_arr = process_image('peppers.png', 'c')
reconst = filter_reconstruct(img_arr, 500, 7, 4, alpha = 0.1, observation = 'V1', mode = 'c')
# saving image
np.save('peppers_reconst.npy', reconst)
# fig, ax1, ax2 = error_colorbar(img_arr = img_arr, reconst = reconst, observation = 'V1', num_cell = 200)
# Out:
# Process Reconstruction on (540, 540, 3) image

# %%
fig, ax1, ax2 = error_colorbar(img_arr = img_arr, reconst = reconst, observation = 'V1', num_cell = 200)

# %%
img_arr - reconst
# Out:
# array([[[ 46,  22,  12],
#         [ 18,  28,  19],
#         [ 20,  29,   0],
#         ...,
#         [ 37,   0,  30],
#         [ 18,   8,  52],
#         [  1,  -4,   5]],
#
#        [[ 43,  29,  26],
#         [ 33,  12,   0],
#         [ -1,   0,  -1],
#         ...,
#         [ 27,   0,   0],
#         [  0,  33,  60],
#         [-15,   0,   0]],
#
#        [[ 11,   0,  29],
#         [ 14,  -1,  29],
#         [  8,   1,  11],
#         ...,
#         [  9,   1,  17],
#         [ -1,  26,  76],
#         [  0,  18,  21]],
#
#        ...,
#
#        [[ -8,   0,   0],
#         [ -8, -22, -12],
#         [-10,   5,   0],
#         ...,
#         [ 32,  53,   0],
#         [ 10,  35,  23],
#         [  4,  23,  -9]],
#
#        [[-11,  12, -23],
#         [-16,   0, -27],
#         [ -7,  11, -21],
#         ...,
#         [ 41,  49,   0],
#         [ 12,  36,   0],
#         [ -5,   0,  34]],
#
#        [[  2,   0, -17],
#         [-27,  32, -22],
#         [  0,  31,  -8],
#         ...,
#         [ 29,  46,   0],
#         [  0,  34,   8],
#         [  0,  -7,   0]]])

# %%
# Out:
# array([[[209, 214, 220],
#         [206, 211, 217],
#         [212, 217, 221],
#         ...,
#         [177, 213, 209],
#         [160, 196, 194],
#         [153, 192, 191]],
#
#        [[216, 221, 227],
#         [202, 207, 211],
#         [198, 206, 209],
#         ...,
#         [165, 202, 195],
#         [162, 198, 194],
#         [154, 190, 190]],
#
#        [[201, 209, 212],
#         [189, 197, 199],
#         [190, 198, 200],
#         ...,
#         [152, 187, 180],
#         [171, 206, 200],
#         [170, 205, 201]],
#
#        ...,
#
#        [[191, 208, 190],
#         [190, 207, 189],
#         [189, 206, 188],
#         ...,
#         [194, 212, 200],
#         [195, 213, 201],
#         [195, 213, 201]],
#
#        [[190, 208, 186],
#         [189, 207, 185],
#         [188, 206, 184],
#         ...,
#         [193, 211, 199],
#         [194, 212, 200],
#         [194, 212, 200]],
#
#        [[196, 214, 190],
#         [196, 214, 190],
#         [195, 213, 189],
#         ...,
#         [192, 210, 196],
#         [192, 210, 198],
#         [192, 210, 198]]], dtype=uint8)

# %%
s = 'hello'
time.ctime().replace(":", "_")
# Out:
# 'Tue Aug  1 16_30_17 2023'

# %%
s+ "_"+"_".join(str.split(time.ctime().replace(":", "_")))
# Out:
# 'hello_Tue_Aug_1_16_32_54_2023'

# %%
observation = '1'
if (observation.split('/')[0] != 'v1' or observation.split('/')[0] != 'V1') :
    observation = observation.lower()
else :
    print('upper triggered')
    observation = observation.upper()
observation
# Out:
#   File "/tmp/ipykernel_3054129/186604379.py", line 2
#     if (observation.split('/')[0] not 'v1' or observation.split('/')[0] not 'V1') :
#                                       ^
# SyntaxError: invalid syntax
