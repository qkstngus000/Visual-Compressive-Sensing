# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.linalg as la

from src.structured_random_features.src.models.weights import V1_weights

# Packages for fft and fitting data
from scipy import fftpack as fft
from sklearn.linear_model import Lasso

# Package for importing image representation
from PIL import Image, ImageOps

from src.V1_Compress import generate_Y, compress
import pandas as pd
import itertools
import dask
from dask.distributed import Client, progress
import seaborn as sns
import time
import os.path

# %%
## Check if this function is applicable to regular compress sensing
classical_img = Image.open("image/tree_part1.jpg")
classical_img = ImageOps.grayscale(classical_img)
classical_arr = np.asarray(classical_img)
cn, cm = classical_arr.shape
print(cn, cm)
classical_samp_list = [100, 200, 500]
alpha = np.logspace(-3, 3, 7)
rep = np.arange(10)
params = []
results = []

# List to make combination of
search_list = {'repetition': rep,
               'alpha': alpha,
               'classical_samp_list': classical_samp_list
              }



# Get repetition * alpha combination amount of result
for row in itertools.product(*search_list.values()):
    product = dict(zip(search_list.keys(), row))
    rep, alp, classical_samp = product.values()
    
    rand_index = np.random.randint(0, cn * cm, classical_samp)
    classical_Y = classical_arr.flatten()[rand_index]
    classical_Y = classical_Y.reshape(classical_samp, 1)

    # Generate C matrix
    C = np.eye(cn * cm)[rand_index, :] * np.sqrt(cn * cm) # 여기서 C 매트릭스를 스케일 해도 결과값이 안달라지는데 교수에게 물어보기
    C3D = C.reshape(classical_samp, cn, cm)
    theta, classical_reform, s = compress(C3D, classical_Y, alp)
    
    error = np.linalg.norm(classical_img - classical_reform, 'fro') / np.sqrt(cm*cn)
    
    params.append({'classical_samp' : classical_samp,
                   'alpha' : alp,
                   'repetition' : rep,
                   'error' : error
                  })
    results.append({'s' : s,
                    'theta' : theta,
                    'reform' : classical_reform,
                   })
# Out:
# 30 30
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.32099469370296, tolerance: 27.7496
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 72.91230012997026, tolerance: 66.30335000000001
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 70.555662956066, tolerance: 29.920779000000007
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 75.70294644206287, tolerance: 57.1323755
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45.519169672924505, tolerance: 29.326099
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 73.0382284572127, tolerance: 68.178872
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 57.83504634804971, tolerance: 31.293956
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 81.99396438062345, tolerance: 62.9839995
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41.925485482165, tolerance: 30.867464000000002
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 73.88695242269876, tolerance: 58.2431995
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48.18724932449239, tolerance: 32.373036
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 90.59616102917887, tolerance: 58.798142
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.392049279869894, tolerance: 31.090044000000002
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 73.53835637437192, tolerance: 56.8214595
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 47.27367126558574, tolerance: 31.277724
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 91.03603162876178, tolerance: 65.04567800000001
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.31202142709557, tolerance: 30.486636
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 66.84034439455127, tolerance: 64.3834875
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 70.5064053830353, tolerance: 29.951018999999995
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.61690820647535, tolerance: 27.691691
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 71.0740166068, tolerance: 63.7623875
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 56.287122010027524, tolerance: 33.1456
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 74.93255244234491, tolerance: 60.6174395
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 164.11064621993984, tolerance: 158.90965500000001
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38.3590313135692, tolerance: 29.169171
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 72.67386426406993, tolerance: 62.939952000000005
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 66.48687564941243, tolerance: 30.460979000000005
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 125.50753025882622, tolerance: 57.26579200000002
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.97391436960421, tolerance: 29.7712
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 76.40195440788149, tolerance: 64.1019555
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 60.00549601954087, tolerance: 31.897819000000002
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 73.90690417024456, tolerance: 60.300822
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.03829645631747, tolerance: 31.019531
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 66.64632418249373, tolerance: 61.134728
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 164.9709875913159, tolerance: 150.2778832
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 77.79604509526554, tolerance: 29.561616000000004
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 104.2542045155828, tolerance: 62.121950000000005
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.07953222089171, tolerance: 30.441019
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.077133731077105, tolerance: 30.103704000000004
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 72.77267182174513, tolerance: 64.04563950000001
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 85.38910358210568, tolerance: 30.874971
#   model = cd_fast.enet_coordinate_descent(
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 96.82094582642651, tolerance: 67.038752
#   model = cd_fast.enet_coordinate_descent(

# %%
params
# Out:
# [{'classical_samp': 100,
#   'alpha': 0.001,
#   'repetition': 0,
#   'error': 145.50814280794646},
#  {'classical_samp': 200,
#   'alpha': 0.001,
#   'repetition': 0,
#   'error': 145.28183397479413},
#  {'classical_samp': 500,
#   'alpha': 0.001,
#   'repetition': 0,
#   'error': 145.19716544098796},
#  {'classical_samp': 100,
#   'alpha': 0.01,
#   'repetition': 0,
#   'error': 145.4196355374758},
#  {'classical_samp': 200,
#   'alpha': 0.01,
#   'repetition': 0,
#   'error': 145.33011108419967},
#  {'classical_samp': 500,
#   'alpha': 0.01,
#   'repetition': 0,
#   'error': 145.21503904374447},
#  {'classical_samp': 100,
#   'alpha': 0.1,
#   'repetition': 0,
#   'error': 145.4640560596651},
#  {'classical_samp': 200,
#   'alpha': 0.1,
#   'repetition': 0,
#   'error': 145.35173893182886},
#  {'classical_samp': 500,
#   'alpha': 0.1,
#   'repetition': 0,
#   'error': 145.21035011186925},
#  {'classical_samp': 100,
#   'alpha': 1.0,
#   'repetition': 0,
#   'error': 145.39037806720566},
#  {'classical_samp': 200,
#   'alpha': 1.0,
#   'repetition': 0,
#   'error': 145.34863317063125},
#  {'classical_samp': 500,
#   'alpha': 1.0,
#   'repetition': 0,
#   'error': 145.27773940770717},
#  {'classical_samp': 100,
#   'alpha': 10.0,
#   'repetition': 0,
#   'error': 145.54605170650984},
#  {'classical_samp': 200,
#   'alpha': 10.0,
#   'repetition': 0,
#   'error': 145.4873704032252},
#  {'classical_samp': 500,
#   'alpha': 10.0,
#   'repetition': 0,
#   'error': 145.52227615453435},
#  {'classical_samp': 100,
#   'alpha': 100.0,
#   'repetition': 0,
#   'error': 145.78164036210686},
#  {'classical_samp': 200,
#   'alpha': 100.0,
#   'repetition': 0,
#   'error': 145.78164036210686},
#  {'classical_samp': 500,
#   'alpha': 100.0,
#   'repetition': 0,
#   'error': 145.78164036210686},
#  {'classical_samp': 100,
#   'alpha': 1000.0,
#   'repetition': 0,
#   'error': 145.78164036210686},
#  {'classical_samp': 200,
#   'alpha': 1000.0,
#   'repetition': 0,
#   'error': 145.78164036210686},
#  {'classical_samp': 500,
#   'alpha': 1000.0,
#   'repetition': 0,
#   'error': 145.78164036210686},
#  {'classical_samp': 100,
#   'alpha': 0.001,
#   'repetition': 1,
#   'error': 145.46592353643499},
#  {'classical_samp': 200,
#   'alpha': 0.001,
#   'repetition': 1,
#   'error': 145.26591121307985},
#  {'classical_samp': 500,
#   'alpha': 0.001,
#   'repetition': 1,
#   'error': 145.1934036004315},
#  {'classical_samp': 100,
#   'alpha': 0.01,
#   'repetition': 1,
#   'error': 145.40451902571797},
#  {'classical_samp': 200,
#   'alpha': 0.01,
#   'repetition': 1,
#   'error': 145.28036830020355},
#  {'classical_samp': 500,
#   'alpha': 0.01,
#   'repetition': 1,
#   'error': 145.21919952839454},
#  {'classical_samp': 100,
#   'alpha': 0.1,
#   'repetition': 1,
#   'error': 145.3814600517835},
#  {'classical_samp': 200,
#   'alpha': 0.1,
#   'repetition': 1,
#   'error': 145.32239804362123},
#  {'classical_samp': 500,
#   'alpha': 0.1,
#   'repetition': 1,
#   'error': 145.2257794842161},
#  {'classical_samp': 100,
#   'alpha': 1.0,
#   'repetition': 1,
#   'error': 145.3781350853292},
#  {'classical_samp': 200,
#   'alpha': 1.0,
#   'repetition': 1,
#   'error': 145.31256332126267},
#  {'classical_samp': 500,
#   'alpha': 1.0,
#   'repetition': 1,
#   'error': 145.2736677721429},
#  {'classical_samp': 100,
#   'alpha': 10.0,
#   'repetition': 1,
#   'error': 145.51178288464337},
#  {'classical_samp': 200,
#   'alpha': 10.0,
#   'repetition': 1,
#   'error': 145.57022185746536},
#  {'classical_samp': 500,
#   'alpha': 10.0,
#   'repetition': 1,
#   'error': 145.52208172110434},
#  {'classical_samp': 100,
#   'alpha': 100.0,
#   'repetition': 1,
#   'error': 145.78164036210686},
#  {'classical_samp': 200,
#   'alpha': 100.0,
#   'repetition': 1,
#   'error': 145.78164036210686},
#  {'classical_samp': 500,
#   'alpha': 100.0,
#   'repetition': 1,
#   'error': 145.78164036210686},
#  {'classical_samp': 100,
#   'alpha': 1000.0,
#   'repetition': 1,
#   'error': 145.78164036210686},
#  {'classical_samp': 200,
#   'alpha': 1000.0,
#   'repetition': 1,
#   'error': 145.78164036210686},
#  {'classical_samp': 500,
#   'alpha': 1000.0,
#   'repetition': 1,
#   'error': 145.78164036210686},
#  {'classical_samp': 100,
#   'alpha': 0.001,
#   'repetition': 2,
#   'error': 145.4480343468187},
#  {'classical_samp': 200,
#   'alpha': 0.001,
#   'repetition': 2,
#   'error': 145.35215179654963},
#  {'classical_samp': 500,
#   'alpha': 0.001,
#   'repetition': 2,
#   'error': 145.17981210211033},
#  {'classical_samp': 100,
#   'alpha': 0.01,
#   'repetition': 2,
#   'error': 145.3322737550431},
#  {'classical_samp': 200,
#   'alpha': 0.01,
#   'repetition': 2,
#   'error': 145.3166685777622},
#  {'classical_samp': 500,
#   'alpha': 0.01,
#   'repetition': 2,
#   'error': 145.21188901159982},
#  {'classical_samp': 100,
#   'alpha': 0.1,
#   'repetition': 2,
#   'error': 145.4579622525221},
#  {'classical_samp': 200,
#   'alpha': 0.1,
#   'repetition': 2,
#   'error': 145.30194831817082},
#  {'classical_samp': 500,
#   'alpha': 0.1,
#   'repetition': 2,
#   'error': 145.23144853457038},
#  {'classical_samp': 100,
#   'alpha': 1.0,
#   'repetition': 2,
#   'error': 145.36724286720633},
#  {'classical_samp': 200,
#   'alpha': 1.0,
#   'repetition': 2,
#   'error': 145.32740031592533},
#  {'classical_samp': 500,
#   'alpha': 1.0,
#   'repetition': 2,
#   'error': 145.2689475949136},
#  {'classical_samp': 100,
#   'alpha': 10.0,
#   'repetition': 2,
#   'error': 145.51194666336897},
#  {'classical_samp': 200,
#   'alpha': 10.0,
#   'repetition': 2,
#   'error': 145.51665534562025},
#  {'classical_samp': 500,
#   'alpha': 10.0,
#   'repetition': 2,
#   'error': 145.51599904205753},
#  {'classical_samp': 100,
#   'alpha': 100.0,
#   'repetition': 2,
#   'error': 145.78164036210686},
#  {'classical_samp': 200,
#   'alpha': 100.0,
#   'repetition': 2,
#   'error': 145.78164036210686},
#  {'classical_samp': 500,
#   'alpha': 100.0,
#   'repetition': 2,
#   'error': 145.78164036210686},
#  {'classical_samp': 100,
#   'alpha': 1000.0,
#   'repetition': 2,
#   'error': 145.78164036210686},
#  {'classical_samp': 200,
#   'alpha': 1000.0,
#   'repetition': 2,
#   'error': 145.78164036210686},
#  {'classical_samp': 500,
#   'alpha': 1000.0,
#   'repetition': 2,
#   'error': 145.78164036210686},
#  {'classical_samp': 100,
#   'alpha': 0.001,
#   'repetition': 3,
#   'error': 145.4054826644696},
#  {'classical_samp': 200,
#   'alpha': 0.001,
#   'repetition': 3,
#   'error': 145.3542644409559},
#  {'classical_samp': 500,
#   'alpha': 0.001,
#   'repetition': 3,
#   'error': 145.1976177644569},
#  {'classical_samp': 100,
#   'alpha': 0.01,
#   'repetition': 3,
#   'error': 145.38000074602942},
#  {'classical_samp': 200,
#   'alpha': 0.01,
#   'repetition': 3,
#   'error': 145.29686492835927},
#  {'classical_samp': 500,
#   'alpha': 0.01,
#   'repetition': 3,
#   'error': 145.2300226605167},
#  {'classical_samp': 100,
#   'alpha': 0.1,
#   'repetition': 3,
#   'error': 145.45016968277733},
#  {'classical_samp': 200,
#   'alpha': 0.1,
#   'repetition': 3,
#   'error': 145.2734930154435},
#  {'classical_samp': 500,
#   'alpha': 0.1,
#   'repetition': 3,
#   'error': 145.23418222011782},
#  {'classical_samp': 100,
#   'alpha': 1.0,
#   'repetition': 3,
#   'error': 145.37214720819125},
#  {'classical_samp': 200,
#   'alpha': 1.0,
#   'repetition': 3,
#   'error': 145.3298133359489},
#  {'classical_samp': 500,
#   'alpha': 1.0,
#   'repetition': 3,
#   'error': 145.28665489209945},
#  {'classical_samp': 100,
#   'alpha': 10.0,
#   'repetition': 3,
#   'error': 145.52636297572238},
#  {'classical_samp': 200,
#   'alpha': 10.0,
#   'repetition': 3,
#   'error': 145.5198706869135},
#  {'classical_samp': 500,
#   'alpha': 10.0,
#   'repetition': 3,
#   'error': 145.53552419482673},
#  {'classical_samp': 100,
#   'alpha': 100.0,
#   'repetition': 3,
#   'error': 145.78164036210686},
#  {'classical_samp': 200,
#   'alpha': 100.0,
#   'repetition': 3,
#   'error': 145.78164036210686},
#  {'classical_samp': 500,
#   'alpha': 100.0,
#   'repetition': 3,
#   'error': 145.78164036210686},
#  {'classical_samp': 100,
#   'alpha': 1000.0,
#   'repetition': 3,
#   'error': 145.78164036210686},
#  {'classical_samp': 200,
#   'alpha': 1000.0,
#   'repetition': 3,
#   'error': 145.78164036210686},
#  {'classical_samp': 500,
#   'alpha': 1000.0,
#   'repetition': 3,
#   'error': 145.78164036210686},
#  {'classical_samp': 100,
#   'alpha': 0.001,
#   'repetition': 4,
#   'error': 145.4105121150269},
#  {'classical_samp': 200,
#   'alpha': 0.001,
#   'repetition': 4,
#   'error': 145.29580376145492},
#  {'classical_samp': 500,
#   'alpha': 0.001,
#   'repetition': 4,
#   'error': 145.20878927895484},
#  {'classical_samp': 100,
#   'alpha': 0.01,
#   'repetition': 4,
#   'error': 145.39326501467366},
#  {'classical_samp': 200,
#   'alpha': 0.01,
#   'repetition': 4,
#   'error': 145.30908571619796},
#  {'classical_samp': 500,
#   'alpha': 0.01,
#   'repetition': 4,
#   'error': 145.2023758861018},
#  {'classical_samp': 100,
#   'alpha': 0.1,
#   'repetition': 4,
#   'error': 145.411001301553},
#  {'classical_samp': 200,
#   'alpha': 0.1,
#   'repetition': 4,
#   'error': 145.32270339845527},
#  {'classical_samp': 500,
#   'alpha': 0.1,
#   'repetition': 4,
#   'error': 145.20455457050684},
#  {'classical_samp': 100,
#   'alpha': 1.0,
#   'repetition': 4,
#   'error': 145.39375991864094},
#  {'classical_samp': 200,
#   'alpha': 1.0,
#   'repetition': 4,
#   'error': 145.34506744270263},
#  {'classical_samp': 500,
#   'alpha': 1.0,
#   'repetition': 4,
#   'error': 145.26259739058105},
#  {'classical_samp': 100,
#   'alpha': 10.0,
#   'repetition': 4,
#   'error': 145.53097575725786},
#  {'classical_samp': 200,
#   'alpha': 10.0,
#   'repetition': 4,
#   'error': 145.5142589520786},
#  {'classical_samp': 500,
#   'alpha': 10.0,
#   'repetition': 4,
#   'error': 145.50782971311565},
#  {'classical_samp': 100,
#   'alpha': 100.0,
#   'repetition': 4,
#   'error': 145.78164036210686},
#  {'classical_samp': 200,
#   'alpha': 100.0,
#   'repetition': 4,
#   'error': 145.78164036210686},
#  {'classical_samp': 500,
#   'alpha': 100.0,
#   'repetition': 4,
#   'error': 145.78164036210686},
#  {'classical_samp': 100,
#   'alpha': 1000.0,
#   'repetition': 4,
#   'error': 145.78164036210686},
#  {'classical_samp': 200,
#   'alpha': 1000.0,
#   'repetition': 4,
#   'error': 145.78164036210686},
#  {'classical_samp': 500,
#   'alpha': 1000.0,
#   'repetition': 4,
#   'error': 145.78164036210686},
#  {'classical_samp': 100,
#   'alpha': 0.001,
#   'repetition': 5,
#   'error': 145.4343234414403},
#  {'classical_samp': 200,
#   'alpha': 0.001,
#   'repetition': 5,
#   'error': 145.28041630295186},
#  {'classical_samp': 500,
#   'alpha': 0.001,
#   'repetition': 5,
#   'error': 145.20991027574001},
#  {'classical_samp': 100,
#   'alpha': 0.01,
#   'repetition': 5,
#   'error': 145.38235222712404},
#  {'classical_samp': 200,
#   'alpha': 0.01,
#   'repetition': 5,
#   'error': 145.3248430503131},
#  {'classical_samp': 500,
#   'alpha': 0.01,
#   'repetition': 5,
#   'error': 145.21366256231093},
#  {'classical_samp': 100,
#   'alpha': 0.1,
#   'repetition': 5,
#   'error': 145.41630475720484},
#  {'classical_samp': 200,
#   'alpha': 0.1,
#   'repetition': 5,
#   'error': 145.32779613851295},
#  {'classical_samp': 500,
#   'alpha': 0.1,
#   'repetition': 5,
#   'error': 145.20771575918351},
#  {'classical_samp': 100,
#   'alpha': 1.0,
#   'repetition': 5,
#   'error': 145.42918466325375},
#  {'classical_samp': 200,
#   'alpha': 1.0,
#   'repetition': 5,
#   'error': 145.34029081573166},
#  {'classical_samp': 500,
#   'alpha': 1.0,
#   'repetition': 5,
#   'error': 145.25601145037714},
#  {'classical_samp': 100,
#   'alpha': 10.0,
#   'repetition': 5,
#   'error': 145.48677566710694},
#  {'classical_samp': 200,
#   'alpha': 10.0,
#   'repetition': 5,
#   'error': 145.51328484683827},
#  {'classical_samp': 500,
#   'alpha': 10.0,
#   'repetition': 5,
#   'error': 145.50860422053665},
#  {'classical_samp': 100,
#   'alpha': 100.0,
#   'repetition': 5,
#   'error': 145.78164036210686},
#  {'classical_samp': 200,
#   'alpha': 100.0,
#   'repetition': 5,
#   'error': 145.78164036210686},
#  {'classical_samp': 500,
#   'alpha': 100.0,
#   'repetition': 5,
#   'error': 145.78164036210686},
#  {'classical_samp': 100,
#   'alpha': 1000.0,
#   'repetition': 5,
#   'error': 145.78164036210686},
#  {'classical_samp': 200,
#   'alpha': 1000.0,
#   'repetition': 5,
#   'error': 145.78164036210686},
#  {'classical_samp': 500,
#   'alpha': 1000.0,
#   'repetition': 5,
#   'error': 145.78164036210686},
#  {'classical_samp': 100,
#   'alpha': 0.001,
#   'repetition': 6,
#   'error': 145.47629456850873},
#  {'classical_samp': 200,
#   'alpha': 0.001,
#   'repetition': 6,
#   'error': 145.3285448052051},
#  {'classical_samp': 500,
#   'alpha': 0.001,
#   'repetition': 6,
#   'error': 145.17952004756484},
#  {'classical_samp': 100,
#   'alpha': 0.01,
#   'repetition': 6,
#   'error': 145.44023521146917},
#  {'classical_samp': 200,
#   'alpha': 0.01,
#   'repetition': 6,
#   'error': 145.33774065545006},
#  {'classical_samp': 500,
#   'alpha': 0.01,
#   'repetition': 6,
#   'error': 145.20642072773907},
#  {'classical_samp': 100,
#   'alpha': 0.1,
#   'repetition': 6,
#   'error': 145.44907714701307},
#  {'classical_samp': 200,
#   'alpha': 0.1,
#   'repetition': 6,
#   'error': 145.34327661188092},
#  {'classical_samp': 500,
#   'alpha': 0.1,
#   'repetition': 6,
#   'error': 145.21539237969617},
#  {'classical_samp': 100,
#   'alpha': 1.0,
#   'repetition': 6,
#   'error': 145.39765999817953},
#  {'classical_samp': 200,
#   'alpha': 1.0,
#   'repetition': 6,
#   'error': 145.37234725120814},
#  {'classical_samp': 500,
#   'alpha': 1.0,
#   'repetition': 6,
#   'error': 145.28084990785067},
#  {'classical_samp': 100,
#   'alpha': 10.0,
#   'repetition': 6,
#   'error': 145.54282476253422},
#  {'classical_samp': 200,
#   'alpha': 10.0,
#   'repetition': 6,
#   'error': 145.49969619261563},
#  {'classical_samp': 500,
#   'alpha': 10.0,
#   'repetition': 6,
#   'error': 145.5346628680809},
#  {'classical_samp': 100,
#   'alpha': 100.0,
#   'repetition': 6,
#   'error': 145.78164036210686},
#  {'classical_samp': 200,
#   'alpha': 100.0,
#   'repetition': 6,
#   'error': 145.78164036210686},
#  {'classical_samp': 500,
#   'alpha': 100.0,
#   'repetition': 6,
#   'error': 145.78164036210686},
#  {'classical_samp': 100,
#   'alpha': 1000.0,
#   'repetition': 6,
#   'error': 145.78164036210686},
#  {'classical_samp': 200,
#   'alpha': 1000.0,
#   'repetition': 6,
#   'error': 145.78164036210686},
#  {'classical_samp': 500,
#   'alpha': 1000.0,
#   'repetition': 6,
#   'error': 145.78164036210686},
#  {'classical_samp': 100,
#   'alpha': 0.001,
#   'repetition': 7,
#   'error': 145.43244821387984},
#  {'classical_samp': 200,
#   'alpha': 0.001,
#   'repetition': 7,
#   'error': 145.26273692875938},
#  {'classical_samp': 500,
#   'alpha': 0.001,
#   'repetition': 7,
#   'error': 145.19532240147072},
#  {'classical_samp': 100,
#   'alpha': 0.01,
#   'repetition': 7,
#   'error': 145.38237409574594},
#  {'classical_samp': 200,
#   'alpha': 0.01,
#   'repetition': 7,
#   'error': 145.33982529385966},
#  {'classical_samp': 500,
#   'alpha': 0.01,
#   'repetition': 7,
#   'error': 145.22095807036004},
#  {'classical_samp': 100,
#   'alpha': 0.1,
#   'repetition': 7,
#   'error': 145.4434839650343},
#  {'classical_samp': 200,
#   'alpha': 0.1,
#   'repetition': 7,
#   'error': 145.33629710665076},
#  {'classical_samp': 500,
#   'alpha': 0.1,
#   'repetition': 7,
#   'error': 145.21605113860005},
#  {'classical_samp': 100,
#   'alpha': 1.0,
#   'repetition': 7,
#   'error': 145.48984222560748},
#  {'classical_samp': 200,
#   'alpha': 1.0,
#   'repetition': 7,
#   'error': 145.35142711424115},
#  {'classical_samp': 500,
#   'alpha': 1.0,
#   'repetition': 7,
#   'error': 145.2627278938447},
#  {'classical_samp': 100,
#   'alpha': 10.0,
#   'repetition': 7,
#   'error': 145.53282397802903},
#  {'classical_samp': 200,
#   'alpha': 10.0,
#   'repetition': 7,
#   'error': 145.5221704598279},
#  {'classical_samp': 500,
#   'alpha': 10.0,
#   'repetition': 7,
#   'error': 145.50860416708264},
#  {'classical_samp': 100,
#   'alpha': 100.0,
#   'repetition': 7,
#   'error': 145.78164036210686},
#  {'classical_samp': 200,
#   'alpha': 100.0,
#   'repetition': 7,
#   'error': 145.78164036210686},
#  {'classical_samp': 500,
#   'alpha': 100.0,
#   'repetition': 7,
#   'error': 145.78164036210686},
#  {'classical_samp': 100,
#   'alpha': 1000.0,
#   'repetition': 7,
#   'error': 145.78164036210686},
#  {'classical_samp': 200,
#   'alpha': 1000.0,
#   'repetition': 7,
#   'error': 145.78164036210686},
#  {'classical_samp': 500,
#   'alpha': 1000.0,
#   'repetition': 7,
#   'error': 145.78164036210686},
#  {'classical_samp': 100,
#   'alpha': 0.001,
#   'repetition': 8,
#   'error': 145.40257580142924},
#  {'classical_samp': 200,
#   'alpha': 0.001,
#   'repetition': 8,
#   'error': 145.2937509456278},
#  {'classical_samp': 500,
#   'alpha': 0.001,
#   'repetition': 8,
#   'error': 145.20829720930996},
#  {'classical_samp': 100,
#   'alpha': 0.01,
#   'repetition': 8,
#   'error': 145.4105141612612},
#  {'classical_samp': 200,
#   'alpha': 0.01,
#   'repetition': 8,
#   'error': 145.3363103624862},
#  {'classical_samp': 500,
#   'alpha': 0.01,
#   'repetition': 8,
#   'error': 145.20197002155967},
#  {'classical_samp': 100,
#   'alpha': 0.1,
#   'repetition': 8,
#   'error': 145.40963205950618},
#  {'classical_samp': 200,
#   'alpha': 0.1,
#   'repetition': 8,
#   'error': 145.3378197620045},
#  {'classical_samp': 500,
#   'alpha': 0.1,
#   'repetition': 8,
#   'error': 145.21230408124077},
#  {'classical_samp': 100,
#   'alpha': 1.0,
#   'repetition': 8,
#   'error': 145.40835110343764},
#  {'classical_samp': 200,
#   'alpha': 1.0,
#   'repetition': 8,
#   'error': 145.3514787755143},
#  {'classical_samp': 500,
#   'alpha': 1.0,
#   'repetition': 8,
#   'error': 145.25494827701306},
#  {'classical_samp': 100,
#   'alpha': 10.0,
#   'repetition': 8,
#   'error': 145.5319088421931},
#  {'classical_samp': 200,
#   'alpha': 10.0,
#   'repetition': 8,
#   'error': 145.4832465934151},
#  {'classical_samp': 500,
#   'alpha': 10.0,
#   'repetition': 8,
#   'error': 145.5118214154544},
#  {'classical_samp': 100,
#   'alpha': 100.0,
#   'repetition': 8,
#   'error': 145.78164036210686},
#  {'classical_samp': 200,
#   'alpha': 100.0,
#   'repetition': 8,
#   'error': 145.78164036210686},
#  {'classical_samp': 500,
#   'alpha': 100.0,
#   'repetition': 8,
#   'error': 145.78164036210686},
#  {'classical_samp': 100,
#   'alpha': 1000.0,
#   'repetition': 8,
#   'error': 145.78164036210686},
#  {'classical_samp': 200,
#   'alpha': 1000.0,
#   'repetition': 8,
#   'error': 145.78164036210686},
#  {'classical_samp': 500,
#   'alpha': 1000.0,
#   'repetition': 8,
#   'error': 145.78164036210686},
#  {'classical_samp': 100,
#   'alpha': 0.001,
#   'repetition': 9,
#   'error': 145.42620872161356},
#  {'classical_samp': 200,
#   'alpha': 0.001,
#   'repetition': 9,
#   'error': 145.2739779252176},
#  {'classical_samp': 500,
#   'alpha': 0.001,
#   'repetition': 9,
#   'error': 145.20463774628445},
#  {'classical_samp': 100,
#   'alpha': 0.01,
#   'repetition': 9,
#   'error': 145.43592168965506},
#  {'classical_samp': 200,
#   'alpha': 0.01,
#   'repetition': 9,
#   'error': 145.3083887422762},
#  {'classical_samp': 500,
#   'alpha': 0.01,
#   'repetition': 9,
#   'error': 145.21204852939},
#  {'classical_samp': 100,
#   'alpha': 0.1,
#   'repetition': 9,
#   'error': 145.4202663490479},
#  {'classical_samp': 200,
#   'alpha': 0.1,
#   'repetition': 9,
#   'error': 145.31607454243087},
#  {'classical_samp': 500,
#   'alpha': 0.1,
#   'repetition': 9,
#   'error': 145.21969602102874},
#  {'classical_samp': 100,
#   'alpha': 1.0,
#   'repetition': 9,
#   'error': 145.42085634497445},
#  {'classical_samp': 200,
#   'alpha': 1.0,
#   'repetition': 9,
#   'error': 145.29907385394307},
#  {'classical_samp': 500,
#   'alpha': 1.0,
#   'repetition': 9,
#   'error': 145.2513635024167},
#  {'classical_samp': 100,
#   'alpha': 10.0,
#   'repetition': 9,
#   'error': 145.58037647073004},
#  {'classical_samp': 200,
#   'alpha': 10.0,
#   'repetition': 9,
#   'error': 145.4975568452607},
#  {'classical_samp': 500,
#   'alpha': 10.0,
#   'repetition': 9,
#   'error': 145.51471440196306},
#  {'classical_samp': 100,
#   'alpha': 100.0,
#   'repetition': 9,
#   'error': 145.78164036210686},
#  {'classical_samp': 200,
#   'alpha': 100.0,
#   'repetition': 9,
#   'error': 145.78164036210686},
#  {'classical_samp': 500,
#   'alpha': 100.0,
#   'repetition': 9,
#   'error': 145.78164036210686},
#  {'classical_samp': 100,
#   'alpha': 1000.0,
#   'repetition': 9,
#   'error': 145.78164036210686},
#  {'classical_samp': 200,
#   'alpha': 1000.0,
#   'repetition': 9,
#   'error': 145.78164036210686},
#  {'classical_samp': 500,
#   'alpha': 1000.0,
#   'repetition': 9,
#   'error': 145.78164036210686}]

# %%
save_path = os.path.join('./result/tree_part1/Classical/')

classical_param_df = pd.DataFrame(params)
classical_param_df.to_csv(os.path.join(save_path, "Classical_Param_" + "_".join(str.split(time.ctime().replace(":", "_"))) + ".csv"))

# %%
classical_param_mean_df = classical_param_df.groupby(
    ['alpha', 'classical_samp'], as_index=False).mean().drop('repetition', axis=1) 

classical_param_min_df = classical_param_mean_df.groupby('classical_samp', as_index=False).min('error').rename(
    columns={'error' : 'mean_err'})

merged_df = pd.merge(classical_param_df, classical_param_min_df, on=['alpha', 'classical_samp'], how='left')
plotting_data = merged_df.loc[merged_df['mean_err'].notnull()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27955/2112247098.py in <module>
# ----> 1 classical_param_mean_df = classical_param_df.groupby(
#       2     ['alpha', 'classical_samp'], as_index=False).mean().drop('repetition', axis=1)
#       3
#       4 classical_param_min_df = classical_param_mean_df.groupby('classical_samp', as_index=False).min('error').rename(
#       5     columns={'error' : 'mean_err'})
#
# NameError: name 'classical_param_df' is not defined

# %%
classical_fig = sns.relplot(data = plotting_data, x = 'classical_samp', y = 'error', kind= 'line')
classical_fig.set(yscale='log')
# plt.plot(x = classical_param_df['classical_samp'].unique(), y = min_classical_param_df_aug['mean_err'])
plt.title('Classical: Num_Sample VS Error')
plt.xticks(classical_param_df['classical_samp'].unique())
plt.show()

# %%
min_classical_param_df_aug
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5324/4116583236.py in <module>
# ----> 1 min_classical_param_df_aug
#
# NameError: name 'min_classical_param_df_aug' is not defined

# %%
## Check if this function is applicable to regular compress sensing
classical_img = Image.open("image/tree_part1.jpg")
classical_img = ImageOps.grayscale(classical_img)
classical_arr = np.asarray(classical_img)
cn, cm = classical_arr.shape
print(cn, cm)
classical_samp_list = [100, 200, 500] #np.floor (cn * cm * 0.20).astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27955/2379376067.py in <module>
#       1 ## Check if this function is applicable to regular compress sensing
# ----> 2 classical_img = Image.open("image/tree_part1.jpg")
#       3 classical_img = ImageOps.grayscale(classical_img)
#       4 classical_arr = np.asarray(classical_img)
#       5 cn, cm = classical_arr.shape
#
# NameError: name 'Image' is not defined

# %%
alpha_list = np.logspace(-3, 3, 7)

for classical_samp in classical_samp_list:
    print('sample at: ', classical_samp)
    for alp in alpha_list:
        # Generate random indexes and find corresponding y value for each index
        rand_index = np.random.permutation(cn * cm)[:classical_samp]
        classical_Y = classical_arr.flatten()[rand_index]
        classical_Y = classical_Y.reshape(classical_samp, 1)

        # Generate C matrix
        C = np.eye(cn * cm)[rand_index, :]# * np.sqrt(cn * cm)
        C3D = C.reshape(classical_samp, cn, cm)
        theta, classical_reform, s = compress(C3D, classical_Y, alp)

        plt.imshow(classical_reform)
        plt.title("Recon.(alp: " + str(alp) + ")")
        plt.show()
# Out:
# sample at:  100
# /home/bans/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43.2945391888953, tolerance: 30.683804
#   model = cd_fast.enet_coordinate_descent(
# sample at:  200
# sample at:  500

# %%
rand_index = np.random.permutation(cn * cm)[:500]
classical_Y = classical_arr.flatten()[rand_index]
classical_Y = classical_Y.reshape(500, 1)

# Generate C matrix
C = np.eye(cn * cm)[rand_index, :] * np.sqrt(cn * cm)
C3D = C.reshape(500, cn, cm)
theta, classical_reform, s = compress(C3D, classical_Y, 0.03)

# %%
plt.imshow(classical_reform)
plt.title("Recon.(alp: 0.003)")
plt.show()

# %%
classical_arr
# Out:
# array([[213, 210, 216, 216, 206, 208, 216, 214, 193, 216, 233, 178, 196,
#         141, 117, 134, 176, 112, 167, 160, 186, 213, 190, 177, 203, 182,
#         195, 202, 185, 180],
#        [220, 206, 204, 208, 208, 214, 215, 204, 228, 227, 203, 159, 174,
#         142,  93,  95, 115, 122, 144, 163, 181, 158, 205, 163, 165, 193,
#         201, 190, 187, 179],
#        [207, 195, 196, 203, 207, 214, 216, 204, 199, 184, 145, 131, 164,
#         171, 115, 105,  70, 102, 101, 117, 125,  86, 147, 109, 143, 204,
#         196, 176, 195, 194],
#        [190, 187, 197, 202, 195, 195, 197, 189, 192, 160, 111,  75, 106,
#         124, 100, 101, 108,  96,  96,  93,  93, 100,  99, 117, 146, 189,
#         174, 170, 192, 203],
#        [198, 194, 200, 202, 190, 180, 169, 152, 183, 172, 167, 112, 129,
#         108,  94,  87, 131, 104,  95, 106, 100, 141, 101, 168, 148, 165,
#         169, 191, 177, 191],
#        [214, 202, 202, 204, 195, 182, 160, 132, 101, 116, 157, 112, 124,
#          88,  79,  67,  91, 105,  71, 105, 101, 119, 101, 162, 147, 162,
#         192, 225, 169, 180],
#        [213, 207, 209, 202, 176, 155, 138, 119, 107, 109, 124,  82,  88,
#          88,  95,  95,  63, 105,  68,  83, 104,  97,  93, 121, 131, 160,
#         187, 210, 148, 174],
#        [203, 212, 219, 193, 138, 102,  95,  93,  77,  84,  97,  90,  95,
#         115,  96,  85,  59,  89,  75,  46, 103, 101,  83,  91, 104, 142,
#         145, 155, 115, 162],
#        [201, 208, 217, 196, 118,  92,  76, 104,  64,  66,  71,  72,  82,
#         126,  93, 102,  75,  78,  88,  94,  84,  72,  80, 100,  97,  88,
#          61, 109, 138, 207],
#        [204, 206, 203, 159, 137, 124,  89,  65,  91, 100,  77,  87,  73,
#          85,  93,  92,  65,  75,  86,  85,  69,  55,  59,  72,  77,  77,
#          80,  58,  81,  93],
#        [180, 172, 188, 168, 178, 125,  80,  73,  93, 111,  91, 138, 107,
#          72, 106,  88,  78,  94, 101,  88,  66,  53,  51,  54,  73, 101,
#          90,  82,  62, 100],
#        [150, 144, 154, 149, 158, 102,  63,  92, 106, 107, 120, 193, 154,
#          75,  79,  52,  87, 102, 103,  84,  67,  66,  66,  61,  73,  96,
#          69,  82,  49,  96],
#        [150, 157, 127,  96,  95, 109,  86, 111, 111,  77, 119, 181, 156,
#          84,  57,  48,  79,  88,  84,  66,  60,  71,  76,  69,  79,  78,
#          87,  80,  89,  79],
#        [109, 121, 101,  84,  66,  91,  87, 129, 123,  73, 114, 124, 114,
#          83,  54,  65,  84,  89,  83,  66,  59,  67,  69,  63,  42,  57,
#          72,  91,  78,  70],
#        [ 55,  58,  76,  78,  66,  65,  65,  97, 116, 104, 135,  87,  77,
#          71,  48,  48,  75,  85,  88,  77,  64,  60,  59,  58,  65,  92,
#          80, 110,  61,  84],
#        [ 75,  71,  89,  61,  82, 101,  91,  51,  39,  88, 131,  72,  74,
#          87,  77,  57,  37,  56,  75,  75,  63,  53,  55,  60,  79,  86,
#          85,  69,  71,  84],
#        [146, 114, 111, 100, 126,  97, 115,  81, 103,  61,  66,  51,  80,
#         120,  79,  61,  55,  75,  66,  72,  50,  66,  62,  55,  81,  37,
#          94,  97,  77,  84],
#        [131,  94, 145, 103, 153,  82,  72, 133, 181, 127, 114,  56,  74,
#         126,  81,  30,  79,  65,  53,  42,  77,  49,  72,  48,  59,  84,
#          66,  59,  76,  66],
#        [128, 107, 183, 128, 106,  82,  91, 101, 130, 157,  51,  65,  90,
#          63,  64, 127, 102,  61,  85, 100, 100,  57,  91,  52,  59, 101,
#          79,  61,  80,  88],
#        [119, 138, 155, 154,  86, 128, 163, 112, 124, 164, 121,  92,  95,
#         153,  51, 191, 106,  76, 133, 156,  51,  84, 114, 100,  50,  36,
#          80,  72,  63, 104],
#        [198, 198, 162, 178, 146, 143, 141, 157, 118, 121, 156, 135,  76,
#         107,  48, 139,  79, 140, 212, 170,  64, 161, 132, 131, 120,  74,
#         103, 122, 115, 122],
#        [205, 150, 189, 183, 190, 186, 189, 237, 155, 149, 112, 126, 126,
#          39,  74, 111,  74, 191, 220,  90, 101, 192, 120, 118, 112, 110,
#          72, 138, 195, 164],
#        [211, 159, 219, 197, 191, 199, 209, 209, 210, 191, 142,  66, 127,
#         111,  28,  60, 163, 206, 165,  62, 154, 206, 176, 186, 192, 207,
#         156, 189, 220, 184],
#        [193, 212, 189, 204, 224, 207, 189, 196, 190, 207, 197, 179, 125,
#          88,  11,  94, 139, 100,  65, 100, 189, 187, 185, 180, 193, 188,
#         207, 198, 172, 188],
#        [203, 204, 205, 205, 204, 200, 197, 195, 192, 201, 191, 187, 211,
#         172,  36,  74,  81,  42, 149, 207, 200, 189, 203, 190, 188, 188,
#         188, 188, 189, 190],
#        [200, 201, 201, 202, 201, 199, 197, 196, 187, 188, 184, 181, 186,
#         177,  77,  55,  71, 126, 197, 198, 190, 193, 195, 190, 194, 194,
#         194, 194, 195, 196],
#        [201, 201, 201, 201, 201, 201, 201, 201, 205, 202, 202, 200, 188,
#         207, 155,  69,  49, 183, 208, 182, 190, 199, 188, 199, 200, 200,
#         201, 201, 202, 203],
#        [201, 200, 199, 199, 199, 199, 200, 201, 197, 203, 196, 196, 185,
#         209, 190,  82,  44, 183, 184, 183, 204, 205, 185, 204, 202, 203,
#         204, 205, 206, 206],
#        [200, 199, 198, 196, 196, 196, 196, 196, 186, 201, 188, 188, 192,
#         198, 192, 105,  48, 169, 186, 201, 206, 206, 192, 197, 200, 201,
#         202, 204, 205, 205],
#        [206, 206, 205, 204, 203, 202, 202, 201, 200, 211, 205, 202, 214,
#         208, 203, 137,  26, 149, 209, 207, 193, 205, 205, 195, 197, 199,
#         201, 203, 203, 203]], dtype=uint8)

# %%
classical_reform * np.sqrt(cn * cm)
# Out:
# array([[ 8.69110423e+01,  7.56844699e+01,  6.37045544e+01,
#          8.12298488e+01,  7.18315207e+01,  7.42107774e+01,
#          8.16488753e+01,  6.56785121e+01,  2.10598388e+01,
#         -1.13993376e+01,  9.81581999e+01,  1.52461291e+01,
#          6.17700224e+01,  4.55176198e+01,  3.56891497e+01,
#          2.67775938e+01,  4.12661804e+01, -2.21009340e+01,
#          3.29948327e+01,  2.62147419e+01,  6.74553218e+01,
#          3.74659975e+01,  5.56976553e+01,  4.59586727e+01,
#          6.88889239e+01,  4.79429342e+01,  3.83755647e+01,
#          6.76489536e+01,  5.16169616e+01,  3.28365203e+01],
#        [ 8.51221009e+01,  7.24172545e+01,  7.02448506e+01,
#          7.39120172e+01,  7.71540870e+01,  8.01616831e+01,
#          8.72564477e+01,  5.98453526e+01,  2.53837355e+01,
#          4.09525738e+01,  4.29443973e+01,  2.46929012e+01,
