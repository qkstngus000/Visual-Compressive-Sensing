# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

from src.data.load_dataset import load_mnist, load_kmnist
from src.models.networks import V1_mnist_RFNet, classical_RFNet
from src.models.utils import train, test

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ### MNIST

# %%
train_loader, val_loader, test_loader = load_mnist(2048, 0.1)

# %%
h, s, f, c = 200, 5.34, 2, None
model = V1_mnist_RFNet(h, s, f, c).to(device)

# hyperparams
lr = 1E-2
optimizer = optim.SGD(model.parameters(), lr=lr)

# train
epochs = 20
log_interval = 5
for epoch in range(1, epochs + 1):
    train(log_interval, device, model, train_loader, optimizer, epoch, verbose=True)
    val_accuracy = test(model, device, val_loader)
# calculate and print test accuracy
test_accuracy = test(model, device, test_loader)
# Out:
# Train_epoch: 1 [0/6000 (0%)]	Loss: 68.616440
#
# Test set: Average loss: 1331.860718. Accuracy: 22403/54000 (41.49%)
#
# Train_epoch: 2 [0/6000 (0%)]	Loss: 1340.740356
#
# Test set: Average loss: 835.472961. Accuracy: 15019/54000 (27.81%)
#
# Train_epoch: 3 [0/6000 (0%)]	Loss: 841.686646
#
# Test set: Average loss: 676.884033. Accuracy: 28046/54000 (51.94%)
#
# Train_epoch: 4 [0/6000 (0%)]	Loss: 744.150085
#
# Test set: Average loss: 276.345001. Accuracy: 33985/54000 (62.94%)
#
# Train_epoch: 5 [0/6000 (0%)]	Loss: 244.411102
#
# Test set: Average loss: 216.392761. Accuracy: 34525/54000 (63.94%)
#
# Train_epoch: 6 [0/6000 (0%)]	Loss: 214.295334
#
# Test set: Average loss: 69.657921. Accuracy: 35763/54000 (66.23%)
#
# Train_epoch: 7 [0/6000 (0%)]	Loss: 64.202675
#
# Test set: Average loss: 141.212891. Accuracy: 38513/54000 (71.32%)
#
# Train_epoch: 8 [0/6000 (0%)]	Loss: 143.372559
#
# Test set: Average loss: 101.331673. Accuracy: 36952/54000 (68.43%)
#
# Train_epoch: 9 [0/6000 (0%)]	Loss: 102.328751
#
# Test set: Average loss: 44.618378. Accuracy: 41895/54000 (77.58%)
#
# Train_epoch: 10 [0/6000 (0%)]	Loss: 42.915291
#
# Test set: Average loss: 43.193829. Accuracy: 42321/54000 (78.37%)
#
# Train_epoch: 11 [0/6000 (0%)]	Loss: 35.654060
#
# Test set: Average loss: 43.135883. Accuracy: 42320/54000 (78.37%)
#
# Train_epoch: 12 [0/6000 (0%)]	Loss: 39.595127
#
# Test set: Average loss: 44.988132. Accuracy: 42157/54000 (78.07%)
#
# Train_epoch: 13 [0/6000 (0%)]	Loss: 39.559135
#
# Test set: Average loss: 82.002724. Accuracy: 41946/54000 (77.68%)
#
# Train_epoch: 14 [0/6000 (0%)]	Loss: 77.509300
#
# Test set: Average loss: 24.351297. Accuracy: 45826/54000 (84.86%)
#
# Train_epoch: 15 [0/6000 (0%)]	Loss: 21.153717
#
# Test set: Average loss: 79.862709. Accuracy: 42554/54000 (78.80%)
#
# Train_epoch: 16 [0/6000 (0%)]	Loss: 73.330795
#
# Test set: Average loss: 19.057032. Accuracy: 47064/54000 (87.16%)
#
# Train_epoch: 17 [0/6000 (0%)]	Loss: 16.185759
#
# Test set: Average loss: 17.587259. Accuracy: 47430/54000 (87.83%)
#
# Train_epoch: 18 [0/6000 (0%)]	Loss: 15.245736
#
# Test set: Average loss: 20.585855. Accuracy: 46342/54000 (85.82%)
#
# Train_epoch: 19 [0/6000 (0%)]	Loss: 17.503489
#
# Test set: Average loss: 67.935478. Accuracy: 42023/54000 (77.82%)
#
# Train_epoch: 20 [0/6000 (0%)]	Loss: 65.216988
#
# Test set: Average loss: 48.103703. Accuracy: 40985/54000 (75.90%)
#
#
# Test set: Average loss: 45.898945. Accuracy: 7703/10000 (77.03%)

# %%
## classical network
inp_size, hidden_size = (1, 28, 28), 200
model = classical_RFNet(inp_size, hidden_size, seed=10).to(device)

# optimizer
lr = 1E-2
optimizer = optim.SGD(model.parameters(), lr=lr)

# train
epochs = 10
log_interval = 5
for epoch in range(1, epochs + 1):
    train(log_interval, device, model, train_loader, optimizer, epoch, verbose=True)
    val_accuracy = test(model, device, val_loader)
# calculate and print test accuracy
test_accuracy = test(model, device, test_loader)
# Out:
# Train_epoch: 1 [0/6000 (0%)]	Loss: 2.326261
# Train_epoch: 1 [4400/6000 (83%)]	Loss: 2.315307
#
# Test set: Average loss: 2.310560. Accuracy: 5062/54000 (9.37%)
#
# Train_epoch: 2 [0/6000 (0%)]	Loss: 2.311584
# Train_epoch: 2 [4400/6000 (83%)]	Loss: 2.293266
#
# Test set: Average loss: 2.289449. Accuracy: 5905/54000 (10.94%)
#
# Train_epoch: 3 [0/6000 (0%)]	Loss: 2.295178
# Train_epoch: 3 [4400/6000 (83%)]	Loss: 2.278391
#
# Test set: Average loss: 2.269177. Accuracy: 7073/54000 (13.10%)
#
# Train_epoch: 4 [0/6000 (0%)]	Loss: 2.270342
# Train_epoch: 4 [4400/6000 (83%)]	Loss: 2.252376
#
# Test set: Average loss: 2.249593. Accuracy: 8584/54000 (15.90%)
#
# Train_epoch: 5 [0/6000 (0%)]	Loss: 2.242956
# Train_epoch: 5 [4400/6000 (83%)]	Loss: 2.230304
#
# Test set: Average loss: 2.230593. Accuracy: 10419/54000 (19.29%)
#
# Train_epoch: 6 [0/6000 (0%)]	Loss: 2.227309
# Train_epoch: 6 [4400/6000 (83%)]	Loss: 2.212623
#
# Test set: Average loss: 2.212053. Accuracy: 12454/54000 (23.06%)
#
# Train_epoch: 7 [0/6000 (0%)]	Loss: 2.207749
# Train_epoch: 7 [4400/6000 (83%)]	Loss: 2.186334
#
# Test set: Average loss: 2.193958. Accuracy: 14714/54000 (27.25%)
#
# Train_epoch: 8 [0/6000 (0%)]	Loss: 2.194457
# Train_epoch: 8 [4400/6000 (83%)]	Loss: 2.184672
#
# Test set: Average loss: 2.176253. Accuracy: 16918/54000 (31.33%)
#
# Train_epoch: 9 [0/6000 (0%)]	Loss: 2.180905
# Train_epoch: 9 [4400/6000 (83%)]	Loss: 2.151765
#
# Test set: Average loss: 2.158844. Accuracy: 19036/54000 (35.25%)
#
# Train_epoch: 10 [0/6000 (0%)]	Loss: 2.163568
# Train_epoch: 10 [4400/6000 (83%)]	Loss: 2.134697
#
# Test set: Average loss: 2.141750. Accuracy: 20939/54000 (38.78%)
#
#
# Test set: Average loss: 2.135391. Accuracy: 3886/10000 (38.86%)

# %% [markdown]
# ### KMNIST

# %%
train_loader, val_loader, test_loader = load_kmnist(128, 0.9)

# %%
h, s, f, c = 100, 5, 2, None
model = V1_mnist_RFNet(h, s, f, c).to(device)

# hyperparams
lr = 1E-4
optimizer = optim.Adam(model.parameters(), lr=lr)

# train
epochs = 5
log_interval = 5
for epoch in range(1, epochs + 1):
    train(log_interval, device, model, train_loader, optimizer, epoch, verbose=True)
    val_accuracy = test(model, device, val_loader)
# calculate and print test accuracy
test_accuracy = test(model, device, test_loader)

# %%
## classical network
inp_size, hidden_size = (1, 28, 28), 100
model = classical_RFNet(inp_size, hidden_size, seed=10).to(device)

# optimizer
lr = 1E-4
optimizer = optim.Adam(model.parameters(), lr=lr)

# train
epochs = 5
log_interval = 5
for epoch in range(1, epochs + 1):
    train(log_interval, device, model, train_loader, optimizer, epoch, verbose=True)
    val_accuracy = test(model, device, val_loader)
# calculate and print test accuracy
test_accuracy = test(model, device, test_loader)
