# %% [markdown]
# Initialize shallow feedforward fully-connected network with V1 type weights and classify __subset of kmnist__ dataset using __Gradient descent__. The partial dataset will have 5 samples/class.

# %%
import numpy as np
import numpy.linalg as la
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from estimator import classical_weights, V1_inspired_weights
from data_fns import load_kmnist
from sklearn.model_selection import train_test_split
import pickle

# %%
torch.cuda.set_device(1)
train, train_labels, test, test_labels = load_kmnist('./data/kmnist/')

num_train = 50
train_few, _, train_labels_few, _ = train_test_split(train, train_labels, train_size=num_train, stratify=train_labels, 
                                          random_state=42)


X_train = torch.from_numpy(train_few).float().to('cuda')
X_test = torch.from_numpy(test).float().to('cuda')
y_train = torch.from_numpy(train_labels_few).long().to('cuda')
y_test = torch.from_numpy(test_labels).long().to('cuda')
n, d = X_train.shape

# %%
class V1_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(V1_inspired_weights(hidden_size, d, t=5, l=2, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class He_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class RF_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(classical_weights(hidden_size, d, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)

# %%
def predict(model, X):
    return model(X).data.max(1)[1]

def error(model, X, y):
    y_pred = predict(model, X)
    accuracy = 1.0 * torch.sum(y_pred == y) / len(y)
    return 1 - accuracy

# %%
n_trials, n_epochs = 10, 7001
models = {'V1': V1_net, 'He': He_net}
h_list = [50, 100, 400, 1000]
lr_list = [1e-3, 1e-2, 1e-1, 1e0]

train_err = {m: {h: {lr: np.zeros((n_trials, n_epochs)) for lr in lr_list} for h in h_list} for m in models.keys()}
test_err = {m: {h: {lr: np.zeros((n_trials, n_epochs)) for lr in lr_list} for h in h_list} for m in models.keys()}
loss_list = {m: {h: {lr: np.zeros((n_trials, n_epochs)) for lr in lr_list} for h in h_list} for m in models.keys()}

# %%
scale = 2/d
t, l = 5, 2
loss_func = nn.CrossEntropyLoss()

for h in h_list:
    for lr in lr_list:
        for m, network in models.items():
            for i in range(n_trials):
                model = network(h, scale).to('cuda')
                optim = torch.optim.SGD(model.parameters(), lr=lr)
                for j in range(n_epochs):
                    optim.zero_grad()
                    loss = loss_func(model(X_train), y_train)
                    loss.backward()
                    optim.step()

                    train_err[m][h][lr][i, j] = error(model, X_train, y_train)
                    test_err[m][h][lr][i, j] = error(model, X_test, y_test)
                    loss_list[m][h][lr][i, j] = loss.data

                    if (j % 1000 == 0):
                        print('Trial %d, Epoch: %d, %s model, h=%d, lr=%0.5f, Loss=%0.5f, test err=%0.3f' % (i,j, m, h, lr, loss.data, 
                                                                                                  test_err[m][h][lr][i, j]))
results = {'test_err': test_err, 'train_err': train_err, 'loss': loss_list}
with open('results/initialize_kmnist/fewshot_data/clf_t=%0.2f_l=%0.2f.pickle' % (t, l), 'wb') as handle:
    pickle.dump(results, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.51591, test err=0.915
# Trial 0, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.24435, test err=0.719
# Trial 0, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.75116, test err=0.661
# Trial 0, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.46686, test err=0.645
# Trial 0, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.30466, test err=0.638
# Trial 0, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.21114, test err=0.635
# Trial 0, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.15398, test err=0.636
# Trial 0, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.11678, test err=0.633
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.52736, test err=0.940
# Trial 1, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.26925, test err=0.717
# Trial 1, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.72539, test err=0.665
# Trial 1, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.43846, test err=0.649
# Trial 1, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.28305, test err=0.647
# Trial 1, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.19367, test err=0.646
# Trial 1, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.13914, test err=0.644
# Trial 1, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.10456, test err=0.643
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.43616, test err=0.880
# Trial 2, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.48245, test err=0.738
# Trial 2, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.89655, test err=0.681
# Trial 2, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.54091, test err=0.656
# Trial 2, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.34113, test err=0.643
# Trial 2, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.22711, test err=0.641
# Trial 2, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.15949, test err=0.638
# Trial 2, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.11785, test err=0.638
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.49851, test err=0.910
# Trial 3, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.44972, test err=0.754
# Trial 3, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.89170, test err=0.675
# Trial 3, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.56972, test err=0.649
# Trial 3, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.38324, test err=0.638
# Trial 3, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.26884, test err=0.638
# Trial 3, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.19596, test err=0.636
# Trial 3, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.14773, test err=0.635
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.78045, test err=0.904
# Trial 4, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.21196, test err=0.678
# Trial 4, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.71184, test err=0.646
# Trial 4, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.44092, test err=0.633
# Trial 4, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.28688, test err=0.629
# Trial 4, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.19646, test err=0.627
# Trial 4, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.14204, test err=0.623
# Trial 4, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.10780, test err=0.622
# Trial 5, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.54469, test err=0.882
# Trial 5, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.17394, test err=0.715
# Trial 5, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.70181, test err=0.669
# Trial 5, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.43849, test err=0.654
# Trial 5, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.28588, test err=0.648
# Trial 5, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.19570, test err=0.643
# Trial 5, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.14102, test err=0.641
# Trial 5, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.10618, test err=0.639
# Trial 6, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.55172, test err=0.853
# Trial 6, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.33026, test err=0.714
# Trial 6, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.78669, test err=0.674
# Trial 6, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.47850, test err=0.657
# Trial 6, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.30915, test err=0.649
# Trial 6, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.21062, test err=0.644
# Trial 6, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.15054, test err=0.642
# Trial 6, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.11244, test err=0.640
# Trial 7, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.72827, test err=0.893
# Trial 7, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.17983, test err=0.675
# Trial 7, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.69750, test err=0.644
# Trial 7, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.44594, test err=0.630
# Trial 7, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.30188, test err=0.626
# Trial 7, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.21302, test err=0.624
# Trial 7, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.15517, test err=0.625
# Trial 7, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.11680, test err=0.623
# Trial 8, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.68158, test err=0.934
# Trial 8, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.04983, test err=0.700
# Trial 8, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.62418, test err=0.673
# Trial 8, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.39965, test err=0.664
# Trial 8, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.26856, test err=0.656
# Trial 8, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.18831, test err=0.653
# Trial 8, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.13729, test err=0.650
# Trial 8, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.10401, test err=0.648
# Trial 9, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.57763, test err=0.860
# Trial 9, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.37299, test err=0.704
# Trial 9, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.82022, test err=0.658
# Trial 9, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.50777, test err=0.645
# Trial 9, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.33144, test err=0.643
# Trial 9, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.22637, test err=0.642
# Trial 9, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.16123, test err=0.641
# Trial 9, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.11975, test err=0.640
# Trial 0, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.32314, test err=0.902
# Trial 0, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.89236, test err=0.771
# Trial 0, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.37344, test err=0.702
# Trial 0, Epoch: 3000, He model, h=50, lr=0.00100, Loss=0.88604, test err=0.667
# Trial 0, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.54644, test err=0.647
# Trial 0, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.34646, test err=0.643
# Trial 0, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.23175, test err=0.638
# Trial 0, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.16390, test err=0.634
# Trial 1, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.31408, test err=0.888
# Trial 1, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.84346, test err=0.744
# Trial 1, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.30897, test err=0.678
# Trial 1, Epoch: 3000, He model, h=50, lr=0.00100, Loss=0.82269, test err=0.638
# Trial 1, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.50328, test err=0.616
# Trial 1, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.32325, test err=0.613
# Trial 1, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.22076, test err=0.617
# Trial 1, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.15873, test err=0.618
# Trial 2, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.36784, test err=0.929
# Trial 2, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.90886, test err=0.790
# Trial 2, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.35808, test err=0.699
# Trial 2, Epoch: 3000, He model, h=50, lr=0.00100, Loss=0.85041, test err=0.678
# Trial 2, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.51886, test err=0.668
# Trial 2, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.33015, test err=0.661
# Trial 2, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.22134, test err=0.655
# Trial 2, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.15591, test err=0.654
# Trial 3, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.32893, test err=0.890
# Trial 3, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.83451, test err=0.775
# Trial 3, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.27776, test err=0.702
# Trial 3, Epoch: 3000, He model, h=50, lr=0.00100, Loss=0.79478, test err=0.656
# Trial 3, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.48382, test err=0.648
# Trial 3, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.31085, test err=0.645
# Trial 3, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.21173, test err=0.645
# Trial 3, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.15126, test err=0.646
# Trial 4, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.30813, test err=0.896
# Trial 4, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.74865, test err=0.748
# Trial 4, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.15543, test err=0.673
# Trial 4, Epoch: 3000, He model, h=50, lr=0.00100, Loss=0.70501, test err=0.646
# Trial 4, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.44335, test err=0.633
# Trial 4, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.29393, test err=0.629
# Trial 4, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.20405, test err=0.628
# Trial 4, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.14752, test err=0.628
# Trial 5, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.34280, test err=0.912
# Trial 5, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.83723, test err=0.790
# Trial 5, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.25009, test err=0.690
# Trial 5, Epoch: 3000, He model, h=50, lr=0.00100, Loss=0.76377, test err=0.643
# Trial 5, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.46708, test err=0.635
# Trial 5, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.30230, test err=0.638
# Trial 5, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.20741, test err=0.640
# Trial 5, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.14976, test err=0.639
# Trial 6, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.33683, test err=0.925
# Trial 6, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.90052, test err=0.759
# Trial 6, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.37837, test err=0.696
# Trial 6, Epoch: 3000, He model, h=50, lr=0.00100, Loss=0.89292, test err=0.666
# Trial 6, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.55644, test err=0.647
# Trial 6, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.35735, test err=0.642
# Trial 6, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.23973, test err=0.640
# Trial 6, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.16764, test err=0.640
# Trial 7, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.32239, test err=0.908
# Trial 7, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.84233, test err=0.813
# Trial 7, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.28234, test err=0.704
# Trial 7, Epoch: 3000, He model, h=50, lr=0.00100, Loss=0.79277, test err=0.657
# Trial 7, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.48759, test err=0.645
# Trial 7, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.31730, test err=0.645
# Trial 7, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.21798, test err=0.648
# Trial 7, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.15661, test err=0.648
# Trial 8, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.27564, test err=0.880
# Trial 8, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.80835, test err=0.763
# Trial 8, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.25887, test err=0.692
# Trial 8, Epoch: 3000, He model, h=50, lr=0.00100, Loss=0.81258, test err=0.658
# Trial 8, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.52172, test err=0.636
# Trial 8, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.34434, test err=0.632
# Trial 8, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.23677, test err=0.632
# Trial 8, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.16993, test err=0.632
# Trial 9, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.31416, test err=0.950
# Trial 9, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.73562, test err=0.780
# Trial 9, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.15592, test err=0.718
# Trial 9, Epoch: 3000, He model, h=50, lr=0.00100, Loss=0.72710, test err=0.676
# Trial 9, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.45646, test err=0.660
# Trial 9, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.29551, test err=0.654
# Trial 9, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.20194, test err=0.653
# Trial 9, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.14518, test err=0.653
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.35595, test err=0.837
# Trial 0, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.06019, test err=0.621
# Trial 0, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.01936, test err=0.618
# Trial 0, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.01069, test err=0.616
# Trial 0, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00719, test err=0.614
# Trial 0, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.00535, test err=0.614
# Trial 0, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00422, test err=0.614
# Trial 0, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00347, test err=0.614
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.19221, test err=0.880
# Trial 1, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.06328, test err=0.640
# Trial 1, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.01946, test err=0.635
# Trial 1, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.01068, test err=0.633
# Trial 1, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00717, test err=0.631
# Trial 1, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.00532, test err=0.630
# Trial 1, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00420, test err=0.629
# Trial 1, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00345, test err=0.629
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.62321, test err=0.891
# Trial 2, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.05732, test err=0.656
# Trial 2, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.01826, test err=0.650
# Trial 2, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.01017, test err=0.648
# Trial 2, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00687, test err=0.646
# Trial 2, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.00513, test err=0.646
# Trial 2, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00406, test err=0.646
# Trial 2, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00334, test err=0.645
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.63852, test err=0.878
# Trial 3, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.06146, test err=0.637
# Trial 3, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.01938, test err=0.630
# Trial 3, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.01069, test err=0.629
# Trial 3, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00720, test err=0.627
# Trial 3, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.00536, test err=0.626
# Trial 3, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00424, test err=0.625
# Trial 3, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00349, test err=0.625
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.48014, test err=0.863
# Trial 4, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.06469, test err=0.629
# Trial 4, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.01934, test err=0.628
# Trial 4, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.01054, test err=0.626
# Trial 4, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00706, test err=0.625
# Trial 4, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.00524, test err=0.624
# Trial 4, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00413, test err=0.624
# Trial 4, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00339, test err=0.624
# Trial 5, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.82717, test err=0.913
# Trial 5, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.06885, test err=0.647
# Trial 5, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.01929, test err=0.642
# Trial 5, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.01034, test err=0.638
# Trial 5, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00688, test err=0.636
# Trial 5, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.00509, test err=0.636
# Trial 5, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00400, test err=0.636
# Trial 5, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00328, test err=0.636
# Trial 6, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.48034, test err=0.867
# Trial 6, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.06533, test err=0.642
# Trial 6, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.01992, test err=0.637
# Trial 6, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.01084, test err=0.634
# Trial 6, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00725, test err=0.634
# Trial 6, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.00537, test err=0.633
# Trial 6, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00423, test err=0.632
# Trial 6, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00347, test err=0.632
# Trial 7, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.57041, test err=0.903
# Trial 7, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.06434, test err=0.655
# Trial 7, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.01969, test err=0.646
# Trial 7, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.01077, test err=0.643
# Trial 7, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00721, test err=0.641
# Trial 7, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.00535, test err=0.641
# Trial 7, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00422, test err=0.640
# Trial 7, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00346, test err=0.640
# Trial 8, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.48285, test err=0.868
# Trial 8, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.06686, test err=0.642
# Trial 8, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.01966, test err=0.635
# Trial 8, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.01055, test err=0.633
# Trial 8, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00703, test err=0.631
# Trial 8, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.00520, test err=0.629
# Trial 8, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00410, test err=0.629
# Trial 8, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00336, test err=0.629
# Trial 9, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.35021, test err=0.854
# Trial 9, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.06636, test err=0.629
# Trial 9, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.02016, test err=0.627
# Trial 9, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.01102, test err=0.626
# Trial 9, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00737, test err=0.626
# Trial 9, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.00546, test err=0.625
# Trial 9, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00430, test err=0.625
# Trial 9, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00353, test err=0.625
# Trial 0, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.30018, test err=0.893
# Trial 0, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.07784, test err=0.637
# Trial 0, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.02089, test err=0.633
# Trial 0, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.01109, test err=0.633
# Trial 0, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00735, test err=0.633
# Trial 0, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.00542, test err=0.633
# Trial 0, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00426, test err=0.633
# Trial 0, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00348, test err=0.633
# Trial 1, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.36234, test err=0.877
# Trial 1, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.08097, test err=0.628
# Trial 1, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.02154, test err=0.623
# Trial 1, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.01134, test err=0.622
# Trial 1, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00748, test err=0.621
# Trial 1, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.00550, test err=0.621
# Trial 1, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00431, test err=0.620
# Trial 1, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00352, test err=0.620
# Trial 2, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.30697, test err=0.913
# Trial 2, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.08075, test err=0.631
# Trial 2, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.02150, test err=0.627
# Trial 2, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.01132, test err=0.625
# Trial 2, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00745, test err=0.624
# Trial 2, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.00547, test err=0.624
# Trial 2, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00428, test err=0.625
# Trial 2, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00350, test err=0.625
# Trial 3, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.34241, test err=0.919
# Trial 3, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.06521, test err=0.646
# Trial 3, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.01925, test err=0.643
# Trial 3, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.01050, test err=0.643
# Trial 3, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00704, test err=0.642
# Trial 3, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.00522, test err=0.641
# Trial 3, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00412, test err=0.641
# Trial 3, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00338, test err=0.641
# Trial 4, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.32959, test err=0.888
# Trial 4, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.07249, test err=0.632
# Trial 4, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.02058, test err=0.631
# Trial 4, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.01103, test err=0.630
# Trial 4, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00732, test err=0.629
# Trial 4, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.00540, test err=0.630
# Trial 4, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00425, test err=0.629
# Trial 4, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00348, test err=0.629
# Trial 5, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.33536, test err=0.919
# Trial 5, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.07246, test err=0.652
# Trial 5, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.02036, test err=0.650
# Trial 5, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.01091, test err=0.649
# Trial 5, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00725, test err=0.648
# Trial 5, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.00535, test err=0.647
# Trial 5, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00421, test err=0.647
# Trial 5, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00345, test err=0.647
# Trial 6, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.32231, test err=0.881
# Trial 6, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.06780, test err=0.648
# Trial 6, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.01994, test err=0.645
# Trial 6, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.01083, test err=0.643
# Trial 6, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00723, test err=0.643
# Trial 6, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.00535, test err=0.642
# Trial 6, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00422, test err=0.641
# Trial 6, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00346, test err=0.642
# Trial 7, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.39476, test err=0.916
# Trial 7, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.07857, test err=0.647
# Trial 7, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.02146, test err=0.646
# Trial 7, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.01138, test err=0.645
# Trial 7, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00751, test err=0.646
# Trial 7, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.00553, test err=0.645
# Trial 7, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00433, test err=0.644
# Trial 7, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00354, test err=0.644
# Trial 8, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.29905, test err=0.891
# Trial 8, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.07035, test err=0.636
# Trial 8, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.01990, test err=0.633
# Trial 8, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.01069, test err=0.631
# Trial 8, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00711, test err=0.630
# Trial 8, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.00525, test err=0.630
# Trial 8, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00413, test err=0.630
# Trial 8, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00338, test err=0.630
# Trial 9, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.35350, test err=0.911
# Trial 9, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.07110, test err=0.639
# Trial 9, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.02021, test err=0.634
# Trial 9, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.01090, test err=0.633
# Trial 9, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00726, test err=0.633
# Trial 9, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.00537, test err=0.633
# Trial 9, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00422, test err=0.632
# Trial 9, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00346, test err=0.632
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.47394, test err=0.904
# Trial 0, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00218, test err=0.634
# Trial 0, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00095, test err=0.632
# Trial 0, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00059, test err=0.632
# Trial 0, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00042, test err=0.632
# Trial 0, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00033, test err=0.632
# Trial 0, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00027, test err=0.632
# Trial 0, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00022, test err=0.632
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.43202, test err=0.871
# Trial 1, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00231, test err=0.613
# Trial 1, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00099, test err=0.613
# Trial 1, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00061, test err=0.612
# Trial 1, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00044, test err=0.613
# Trial 1, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00034, test err=0.614
# Trial 1, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00027, test err=0.614
# Trial 1, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00023, test err=0.614
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.68000, test err=0.857
# Trial 2, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00220, test err=0.609
# Trial 2, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00096, test err=0.607
# Trial 2, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00059, test err=0.606
# Trial 2, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00043, test err=0.606
# Trial 2, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00033, test err=0.606
# Trial 2, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00027, test err=0.605
# Trial 2, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00022, test err=0.605
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.59083, test err=0.863
# Trial 3, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00215, test err=0.635
# Trial 3, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00093, test err=0.634
# Trial 3, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00058, test err=0.634
# Trial 3, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00041, test err=0.633
# Trial 3, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00032, test err=0.633
# Trial 3, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00026, test err=0.632
# Trial 3, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00022, test err=0.632
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.74260, test err=0.876
# Trial 4, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00231, test err=0.642
# Trial 4, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00099, test err=0.641
# Trial 4, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00061, test err=0.640
# Trial 4, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00044, test err=0.639
# Trial 4, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00034, test err=0.639
# Trial 4, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00027, test err=0.638
# Trial 4, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00023, test err=0.638
# Trial 5, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.50377, test err=0.893
# Trial 5, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00218, test err=0.635
# Trial 5, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00095, test err=0.634
# Trial 5, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00059, test err=0.633
# Trial 5, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00042, test err=0.633
# Trial 5, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00033, test err=0.632
# Trial 5, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00027, test err=0.631
# Trial 5, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00022, test err=0.632
# Trial 6, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.57265, test err=0.898
# Trial 6, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00214, test err=0.622
# Trial 6, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00093, test err=0.620
# Trial 6, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00058, test err=0.620
# Trial 6, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00042, test err=0.619
# Trial 6, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00032, test err=0.620
# Trial 6, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00026, test err=0.620
# Trial 6, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00022, test err=0.620
# Trial 7, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.62521, test err=0.918
# Trial 7, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00220, test err=0.643
# Trial 7, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00095, test err=0.641
# Trial 7, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00059, test err=0.640
# Trial 7, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00042, test err=0.640
# Trial 7, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00033, test err=0.639
# Trial 7, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00027, test err=0.639
# Trial 7, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00022, test err=0.639
# Trial 8, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.38146, test err=0.850
# Trial 8, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00221, test err=0.624
# Trial 8, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00096, test err=0.623
# Trial 8, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00060, test err=0.621
# Trial 8, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00043, test err=0.621
# Trial 8, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00033, test err=0.621
# Trial 8, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00027, test err=0.621
# Trial 8, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00023, test err=0.621
# Trial 9, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.57244, test err=0.840
# Trial 9, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00227, test err=0.633
# Trial 9, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00098, test err=0.632
# Trial 9, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00061, test err=0.631
# Trial 9, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00043, test err=0.631
# Trial 9, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00034, test err=0.631
# Trial 9, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00027, test err=0.630
# Trial 9, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00023, test err=0.630
# Trial 0, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.32334, test err=0.907
# Trial 0, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00218, test err=0.637
# Trial 0, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00094, test err=0.637
# Trial 0, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00058, test err=0.636
# Trial 0, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00042, test err=0.637
# Trial 0, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00032, test err=0.636
# Trial 0, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00026, test err=0.637
# Trial 0, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00022, test err=0.637
# Trial 1, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.30326, test err=0.884
# Trial 1, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00215, test err=0.635
# Trial 1, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00093, test err=0.635
# Trial 1, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00058, test err=0.635
# Trial 1, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00042, test err=0.636
# Trial 1, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00032, test err=0.636
# Trial 1, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00026, test err=0.636
# Trial 1, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00022, test err=0.637
# Trial 2, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.29853, test err=0.880
# Trial 2, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00223, test err=0.629
# Trial 2, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00096, test err=0.629
# Trial 2, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00059, test err=0.630
# Trial 2, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00043, test err=0.630
# Trial 2, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00033, test err=0.631
# Trial 2, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00027, test err=0.630
# Trial 2, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00022, test err=0.631
# Trial 3, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.35883, test err=0.879
# Trial 3, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00216, test err=0.634
# Trial 3, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00093, test err=0.633
# Trial 3, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00058, test err=0.633
# Trial 3, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00041, test err=0.632
# Trial 3, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00032, test err=0.633
# Trial 3, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00026, test err=0.633
# Trial 3, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00022, test err=0.633
# Trial 4, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.36100, test err=0.894
# Trial 4, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00221, test err=0.635
# Trial 4, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00095, test err=0.635
# Trial 4, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00059, test err=0.634
# Trial 4, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00042, test err=0.634
# Trial 4, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00033, test err=0.634
# Trial 4, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00027, test err=0.635
# Trial 4, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00022, test err=0.635
# Trial 5, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.30215, test err=0.902
# Trial 5, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00218, test err=0.637
# Trial 5, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00094, test err=0.636
# Trial 5, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00059, test err=0.637
# Trial 5, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00042, test err=0.637
# Trial 5, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00033, test err=0.637
# Trial 5, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00026, test err=0.637
# Trial 5, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00022, test err=0.637
# Trial 6, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.30674, test err=0.894
# Trial 6, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00222, test err=0.641
# Trial 6, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00096, test err=0.642
# Trial 6, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00059, test err=0.642
# Trial 6, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00043, test err=0.642
# Trial 6, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00033, test err=0.642
# Trial 6, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00027, test err=0.642
# Trial 6, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00022, test err=0.642
# Trial 7, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.31423, test err=0.905
# Trial 7, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00219, test err=0.631
# Trial 7, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00094, test err=0.632
# Trial 7, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00059, test err=0.631
# Trial 7, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00042, test err=0.631
# Trial 7, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00032, test err=0.632
# Trial 7, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00026, test err=0.632
# Trial 7, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00022, test err=0.632
# Trial 8, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.32989, test err=0.875
# Trial 8, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00218, test err=0.630
# Trial 8, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00094, test err=0.631
# Trial 8, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00058, test err=0.630
# Trial 8, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00042, test err=0.631
# Trial 8, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00032, test err=0.631
# Trial 8, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00026, test err=0.631
# Trial 8, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00022, test err=0.631
# Trial 9, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.34284, test err=0.867
# Trial 9, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00215, test err=0.628
# Trial 9, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00093, test err=0.627
# Trial 9, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00058, test err=0.628
# Trial 9, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00041, test err=0.628
# Trial 9, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00032, test err=0.629
# Trial 9, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00026, test err=0.629
# Trial 9, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00022, test err=0.628
# Trial 0, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.46339, test err=0.900
# Trial 0, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.00016, test err=0.603
# Trial 0, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.00007, test err=0.603
# Trial 0, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.00005, test err=0.602
# Trial 0, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.602
# Trial 0, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.602
# Trial 0, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.602
# Trial 0, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.602
# Trial 1, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.46097, test err=0.790
# Trial 1, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.00015, test err=0.649
# Trial 1, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.00007, test err=0.649
# Trial 1, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.00004, test err=0.649
# Trial 1, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.649
# Trial 1, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.649
# Trial 1, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.649
# Trial 1, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.649
# Trial 2, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.57210, test err=0.773
# Trial 2, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.00014, test err=0.633
# Trial 2, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.00006, test err=0.634
# Trial 2, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.00004, test err=0.633
# Trial 2, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.634
# Trial 2, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.633
# Trial 2, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.634
# Trial 2, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.633
# Trial 3, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.46697, test err=0.884
# Trial 3, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.00014, test err=0.637
# Trial 3, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.00007, test err=0.636
# Trial 3, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.00004, test err=0.636
# Trial 3, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.636
# Trial 3, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.635
# Trial 3, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.635
# Trial 3, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.635
# Trial 4, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.54589, test err=0.891
# Trial 4, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.00014, test err=0.617
# Trial 4, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.00007, test err=0.617
# Trial 4, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.00004, test err=0.617
# Trial 4, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.617
# Trial 4, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.616
# Trial 4, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.617
# Trial 4, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.617
# Trial 5, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.63432, test err=0.812
# Trial 5, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.00016, test err=0.622
# Trial 5, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.00007, test err=0.620
# Trial 5, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.00005, test err=0.619
# Trial 5, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.618
# Trial 5, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.618
# Trial 5, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.618
# Trial 5, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.618
# Trial 6, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.53965, test err=0.836
# Trial 6, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.00015, test err=0.654
# Trial 6, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.00007, test err=0.652
# Trial 6, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.00004, test err=0.650
# Trial 6, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.650
# Trial 6, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.649
# Trial 6, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.648
# Trial 6, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.648
# Trial 7, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.51434, test err=0.826
# Trial 7, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.00016, test err=0.638
# Trial 7, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.00007, test err=0.637
# Trial 7, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.00005, test err=0.637
# Trial 7, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.636
# Trial 7, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.636
# Trial 7, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.635
# Trial 7, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.634
# Trial 8, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.44567, test err=0.848
# Trial 8, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.00015, test err=0.623
# Trial 8, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.00007, test err=0.622
# Trial 8, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.00004, test err=0.621
# Trial 8, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.621
# Trial 8, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.620
# Trial 8, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.620
# Trial 8, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.620
# Trial 9, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.73396, test err=0.843
# Trial 9, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.00015, test err=0.630
# Trial 9, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.00007, test err=0.630
# Trial 9, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.00004, test err=0.630
# Trial 9, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.630
# Trial 9, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.630
# Trial 9, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.630
# Trial 9, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.630
# Trial 0, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.37844, test err=0.807
# Trial 0, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.00013, test err=0.612
# Trial 0, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.00006, test err=0.612
# Trial 0, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.00004, test err=0.612
# Trial 0, Epoch: 4000, He model, h=50, lr=1.00000, Loss=0.00003, test err=0.612
# Trial 0, Epoch: 5000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.612
# Trial 0, Epoch: 6000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.613
# Trial 0, Epoch: 7000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.613
# Trial 1, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.33364, test err=0.826
# Trial 1, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.00014, test err=0.631
# Trial 1, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.00006, test err=0.631
# Trial 1, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.00004, test err=0.631
# Trial 1, Epoch: 4000, He model, h=50, lr=1.00000, Loss=0.00003, test err=0.631
# Trial 1, Epoch: 5000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.631
# Trial 1, Epoch: 6000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.631
# Trial 1, Epoch: 7000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.631
# Trial 2, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.32245, test err=0.769
# Trial 2, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.00013, test err=0.618
# Trial 2, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.00006, test err=0.619
# Trial 2, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.00004, test err=0.619
# Trial 2, Epoch: 4000, He model, h=50, lr=1.00000, Loss=0.00003, test err=0.621
# Trial 2, Epoch: 5000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.621
# Trial 2, Epoch: 6000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.621
# Trial 2, Epoch: 7000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.621
# Trial 3, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.32299, test err=0.768
# Trial 3, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.00014, test err=0.629
# Trial 3, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.00006, test err=0.629
# Trial 3, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.00004, test err=0.630
# Trial 3, Epoch: 4000, He model, h=50, lr=1.00000, Loss=0.00003, test err=0.630
# Trial 3, Epoch: 5000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.630
# Trial 3, Epoch: 6000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.630
# Trial 3, Epoch: 7000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.630
# Trial 4, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.36281, test err=0.762
# Trial 4, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.00015, test err=0.620
# Trial 4, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.00007, test err=0.620
# Trial 4, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.00004, test err=0.620
# Trial 4, Epoch: 4000, He model, h=50, lr=1.00000, Loss=0.00003, test err=0.621
# Trial 4, Epoch: 5000, He model, h=50, lr=1.00000, Loss=0.00003, test err=0.620
# Trial 4, Epoch: 6000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.620
# Trial 4, Epoch: 7000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.620
# Trial 5, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.35286, test err=0.801
# Trial 5, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.00014, test err=0.641
# Trial 5, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.00006, test err=0.640
# Trial 5, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.00004, test err=0.640
# Trial 5, Epoch: 4000, He model, h=50, lr=1.00000, Loss=0.00003, test err=0.640
# Trial 5, Epoch: 5000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.640
# Trial 5, Epoch: 6000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.640
# Trial 5, Epoch: 7000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.640
# Trial 6, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.33173, test err=0.787
# Trial 6, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.00014, test err=0.625
# ...
# Trial 5, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.00081, test err=0.626
# Trial 5, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.00051, test err=0.627
# Trial 5, Epoch: 4000, He model, h=1000, lr=0.10000, Loss=0.00037, test err=0.627
# Trial 5, Epoch: 5000, He model, h=1000, lr=0.10000, Loss=0.00029, test err=0.627
# Trial 5, Epoch: 6000, He model, h=1000, lr=0.10000, Loss=0.00024, test err=0.627
# Trial 5, Epoch: 7000, He model, h=1000, lr=0.10000, Loss=0.00020, test err=0.627
# Trial 6, Epoch: 0, He model, h=1000, lr=0.10000, Loss=2.32539, test err=0.793
# Trial 6, Epoch: 1000, He model, h=1000, lr=0.10000, Loss=0.00177, test err=0.626
# Trial 6, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.00080, test err=0.627
# Trial 6, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.00051, test err=0.627
# Trial 6, Epoch: 4000, He model, h=1000, lr=0.10000, Loss=0.00037, test err=0.627
# Trial 6, Epoch: 5000, He model, h=1000, lr=0.10000, Loss=0.00029, test err=0.626
# Trial 6, Epoch: 6000, He model, h=1000, lr=0.10000, Loss=0.00023, test err=0.627
# Trial 6, Epoch: 7000, He model, h=1000, lr=0.10000, Loss=0.00020, test err=0.627
# Trial 7, Epoch: 0, He model, h=1000, lr=0.10000, Loss=2.33325, test err=0.803
# Trial 7, Epoch: 1000, He model, h=1000, lr=0.10000, Loss=0.00175, test err=0.635
# Trial 7, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.00079, test err=0.635
# Trial 7, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.00050, test err=0.635
# Trial 7, Epoch: 4000, He model, h=1000, lr=0.10000, Loss=0.00036, test err=0.636
# Trial 7, Epoch: 5000, He model, h=1000, lr=0.10000, Loss=0.00028, test err=0.636
# Trial 7, Epoch: 6000, He model, h=1000, lr=0.10000, Loss=0.00023, test err=0.635
# Trial 7, Epoch: 7000, He model, h=1000, lr=0.10000, Loss=0.00019, test err=0.635
# Trial 8, Epoch: 0, He model, h=1000, lr=0.10000, Loss=2.33055, test err=0.775
# Trial 8, Epoch: 1000, He model, h=1000, lr=0.10000, Loss=0.00176, test err=0.633
# Trial 8, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.00079, test err=0.633
# Trial 8, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.00050, test err=0.633
# Trial 8, Epoch: 4000, He model, h=1000, lr=0.10000, Loss=0.00036, test err=0.633
# Trial 8, Epoch: 5000, He model, h=1000, lr=0.10000, Loss=0.00028, test err=0.633
# Trial 8, Epoch: 6000, He model, h=1000, lr=0.10000, Loss=0.00023, test err=0.633
# Trial 8, Epoch: 7000, He model, h=1000, lr=0.10000, Loss=0.00020, test err=0.633
# Trial 9, Epoch: 0, He model, h=1000, lr=0.10000, Loss=2.35111, test err=0.815
# Trial 9, Epoch: 1000, He model, h=1000, lr=0.10000, Loss=0.00174, test err=0.636
# Trial 9, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.00079, test err=0.636
# Trial 9, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.00050, test err=0.636
# Trial 9, Epoch: 4000, He model, h=1000, lr=0.10000, Loss=0.00036, test err=0.637
# Trial 9, Epoch: 5000, He model, h=1000, lr=0.10000, Loss=0.00028, test err=0.637
# Trial 9, Epoch: 6000, He model, h=1000, lr=0.10000, Loss=0.00023, test err=0.636
# Trial 9, Epoch: 7000, He model, h=1000, lr=0.10000, Loss=0.00019, test err=0.637
# Trial 0, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.62356, test err=0.831
# Trial 0, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.00009, test err=0.614
# Trial 0, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00004, test err=0.614
# Trial 0, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00003, test err=0.613
# Trial 0, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.612
# Trial 0, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.612
# Trial 0, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=0.00001, test err=0.613
# Trial 0, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=0.00001, test err=0.612
# Trial 1, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.81331, test err=0.894
# Trial 1, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.00009, test err=0.630
# Trial 1, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00004, test err=0.628
# Trial 1, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00003, test err=0.626
# Trial 1, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.626
# Trial 1, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.625
# Trial 1, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=0.00001, test err=0.625
# Trial 1, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=0.00001, test err=0.624
# Trial 2, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.37877, test err=0.815
# Trial 2, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.00010, test err=0.640
# Trial 2, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00005, test err=0.637
# Trial 2, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00003, test err=0.635
# Trial 2, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.634
# Trial 2, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.633
# Trial 2, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=0.00001, test err=0.632
# Trial 2, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=0.00001, test err=0.631
# Trial 3, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.80094, test err=0.791
# Trial 3, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.00009, test err=0.630
# Trial 3, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00004, test err=0.628
# Trial 3, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00003, test err=0.627
# Trial 3, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.627
# Trial 3, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.627
# Trial 3, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=0.00001, test err=0.627
# Trial 3, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=0.00001, test err=0.626
# Trial 4, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.56951, test err=0.891
# Trial 4, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.00008, test err=0.634
# Trial 4, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00004, test err=0.632
# Trial 4, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00003, test err=0.631
# Trial 4, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.630
# Trial 4, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.629
# Trial 4, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=0.00001, test err=0.629
# Trial 4, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=0.00001, test err=0.628
# Trial 5, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.69554, test err=0.836
# Trial 5, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.00010, test err=0.616
# Trial 5, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00005, test err=0.615
# Trial 5, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00003, test err=0.614
# Trial 5, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.613
# Trial 5, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.613
# Trial 5, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=0.00001, test err=0.613
# Trial 5, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=0.00001, test err=0.613
# Trial 6, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.66972, test err=0.833
# Trial 6, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.00008, test err=0.665
# Trial 6, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00004, test err=0.664
# Trial 6, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00003, test err=0.662
# Trial 6, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.661
# Trial 6, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.661
# Trial 6, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=0.00001, test err=0.660
# Trial 6, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=0.00001, test err=0.660
# Trial 7, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.53078, test err=0.810
# Trial 7, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.00009, test err=0.628
# Trial 7, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00004, test err=0.629
# Trial 7, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00003, test err=0.629
# Trial 7, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.629
# Trial 7, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.629
# Trial 7, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=0.00001, test err=0.629
# Trial 7, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=0.00001, test err=0.629
# Trial 8, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.51822, test err=0.752
# Trial 8, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.00009, test err=0.621
# Trial 8, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00004, test err=0.620
# Trial 8, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00003, test err=0.619
# Trial 8, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.619
# Trial 8, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.618
# Trial 8, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=0.00001, test err=0.617
# Trial 8, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=0.00001, test err=0.617
# Trial 9, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.60387, test err=0.878
# Trial 9, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.00009, test err=0.662
# Trial 9, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00004, test err=0.661
# Trial 9, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00003, test err=0.662
# Trial 9, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.662
# Trial 9, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.662
# Trial 9, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=0.00001, test err=0.662
# Trial 9, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=0.00001, test err=0.662
# Trial 0, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.34371, test err=0.763
# Trial 0, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.00012, test err=0.628
# Trial 0, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00006, test err=0.628
# Trial 0, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00004, test err=0.628
# Trial 0, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.628
# Trial 0, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.627
# Trial 0, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.627
# Trial 0, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.627
# Trial 1, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.33572, test err=0.835
# Trial 1, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.00013, test err=0.622
# Trial 1, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00006, test err=0.622
# Trial 1, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00004, test err=0.623
# Trial 1, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.623
# Trial 1, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.623
# Trial 1, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.623
# Trial 1, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.623
# Trial 2, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.31133, test err=0.833
# Trial 2, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.00013, test err=0.624
# Trial 2, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00006, test err=0.626
# Trial 2, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00004, test err=0.626
# Trial 2, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.627
# Trial 2, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.626
# Trial 2, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.626
# Trial 2, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.626
# Trial 3, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.34066, test err=0.747
# Trial 3, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.00013, test err=0.628
# Trial 3, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00006, test err=0.627
# Trial 3, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00004, test err=0.627
# Trial 3, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.626
# Trial 3, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.626
# Trial 3, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.626
# Trial 3, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.627
# Trial 4, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.33053, test err=0.795
# Trial 4, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.00013, test err=0.620
# Trial 4, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00006, test err=0.620
# Trial 4, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00004, test err=0.621
# Trial 4, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.621
# Trial 4, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.621
# Trial 4, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.621
# Trial 4, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.621
# Trial 5, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.33769, test err=0.830
# Trial 5, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.00013, test err=0.633
# Trial 5, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00006, test err=0.633
# Trial 5, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00004, test err=0.633
# Trial 5, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.633
# Trial 5, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.633
# Trial 5, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.632
# Trial 5, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.632
# Trial 6, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.30484, test err=0.769
# Trial 6, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.00012, test err=0.629
# Trial 6, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00006, test err=0.628
# Trial 6, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00004, test err=0.628
# Trial 6, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.628
# Trial 6, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.628
# Trial 6, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.628
# Trial 6, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=0.00001, test err=0.628
# Trial 7, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.32335, test err=0.766
# Trial 7, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.00012, test err=0.631
# Trial 7, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00006, test err=0.632
# Trial 7, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00004, test err=0.632
# Trial 7, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.632
# Trial 7, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.632
# Trial 7, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.632
# Trial 7, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.633
# Trial 8, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.31962, test err=0.785
# Trial 8, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.00013, test err=0.629
# Trial 8, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00006, test err=0.629
# Trial 8, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00004, test err=0.629
# Trial 8, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.629
# Trial 8, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.629
# Trial 8, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.629
# Trial 8, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.629
# Trial 9, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.30507, test err=0.749
# Trial 9, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.00013, test err=0.621
# Trial 9, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00006, test err=0.621
# Trial 9, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00004, test err=0.622
# Trial 9, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.622
# Trial 9, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.621
# Trial 9, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.621
# Trial 9, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.621

# %% [markdown]
# ## plot results

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

t, l, n_epochs= 5, 2, 7001
models = ['V1', 'He']
h_list = [50, 100, 400, 1000]
lr_list = [1e-3, 1e-2, 1e-1, 1e0]

for h in h_list:
    for lr in lr_list:
        with open('results/initialize_kmnist/fewshot_data/clf_t=%0.2f_l=%0.2f.pickle' % (t, l), 'rb') as handle:
            sims = pickle.load(handle)

        fig = plt.figure(figsize=(12, 5))
        plt.suptitle(r'Shallow FFW FC net w/ GD. h=%d, lr=%0.4f, '% (h, lr), fontsize=16)
        
        # loss
        ax = fig.add_subplot(131)
        plt.title('Network loss', fontsize=16)
        for m in models:
            avg_loss = np.mean(sims['loss'][m][h][lr], axis=0)
            std_loss = np.std(sims['loss'][m][h][lr], axis=0)                       
            plt.plot(np.arange(n_epochs), avg_loss, label=m, lw=3)
            plt.fill_between(np.arange(n_epochs), avg_loss - std_loss, avg_loss + std_loss, alpha=0.2)
        plt.xlabel('Epoch', fontsize=20)
        plt.ylabel('Training loss', fontsize=20)
        ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
        plt.yscale('log')
        plt.legend(fontsize=18)
        
        # train err
        ax = fig.add_subplot(132)
        plt.title('Train error', fontsize=16)
        for m in models:
            avg_train_err = np.mean(sims['train_err'][m][h][lr], axis=0)
            std_train_err = np.std(sims['train_err'][m][h][lr], axis=0)
            plt.plot(np.arange(n_epochs), avg_train_err, label=m, lw=3)
            plt.fill_between(np.arange(n_epochs), avg_train_err - std_train_err, avg_train_err + std_train_err,  alpha=0.2)
        
        plt.xlabel('Epoch', fontsize=20)
        plt.ylabel('Training error', fontsize=20)
        ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
        plt.yticks(np.arange(0, 1, 0.2))
        plt.yscale('log')
        plt.legend(fontsize=18)

        # test err
        ax = fig.add_subplot(133)
        plt.title('Test error', fontsize=16)
        for m in models:
            avg_test_err = np.mean(sims['test_err'][m][h][lr], axis=0)
            std_test_err = np.std(sims['test_err'][m][h][lr], axis=0)
            plt.plot(np.arange(n_epochs), avg_test_err, label=m, lw=3)
            plt.fill_between(np.arange(n_epochs), avg_test_err - std_test_err, avg_test_err + std_test_err, alpha=0.2)

        plt.xlabel('Epoch', fontsize=20)
        plt.ylabel('Test error', fontsize=20)
        ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
        plt.yticks(np.arange(0, 1, 0.2))
        plt.yscale('log')
        plt.legend(fontsize=18)

        plt.tight_layout()
        plt.subplots_adjust(top=0.8)    

        print(h, lr)
        plt.savefig('results/initialize_kmnist/fewshot_data/init_t=%0.2f_l=%0.2f_h=%d_lr=%0.4f.png' % (t, l, h, lr))
        plt.close()
# Out:
# 50 0.001
# 50 0.01
# 50 0.1
# 50 1.0
# 100 0.001
# 100 0.01
# 100 0.1
# 100 1.0
# 400 0.001
# 400 0.01
# 400 0.1
# 400 1.0
# 1000 0.001
# 1000 0.01
# 1000 0.1
# 1000 1.0

# %%
# !nvidia-smi

# %%
np.random.multivariate_normal((5, 3), np.eye(2))

# %%
np.random.uniform(2, 8, (4, 2))
