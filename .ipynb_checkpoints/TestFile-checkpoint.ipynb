# %%
import os
import os.path as path
from tqdm import tqdm

import matplotlib.pyplot as plt
import numpy as np
import numpy.linalg as la

from src.structured_random_features.src.models.weights import V1_weights

# Packages for fft and fitting data
from scipy import fftpack as fft
from sklearn.linear_model import Lasso

# Package for importing image representation
from PIL import Image, ImageOps

from src.V1_Compress import generateY, compress

# %%
import pandas as pd

# %%
def OptHyperParams(data): 
#     print(pd.DataFrame(data).sort_values(by = 'score', ascending = True).loc[0])
#     df = pd.DataFrame(data)
#     print("Inside func min: ",df[df.score == df.score.min()])
    return (pd.DataFrame(data).sort_values(by = 'score', ascending = True).loc[0])

# %%
params = []
reformed = []
alpha = np.arange(1, 402, 5)

# Load Image
imageName = 'image/tree_part1.jpg'
img = Image.open(imageName)
img = ImageOps.grayscale(img)
imgArr = np.asarray(img)


# Load V1 weight
numCell = [100, 200, 500]
cellSize = [2, 5, 7]
sparseFreq = [1, 2, 5]
dim = imgArr.shape
n, m = dim


for num in numCell:
    for sz in cellSize:
        for freq in sparseFreq:
            W = V1_weights(num, dim, sz, freq) 
            y = generateY(W, imgArr)
            W_model = W.reshape(num, n, m)
            bestAlpha = []
            for i, a in enumerate(alpha):
                theta, reform, s = compress(W_model, y, a)
                score = np.linalg.norm(img - reform, 'fro') / n
                bestAlpha.append({'alpha': a,
                                  'theta': theta,
                                  'reform': reform,
                                  'sparse': s,
                                  'score' : score})
#                 print(i,"th iteration", i)
            alphaOpt, thetaOpt, reformOpt, sparseOpt, scoreOpt = OptHyperParams(bestAlpha)
            print(OptHyperParams(bestAlpha))
#             print('alphaData:', OptHyperParams(bestAlpha))
            params.append({'numCell' : num,
                           'cellSize' : sz,
                           'sparseFreq' : freq,
                           'alpha' : alphaOpt,
                           'theta' : thetaOpt,
                           'reform' : reformOpt,
                           'sparse' : sparseOpt,
                           'score' : scoreOpt})
                
OptHyperParam = OptHyperParams(params)
# Out:
# alpha                                                     1
# theta     [[3.459175423318254, -4.677142021341913, 4.082...
# reform    [[206.21039170827692, 199.32466212229977, 192....
# sparse    [3909.415498552107, 417.9188575498237, 466.155...
# score                                             32.939057
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[3.7448451329175545, 4.781775095320784, 3.360...
# reform    [[219.19830142753437, 201.5850420049646, 185.9...
# sparse    [4108.365016028477, 272.24476188214453, 518.50...
# score                                             28.982443
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[-5.140317754549804, -6.933909742706487, -5.9...
# reform    [[226.64646300982253, 221.5405626645405, 212.3...
# sparse    [3950.5270107001375, 471.6888745310952, 489.32...
# score                                             29.038196
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[-0.37223554599328534, -0.6300636846312785, -...
# reform    [[220.03786342323394, 224.34182222103965, 248....
# sparse    [3965.9283780861156, 318.63591408003293, 467.9...
# score                                               30.3635
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[1.0805885915926996, 0.9069621311209319, -5.6...
# reform    [[199.51348354108518, 215.56072655584063, 225....
# sparse    [4016.3568049082696, 348.74772329483415, 553.7...
# score                                             24.596992
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[7.571112077354515, -8.904839827207306, 4.497...
# reform    [[210.7473448179841, 208.62803554498583, 206.3...
# sparse    [4044.826932350913, 363.5126809774236, 558.533...
# score                                              23.13348
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[1.0506294987168596, -0.7350756078121807, -0....
# reform    [[254.53388278659597, 204.32219257226686, 176....
# sparse    [4005.863265703686, 408.28643501397477, 544.53...
# score                                             27.554438
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[4.337078987291688, -7.000058516805979, 5.393...
# reform    [[198.11849712926693, 222.12651892079063, 229....
# sparse    [3970.1292061277663, 375.57532197225146, 546.7...
# score                                             26.319192
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[7.743621174734563, -10.644660666365061, 9.88...
# reform    [[205.28966734843033, 204.95744644481843, 204....
# sparse    [4044.1011814097747, 362.43755425221616, 558.8...
# score                                             23.107449
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[1.2621770287737182, 1.7351780320834282, 1.60...
# reform    [[214.32997032633187, 207.04179343646382, 180....
# sparse    [4028.255165924213, 375.67539869477895, 539.58...
# score                                             22.689524
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[0.3873949492838643, 0.5136330167625192, 0.24...
# reform    [[213.18755587409996, 223.04318911531303, 222....
# sparse    [4016.5309081580026, 336.6032989332992, 533.26...
# score                                             20.887515
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[-4.0078676129240405, 1.2066168280788983, 4.8...
# reform    [[230.43904972093208, 209.20585461000792, 180....
# sparse    [4030.704522067435, 373.7187735915748, 543.957...
# score                                               20.7213
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[-2.1768466400826907, -2.5233882419921487, -2...
# reform    [[253.91961723746613, 197.29170138830816, 217....
# sparse    [4026.2282434644, 392.58217602046926, 562.1565...
# score                                              23.71994
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[2.2832921709212473, -2.9588366511479034, 1.3...
# reform    [[205.0327889537146, 201.259223535655, 201.600...
# sparse    [4041.447989812323, 364.482569056543, 555.4123...
# score                                             20.293168
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[-4.7695832606511885, -3.5497593206274356, 1....
# reform    [[211.5940987674146, 209.9025512612546, 207.56...
# sparse    [4044.151033621, 363.93911202036173, 560.18690...
# score                                             22.484323
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[0.531130692003661, -1.4074437611190853, 2.32...
# reform    [[234.72701887699466, 187.44904167640058, 190....
# sparse    [3971.40169442528, 304.9349650393176, 505.2857...
# score                                             23.958419
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[1.6641948313226667, 1.6790844857463334, -0.5...
# reform    [[229.09497225372553, 225.2976310725463, 216.9...
# sparse    [4045.0403062443474, 366.6732886929527, 560.06...
# score                                               19.1492
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[-7.403589263058327, -7.834914712428585, -2.2...
# reform    [[206.98176349223203, 205.08668395252215, 203....
# sparse    [4044.194290101478, 364.89702371563004, 560.62...
# score                                             22.808326
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[-0.6372556734363599, -0.3283139140252076, 0....
# reform    [[209.96957598733206, 215.6918006811492, 212.6...
# sparse    [4014.090245633675, 386.822928148778, 553.8197...
# score                                             14.716548
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[-1.427474502798268, -1.8346364300319018, -1....
# reform    [[213.15359031449398, 206.9260289087597, 218.1...
# sparse    [4044.4863291752968, 367.37510691110475, 557.3...
# score                                             15.293195
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[8.973141438777537, 6.961094463736934, -4.525...
# reform    [[220.99740167073267, 216.46493411264245, 212....
# sparse    [4042.682360934024, 364.47601551732924, 562.29...
# score                                             19.757903
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[-6.035196783666018, -2.344410623286784, 5.42...
# reform    [[224.4541650694199, 206.5157560923898, 207.46...
# sparse    [4037.1127384205033, 368.6590658467878, 555.35...
# score                                             13.243804
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[-3.064169541720613, 0.3890306043560118, 6.13...
# reform    [[222.31128837231972, 212.78816318552992, 208....
# sparse    [4042.948927970607, 364.0637662454062, 559.148...
# score                                               17.5082
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[8.926011486006786, 11.312838642470128, 8.015...
# reform    [[214.89362555636768, 210.39178609158253, 204....
# sparse    [4044.0712525370104, 364.01629775579477, 560.1...
# score                                             22.408879
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[-0.8989161287818611, 1.559724664732392, -1.5...
# reform    [[243.69979003326122, 188.42586740527085, 222....
# sparse    [4037.5909321288077, 362.64525552447304, 547.1...
# score                                             13.549166
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[3.7368521985504066, 0.9249891331143321, -5.2...
# reform    [[226.45307759956756, 215.50813506768912, 211....
# sparse    [4044.9908908068073, 364.780943592194, 559.238...
# score                                             17.607005
# Name: 0, dtype: object
# alpha                                                     1
# theta     [[8.351672465615255, -0.9133846879411531, -10....
# reform    [[211.52685291760733, 209.39457603307622, 206....
# sparse    [4043.7099312022833, 364.399800209783, 559.872...
# score                                             22.773459
# Name: 0, dtype: object

# %%
OptHyperParam
# Out:
# numCell                                                     100
# cellSize                                                      2
# sparseFreq                                                    1
# alpha                                                         1
# theta         [[-2.288586456756442, 1.7794772192949928, 1.07...
# reform        [[182.66354664162174, 217.4935784882485, 215.0...
# sparse        [3820.819616507985, 273.8673163648095, 661.412...
# score                                                 29.458367
# Name: 0, dtype: object
