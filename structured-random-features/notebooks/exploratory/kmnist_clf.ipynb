# %%
from data_fns import load_kmnist
from estimator import RFClassifier, classical_weights, V1_inspired_weights, relu, parallelized_clf
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import numpy.linalg as la
import pickle

# %%
import dask
from dask.distributed import Client
client = Client(threads_per_worker=5, n_workers=5)
client
# Out:
# <Client: 'tcp://127.0.0.1:42835' processes=5 threads=25, memory=67.32 GB>

# %%
# load data
X_train, y_train, X_test, y_test = load_kmnist('data/kmnist/')

# %%
n_features = sorted(set(np.logspace(0, 3.5, 100).astype('int')))

# weight params
t, l = 5, 2
kwargs = {'t': t, 'l': l}
weights_V1 = {'weight_fun': V1_inspired_weights, 'kwargs': kwargs}
weights_classical = {'weight_fun': classical_weights}

# params for classification
# sgd = SGDClassifier(loss="squared_hinge", alpha=1, max_iter=200, tol=1e-5, shuffle=True, n_jobs=5,
#                     learning_rate="optimal", early_stopping=True, validation_fraction=0.1, n_iter_no_change=20)
svc = LinearSVC(random_state=20, tol=1e-4, max_iter=200)
b = np.mean(la.norm(X_train)/ np.sqrt(X_train.shape[0]))

# %%
# %%time
results = {}
m = np.zeros_like(n_features, dtype='float')
results['classical'] = {'avg_test_err': m.copy(), 'std_test_err': m.copy()}
results['V1'] = {'avg_test_err': m.copy(), 'std_test_err': m.copy()}
for i, n in enumerate(n_features):

    # classical random features
    params_classical = {'width': n, **weights_classical, 'bias': b, 'nonlinearity': relu, 'clf': svc}
    _, _, results['classical']['avg_test_err'][i], results['classical']['std_test_err'][i] = parallelized_clf(RFClassifier, 
                                                                                                    params_classical, 
                                                                                                    X_train, y_train, 
                                                                                                    X_test, y_test, 
                                                                                                    n_iters=5)
    
    # V1 inspired
    params_V1 = {'width': n, **weights_V1, 'bias': b, 'nonlinearity': relu, 'clf': svc} 
    _, _, results['V1']['avg_test_err'][i], results['V1']['std_test_err'][i] = parallelized_clf(RFClassifier, 
                                                                                                params_V1, 
                                                                                                X_train, y_train, 
                                                                                                X_test, y_test, 
                                                                                                n_iters=5)

    print('Iter: %d/%d, V1 test err=%0.2f, RF test err= %0.2f' % (n, n_features[-1],  
                                                                       results['V1']['avg_test_err'][i],
                                                                      results['classical']['avg_test_err'][i]))
    
with open('results/kmnist_clf/kmnist_clf_t=%0.2f_l=%0.3f.pickle' % (t, l), 'wb') as handle:
    pickle.dump(results, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Iter: 1/3162, V1 test err=0.88, RF test err= 0.88
# Iter: 2/3162, V1 test err=0.86, RF test err= 0.89
# Iter: 3/3162, V1 test err=0.84, RF test err= 0.87
# Iter: 4/3162, V1 test err=0.88, RF test err= 0.88
# Iter: 5/3162, V1 test err=0.84, RF test err= 0.87
# Iter: 6/3162, V1 test err=0.85, RF test err= 0.88
# Iter: 7/3162, V1 test err=0.87, RF test err= 0.87
# Iter: 8/3162, V1 test err=0.84, RF test err= 0.86
# Iter: 9/3162, V1 test err=0.80, RF test err= 0.86
# Iter: 10/3162, V1 test err=0.80, RF test err= 0.85
# Iter: 11/3162, V1 test err=0.82, RF test err= 0.84
# Iter: 12/3162, V1 test err=0.81, RF test err= 0.86
# Iter: 13/3162, V1 test err=0.73, RF test err= 0.86
# Iter: 14/3162, V1 test err=0.73, RF test err= 0.83
# Iter: 15/3162, V1 test err=0.75, RF test err= 0.82
# Iter: 17/3162, V1 test err=0.75, RF test err= 0.82
# Iter: 18/3162, V1 test err=0.74, RF test err= 0.79
# Iter: 20/3162, V1 test err=0.72, RF test err= 0.84
# Iter: 22/3162, V1 test err=0.71, RF test err= 0.77
# Iter: 23/3162, V1 test err=0.68, RF test err= 0.81
# Iter: 25/3162, V1 test err=0.64, RF test err= 0.79
# Iter: 28/3162, V1 test err=0.68, RF test err= 0.71
# Iter: 30/3162, V1 test err=0.63, RF test err= 0.72
# Iter: 33/3162, V1 test err=0.61, RF test err= 0.71
# Iter: 35/3162, V1 test err=0.64, RF test err= 0.68
# Iter: 38/3162, V1 test err=0.60, RF test err= 0.72
# Iter: 42/3162, V1 test err=0.56, RF test err= 0.69
# Iter: 45/3162, V1 test err=0.60, RF test err= 0.67
# Iter: 49/3162, V1 test err=0.53, RF test err= 0.65
# Iter: 53/3162, V1 test err=0.49, RF test err= 0.61
# Iter: 58/3162, V1 test err=0.53, RF test err= 0.64
# Iter: 63/3162, V1 test err=0.60, RF test err= 0.59
# Iter: 68/3162, V1 test err=0.47, RF test err= 0.57
# Iter: 74/3162, V1 test err=0.47, RF test err= 0.61
# Iter: 81/3162, V1 test err=0.44, RF test err= 0.53
# Iter: 87/3162, V1 test err=0.45, RF test err= 0.54
# Iter: 95/3162, V1 test err=0.44, RF test err= 0.59
# Iter: 103/3162, V1 test err=0.41, RF test err= 0.53
# Iter: 112/3162, V1 test err=0.40, RF test err= 0.55
# Iter: 121/3162, V1 test err=0.34, RF test err= 0.50
# Iter: 132/3162, V1 test err=0.37, RF test err= 0.51
# Iter: 143/3162, V1 test err=0.32, RF test err= 0.47
# Iter: 155/3162, V1 test err=0.31, RF test err= 0.50
# Iter: 168/3162, V1 test err=0.31, RF test err= 0.47
# Iter: 183/3162, V1 test err=0.30, RF test err= 0.48
# Iter: 198/3162, V1 test err=0.31, RF test err= 0.49
# Iter: 215/3162, V1 test err=0.28, RF test err= 0.47
# Iter: 233/3162, V1 test err=0.27, RF test err= 0.43
# Iter: 253/3162, V1 test err=0.24, RF test err= 0.45
# Iter: 275/3162, V1 test err=0.25, RF test err= 0.40
# Iter: 298/3162, V1 test err=0.26, RF test err= 0.38
# Iter: 323/3162, V1 test err=0.24, RF test err= 0.45
# Iter: 351/3162, V1 test err=0.23, RF test err= 0.40
# Iter: 380/3162, V1 test err=0.22, RF test err= 0.39
# Iter: 413/3162, V1 test err=0.19, RF test err= 0.37
# Iter: 448/3162, V1 test err=0.21, RF test err= 0.36
# Iter: 486/3162, V1 test err=0.18, RF test err= 0.39
# Iter: 527/3162, V1 test err=0.17, RF test err= 0.34
# Iter: 572/3162, V1 test err=0.16, RF test err= 0.36

# %%
import pickle 
import numpy as np
import matplotlib.pyplot as plt

n_features = sorted(set(np.logspace(0, 3.5, 100).astype('int')))
t, l = 5, 2
with open('results/kmnist_clf/kmnist_clf_t=%0.2f_l=%0.3f.pickle' % (t, l), 'rb') as handle:
    results = pickle.load(handle)

fig = plt.figure(figsize=(10.6, 8))
ax = fig.add_subplot(111)
ax.errorbar(n_features, results['V1']['avg_test_err'], yerr=results['V1']['std_test_err'], fmt='-', 
            label='V1-inspired',  markersize=4, lw=5, elinewidth=3)
ax.errorbar(n_features, results['classical']['avg_test_err'], yerr=results['classical']['std_test_err'], 
            fmt='-', label='classical', markersize=4, lw=5, elinewidth=3)
plt.xlabel('Hidden layer width', fontsize=40)
plt.ylabel('Classification error', fontsize=40)
plt.xlim([0, 3020])
plt.yticks(np.arange(0, 1.1, 0.2))
plt.ylim([-0.05, 1.05])
plt.xticks(np.arange(0, 3200, 1000))
ax.tick_params(axis = 'both', which = 'major', labelsize = 40, width=2, length=6)

plt.legend(loc = 'upper right', fontsize=30)

# %% [markdown]
# ### Few shot learning

# %%
train, train_labels, test, test_labels = load_kmnist('data/kmnist/')
num_train = 50
X_train, _, y_train, _ = train_test_split(train, train_labels, train_size=num_train, stratify=train_labels, 
                                          random_state=42)
X_test, y_test = test.copy(), test_labels.copy()

# %%
n_features = sorted(set(np.logspace(0, 3.5, 100).astype('int')))

# weight params
t, l, scale = 0.5, 0.5, 1
kwargs = {'t': t, 'l': l, 'scale': scale}
weights_V1 = {'weight_fun': V1_inspired_weights, 'kwargs': kwargs}

kwargs_classical = {'scale': scale}
weights_classical = {'weight_fun': classical_weights, 'kwargs': kwargs_classical}

# params for classification
# sgd = SGDClassifier(loss="squared_hinge", alpha=1, max_iter=200, tol=1e-5, shuffle=True, n_jobs=5,
#                     learning_rate="optimal", early_stopping=True, validation_fraction=0.2, n_iter_no_change=20)
svc = LinearSVC(random_state=20, tol=1e-4, max_iter=500)

b = np.mean(la.norm(X_train)/ np.sqrt(X_train.shape[0]))

# %%
# %%time
results = {}
m = np.zeros_like(n_features, dtype='float')
results['classical'] = {'avg_test_err': m.copy(), 'std_test_err': m.copy()}
results['V1'] = {'avg_test_err': m.copy(), 'std_test_err': m.copy()}
for i, n in enumerate(n_features):

    # classical random features
    params_classical = {'width': n, **weights_classical, 'bias': b, 'nonlinearity': relu, 'clf': svc}
    _, _, results['classical']['avg_test_err'][i], results['classical']['std_test_err'][i] = parallelized_clf(RFClassifier, 
                                                                                                    params_classical, 
                                                                                                    X_train, y_train, 
                                                                                                    X_test, y_test, 
                                                                                                    n_iters=5)
    
    # haltere inspired
    params_V1 = {'width': n, **weights_V1, 'bias': b, 'nonlinearity': relu, 'clf': svc} 
    _, _, results['V1']['avg_test_err'][i], results['V1']['std_test_err'][i] = parallelized_clf(RFClassifier, 
                                                                                                params_V1, 
                                                                                                X_train, y_train, 
                                                                                                X_test, y_test, 
                                                                                                n_iters=5)

    print('Iter: %d/%d, V1 test err=%0.2f, RF test err= %0.2f' % (n, n_features[-1],  
                                                                       results['V1']['avg_test_err'][i],
                                                                      results['classical']['avg_test_err'][i]))
    
with open('results/kmnist_clf/kmnist_clf_t=%0.2f_l=%0.3f_few_shot.pickle' % (t, l), 'wb') as handle:
    pickle.dump(results, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Iter: 1/3162, V1 test err=0.89, RF test err= 0.89
# Iter: 2/3162, V1 test err=0.90, RF test err= 0.90
# Iter: 3/3162, V1 test err=0.88, RF test err= 0.88
# Iter: 4/3162, V1 test err=0.88, RF test err= 0.86
# Iter: 5/3162, V1 test err=0.87, RF test err= 0.86
# Iter: 6/3162, V1 test err=0.86, RF test err= 0.86
# Iter: 7/3162, V1 test err=0.84, RF test err= 0.85
# Iter: 8/3162, V1 test err=0.86, RF test err= 0.86
# Iter: 9/3162, V1 test err=0.84, RF test err= 0.84
# Iter: 10/3162, V1 test err=0.85, RF test err= 0.85
# Iter: 11/3162, V1 test err=0.82, RF test err= 0.83
# Iter: 12/3162, V1 test err=0.83, RF test err= 0.83
# Iter: 13/3162, V1 test err=0.82, RF test err= 0.82
# Iter: 14/3162, V1 test err=0.82, RF test err= 0.84
# Iter: 15/3162, V1 test err=0.83, RF test err= 0.83
# Iter: 17/3162, V1 test err=0.80, RF test err= 0.83
# Iter: 18/3162, V1 test err=0.81, RF test err= 0.83
# Iter: 20/3162, V1 test err=0.80, RF test err= 0.82
# Iter: 22/3162, V1 test err=0.80, RF test err= 0.82
# Iter: 23/3162, V1 test err=0.78, RF test err= 0.80
# Iter: 25/3162, V1 test err=0.81, RF test err= 0.81
# Iter: 28/3162, V1 test err=0.79, RF test err= 0.78
# Iter: 30/3162, V1 test err=0.78, RF test err= 0.78
# Iter: 33/3162, V1 test err=0.78, RF test err= 0.78
# Iter: 35/3162, V1 test err=0.78, RF test err= 0.76
# Iter: 38/3162, V1 test err=0.77, RF test err= 0.78
# Iter: 42/3162, V1 test err=0.78, RF test err= 0.76
# Iter: 45/3162, V1 test err=0.76, RF test err= 0.74
# Iter: 49/3162, V1 test err=0.76, RF test err= 0.74
# Iter: 53/3162, V1 test err=0.76, RF test err= 0.74
# Iter: 58/3162, V1 test err=0.74, RF test err= 0.74
# Iter: 63/3162, V1 test err=0.75, RF test err= 0.74
# Iter: 68/3162, V1 test err=0.73, RF test err= 0.73
# Iter: 74/3162, V1 test err=0.73, RF test err= 0.72
# Iter: 81/3162, V1 test err=0.75, RF test err= 0.72
# Iter: 87/3162, V1 test err=0.74, RF test err= 0.71
# Iter: 95/3162, V1 test err=0.73, RF test err= 0.71
# Iter: 103/3162, V1 test err=0.74, RF test err= 0.70
# Iter: 112/3162, V1 test err=0.75, RF test err= 0.69
# Iter: 121/3162, V1 test err=0.72, RF test err= 0.69
# Iter: 132/3162, V1 test err=0.73, RF test err= 0.68
# Iter: 143/3162, V1 test err=0.72, RF test err= 0.69
# Iter: 155/3162, V1 test err=0.73, RF test err= 0.69
# Iter: 168/3162, V1 test err=0.72, RF test err= 0.69
# Iter: 183/3162, V1 test err=0.72, RF test err= 0.68
# Iter: 198/3162, V1 test err=0.71, RF test err= 0.68
# Iter: 215/3162, V1 test err=0.72, RF test err= 0.68
# Iter: 233/3162, V1 test err=0.71, RF test err= 0.67
# Iter: 253/3162, V1 test err=0.71, RF test err= 0.67
# Iter: 275/3162, V1 test err=0.70, RF test err= 0.67
# Iter: 298/3162, V1 test err=0.70, RF test err= 0.66
# Iter: 323/3162, V1 test err=0.69, RF test err= 0.67
# Iter: 351/3162, V1 test err=0.70, RF test err= 0.67
# Iter: 380/3162, V1 test err=0.70, RF test err= 0.67
# Iter: 413/3162, V1 test err=0.70, RF test err= 0.66
# Iter: 448/3162, V1 test err=0.70, RF test err= 0.66
# Iter: 486/3162, V1 test err=0.68, RF test err= 0.66
# Iter: 527/3162, V1 test err=0.70, RF test err= 0.67
# Iter: 572/3162, V1 test err=0.69, RF test err= 0.66
# Iter: 620/3162, V1 test err=0.68, RF test err= 0.65
# Iter: 673/3162, V1 test err=0.68, RF test err= 0.66
# Iter: 730/3162, V1 test err=0.68, RF test err= 0.66
# Iter: 792/3162, V1 test err=0.68, RF test err= 0.66
# Iter: 859/3162, V1 test err=0.68, RF test err= 0.66
# Iter: 932/3162, V1 test err=0.67, RF test err= 0.66
# Iter: 1011/3162, V1 test err=0.67, RF test err= 0.65
# Iter: 1097/3162, V1 test err=0.68, RF test err= 0.65
# Iter: 1190/3162, V1 test err=0.67, RF test err= 0.66
# Iter: 1291/3162, V1 test err=0.67, RF test err= 0.65
# Iter: 1401/3162, V1 test err=0.67, RF test err= 0.66
# Iter: 1519/3162, V1 test err=0.67, RF test err= 0.65
# Iter: 1648/3162, V1 test err=0.67, RF test err= 0.66
# Iter: 1788/3162, V1 test err=0.67, RF test err= 0.65
# Iter: 1940/3162, V1 test err=0.67, RF test err= 0.65
# Iter: 2104/3162, V1 test err=0.66, RF test err= 0.65
# Iter: 2283/3162, V1 test err=0.66, RF test err= 0.65
# Iter: 2477/3162, V1 test err=0.66, RF test err= 0.65
# Iter: 2687/3162, V1 test err=0.66, RF test err= 0.65
# Iter: 2915/3162, V1 test err=0.66, RF test err= 0.65
# Iter: 3162/3162, V1 test err=0.66, RF test err= 0.65
# CPU times: user 2min 56s, sys: 1min 1s, total: 3min 58s
# Wall time: 1h 2min 40s

# %%
fig = plt.figure(figsize=(10.6, 8))
ax = fig.add_subplot(111)
ax.errorbar(n_features, results['V1']['avg_test_err'], yerr=results['V1']['std_test_err'], fmt='-', 
            label='V1-inspired',  markersize=4, lw=5, elinewidth=3)
ax.errorbar(n_features, results['classical']['avg_test_err'], yerr=results['classical']['std_test_err'], 
            fmt='-', label='classical', markersize=4, lw=5, elinewidth=3)
plt.xlabel('Hidden layer width', fontsize=40)
plt.ylabel('Classification error', fontsize=40)
# plt.xticks(np.arange(0, 1020, 200))
# plt.xlim([0, 1000])
# plt.yticks(np.arange(0, 0.6, 0.1))
# plt.ylim([-0.05, 0.55])
# plt.xticks(np.arange(0, 255, 50))
ax.tick_params(axis = 'both', which = 'major', labelsize = 40, width=2, length=6)

plt.legend(loc = 'upper right', fontsize=30)
# plt.savefig('results/kmnist_clf/kmnist_clf_t=%0.2f_l=%0.2f_fewshot.png' % (t, l))
