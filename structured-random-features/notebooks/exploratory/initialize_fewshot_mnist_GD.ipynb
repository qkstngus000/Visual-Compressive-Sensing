# %% [markdown]
# Initialize shallow feedforward fully-connected network with V1 type weights and classify __subset of mnist__ dataset using __Gradient descent__. The partial dataset will have 5 samples/class.

# %%
import numpy as np
import numpy.linalg as la
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from estimator import classical_weights, V1_inspired_weights
from data_fns import load_mnist
from sklearn.model_selection import train_test_split
import pickle

# %%
torch.cuda.set_device(1)
train, train_labels, test, test_labels = load_mnist('./data/mnist/')

num_train = 50
train_few, _, train_labels_few, _ = train_test_split(train, train_labels, train_size=num_train, stratify=train_labels, 
                                          random_state=42)


X_train = torch.from_numpy(train_few).float().to('cuda')
X_test = torch.from_numpy(test).float().to('cuda')
y_train = torch.from_numpy(train_labels_few).long().to('cuda')
y_test = torch.from_numpy(test_labels).long().to('cuda')
n, d = X_train.shape

# %%
class V1_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(V1_inspired_weights(hidden_size, d, t=5, l=2, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class He_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class RF_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(classical_weights(hidden_size, d, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)

# %%
def predict(model, X):
    return model(X).data.max(1)[1]

def error(model, X, y):
    y_pred = predict(model, X)
    accuracy = 1.0 * torch.sum(y_pred == y) / len(y)
    return 1 - accuracy

# %%
n_trials, n_epochs = 10, 7001
models = {'V1': V1_net, 'He': He_net}
h_list = [50, 100, 400, 1000]
lr_list = [1e-3, 1e-2, 1e-1, 1e0]

train_err = {m: {h: {lr: np.zeros((n_trials, n_epochs)) for lr in lr_list} for h in h_list} for m in models.keys()}
test_err = {m: {h: {lr: np.zeros((n_trials, n_epochs)) for lr in lr_list} for h in h_list} for m in models.keys()}
loss_list = {m: {h: {lr: np.zeros((n_trials, n_epochs)) for lr in lr_list} for h in h_list} for m in models.keys()}

# %%
scale = 2/d
t, l = 5, 2
loss_func = nn.CrossEntropyLoss()

for h in h_list:
    for lr in lr_list:
        for m, network in models.items():
            for i in range(n_trials):
                model = network(h, scale).to('cuda')
                optim = torch.optim.SGD(model.parameters(), lr=lr)
                for j in range(n_epochs):
                    optim.zero_grad()
                    loss = loss_func(model(X_train), y_train)
                    loss.backward()
                    optim.step()

                    train_err[m][h][lr][i, j] = error(model, X_train, y_train)
                    test_err[m][h][lr][i, j] = error(model, X_test, y_test)
                    loss_list[m][h][lr][i, j] = loss.data

                    if (j % 1000 == 0):
                        print('Trial %d, Epoch: %d, %s model, h=%d, lr=%0.5f, Loss=%0.5f, test err=%0.3f' % (i,j, m, h, lr, loss.data, 
                                                                                                  test_err[m][h][lr][i, j]))
results = {'test_err': test_err, 'train_err': train_err, 'loss': loss_list}
with open('results/initialize_mnist/fewshot_data/clf_t=%0.2f_l=%0.2f.pickle' % (t, l), 'wb') as handle:
    pickle.dump(results, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.54700, test err=0.906
# Trial 0, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.55330, test err=0.523
# Trial 0, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=1.00266, test err=0.406
# Trial 0, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.65458, test err=0.374
# Trial 0, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.44057, test err=0.359
# Trial 0, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.30759, test err=0.350
# Trial 0, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.22350, test err=0.346
# Trial 0, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.16893, test err=0.342
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.46790, test err=0.918
# Trial 1, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.43175, test err=0.495
# Trial 1, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.91704, test err=0.431
# Trial 1, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.60955, test err=0.396
# Trial 1, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.41678, test err=0.371
# Trial 1, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.29431, test err=0.355
# Trial 1, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.21504, test err=0.342
# Trial 1, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.16266, test err=0.336
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.98724, test err=0.916
# Trial 2, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.33644, test err=0.456
# Trial 2, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.82030, test err=0.361
# Trial 2, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.53237, test err=0.334
# Trial 2, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.35971, test err=0.322
# Trial 2, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.25285, test err=0.318
# Trial 2, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.18533, test err=0.316
# Trial 2, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.14108, test err=0.313
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.52746, test err=0.871
# Trial 3, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.45555, test err=0.484
# Trial 3, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.93697, test err=0.381
# Trial 3, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.63925, test err=0.345
# Trial 3, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.45384, test err=0.329
# Trial 3, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.33083, test err=0.319
# Trial 3, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.24682, test err=0.317
# Trial 3, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.18848, test err=0.316
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.35333, test err=0.851
# Trial 4, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.47614, test err=0.469
# Trial 4, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.97289, test err=0.394
# Trial 4, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.64242, test err=0.366
# Trial 4, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.43525, test err=0.354
# Trial 4, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.30187, test err=0.343
# Trial 4, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.21629, test err=0.335
# Trial 4, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.16083, test err=0.331
# Trial 5, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.47111, test err=0.928
# Trial 5, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.39286, test err=0.462
# Trial 5, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.85837, test err=0.367
# Trial 5, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.54758, test err=0.340
# Trial 5, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.36364, test err=0.324
# Trial 5, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.25230, test err=0.317
# Trial 5, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.18321, test err=0.314
# Trial 5, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.13859, test err=0.312
# Trial 6, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.76951, test err=0.957
# Trial 6, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.45868, test err=0.516
# Trial 6, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.90573, test err=0.397
# Trial 6, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.57010, test err=0.361
# Trial 6, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.37403, test err=0.340
# Trial 6, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.25747, test err=0.334
# Trial 6, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.18608, test err=0.330
# Trial 6, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.14064, test err=0.327
# Trial 7, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.37832, test err=0.854
# Trial 7, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.42198, test err=0.460
# Trial 7, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.88809, test err=0.384
# Trial 7, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.56544, test err=0.360
# Trial 7, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.37416, test err=0.348
# Trial 7, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.25919, test err=0.346
# Trial 7, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.18829, test err=0.343
# Trial 7, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.14270, test err=0.342
# Trial 8, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.39968, test err=0.878
# Trial 8, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.46506, test err=0.537
# Trial 8, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.94931, test err=0.415
# Trial 8, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.61858, test err=0.376
# Trial 8, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.40967, test err=0.355
# Trial 8, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.28097, test err=0.344
# Trial 8, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.20170, test err=0.338
# Trial 8, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.15133, test err=0.333
# Trial 9, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.88924, test err=0.931
# Trial 9, Epoch: 1000, V1 model, h=50, lr=0.00100, Loss=1.29111, test err=0.441
# Trial 9, Epoch: 2000, V1 model, h=50, lr=0.00100, Loss=0.77711, test err=0.375
# Trial 9, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=0.49913, test err=0.343
# Trial 9, Epoch: 4000, V1 model, h=50, lr=0.00100, Loss=0.33949, test err=0.328
# Trial 9, Epoch: 5000, V1 model, h=50, lr=0.00100, Loss=0.24305, test err=0.321
# Trial 9, Epoch: 6000, V1 model, h=50, lr=0.00100, Loss=0.18134, test err=0.317
# Trial 9, Epoch: 7000, V1 model, h=50, lr=0.00100, Loss=0.13981, test err=0.313
# Trial 0, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.31583, test err=0.938
# Trial 0, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.87947, test err=0.546
# Trial 0, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.36022, test err=0.431
# Trial 0, Epoch: 3000, He model, h=50, lr=0.00100, Loss=0.88922, test err=0.384
# Trial 0, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.57544, test err=0.349
# Trial 0, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.38374, test err=0.335
# Trial 0, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.26664, test err=0.327
# Trial 0, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.19347, test err=0.321
# Trial 1, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.33641, test err=0.888
# Trial 1, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.93493, test err=0.644
# Trial 1, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.43292, test err=0.419
# Trial 1, Epoch: 3000, He model, h=50, lr=0.00100, Loss=0.91980, test err=0.344
# Trial 1, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.57158, test err=0.320
# Trial 1, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.36976, test err=0.313
# Trial 1, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.25249, test err=0.312
# Trial 1, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.18127, test err=0.313
# Trial 2, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.31224, test err=0.914
# Trial 2, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.84539, test err=0.560
# Trial 2, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.32980, test err=0.392
# Trial 2, Epoch: 3000, He model, h=50, lr=0.00100, Loss=0.86065, test err=0.334
# Trial 2, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.55152, test err=0.325
# Trial 2, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.36447, test err=0.322
# Trial 2, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.25183, test err=0.323
# Trial 2, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.18192, test err=0.321
# Trial 3, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.33430, test err=0.894
# Trial 3, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.89897, test err=0.562
# Trial 3, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.38629, test err=0.392
# Trial 3, Epoch: 3000, He model, h=50, lr=0.00100, Loss=0.90609, test err=0.344
# Trial 3, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.57781, test err=0.317
# Trial 3, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.37863, test err=0.305
# Trial 3, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.25921, test err=0.302
# Trial 3, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.18613, test err=0.301
# Trial 4, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.35378, test err=0.915
# Trial 4, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.94853, test err=0.661
# Trial 4, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.49715, test err=0.474
# Trial 4, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.00512, test err=0.390
# Trial 4, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.63678, test err=0.366
# Trial 4, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.41373, test err=0.352
# Trial 4, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.28366, test err=0.342
# Trial 4, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.20433, test err=0.338
# Trial 5, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.30394, test err=0.887
# Trial 5, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.88932, test err=0.606
# Trial 5, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.37491, test err=0.409
# Trial 5, Epoch: 3000, He model, h=50, lr=0.00100, Loss=0.89520, test err=0.349
# Trial 5, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.56452, test err=0.322
# Trial 5, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.36723, test err=0.316
# Trial 5, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.25077, test err=0.315
# Trial 5, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.18036, test err=0.314
# Trial 6, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.34386, test err=0.899
# Trial 6, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.97038, test err=0.679
# Trial 6, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.50645, test err=0.447
# Trial 6, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.01564, test err=0.381
# Trial 6, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.65139, test err=0.354
# Trial 6, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.42807, test err=0.339
# Trial 6, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.29362, test err=0.332
# Trial 6, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.21058, test err=0.330
# Trial 7, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.32300, test err=0.885
# Trial 7, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.96913, test err=0.564
# Trial 7, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.50395, test err=0.412
# Trial 7, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.01311, test err=0.355
# Trial 7, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.65356, test err=0.328
# Trial 7, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.42742, test err=0.313
# Trial 7, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.28865, test err=0.307
# Trial 7, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.20367, test err=0.303
# Trial 8, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.31084, test err=0.888
# Trial 8, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.95822, test err=0.619
# Trial 8, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.49859, test err=0.463
# Trial 8, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.01350, test err=0.367
# Trial 8, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.65134, test err=0.324
# Trial 8, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.42254, test err=0.317
# Trial 8, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.28451, test err=0.314
# Trial 8, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.20087, test err=0.314
# Trial 9, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.32658, test err=0.893
# Trial 9, Epoch: 1000, He model, h=50, lr=0.00100, Loss=1.98765, test err=0.640
# Trial 9, Epoch: 2000, He model, h=50, lr=0.00100, Loss=1.56122, test err=0.492
# Trial 9, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.07156, test err=0.389
# Trial 9, Epoch: 4000, He model, h=50, lr=0.00100, Loss=0.68725, test err=0.362
# Trial 9, Epoch: 5000, He model, h=50, lr=0.00100, Loss=0.44504, test err=0.347
# Trial 9, Epoch: 6000, He model, h=50, lr=0.00100, Loss=0.30044, test err=0.338
# Trial 9, Epoch: 7000, He model, h=50, lr=0.00100, Loss=0.21281, test err=0.332
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.48679, test err=0.875
# Trial 0, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.06928, test err=0.292
# Trial 0, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.02247, test err=0.289
# Trial 0, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.01236, test err=0.290
# Trial 0, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00829, test err=0.290
# Trial 0, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.00614, test err=0.289
# Trial 0, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00483, test err=0.289
# Trial 0, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00396, test err=0.289
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.51062, test err=0.949
# Trial 1, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.07869, test err=0.326
# Trial 1, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.02402, test err=0.322
# Trial 1, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.01303, test err=0.321
# Trial 1, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00867, test err=0.321
# Trial 1, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.00640, test err=0.321
# Trial 1, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00503, test err=0.322
# Trial 1, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00411, test err=0.322
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.84167, test err=0.931
# Trial 2, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.08895, test err=0.313
# Trial 2, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.02622, test err=0.309
# Trial 2, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.01402, test err=0.310
# Trial 2, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00926, test err=0.311
# Trial 2, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.00680, test err=0.309
# Trial 2, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00532, test err=0.310
# Trial 2, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00434, test err=0.310
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.61852, test err=0.886
# Trial 3, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.07322, test err=0.282
# Trial 3, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.02283, test err=0.284
# Trial 3, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.01247, test err=0.285
# Trial 3, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00833, test err=0.285
# Trial 3, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.00616, test err=0.287
# Trial 3, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00484, test err=0.287
# Trial 3, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00397, test err=0.288
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.51116, test err=0.917
# Trial 4, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.07041, test err=0.319
# Trial 4, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.02241, test err=0.314
# Trial 4, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.01227, test err=0.313
# Trial 4, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00818, test err=0.312
# Trial 4, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.00605, test err=0.311
# Trial 4, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00476, test err=0.311
# Trial 4, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00390, test err=0.311
# Trial 5, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.59012, test err=0.967
# Trial 5, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.08004, test err=0.340
# Trial 5, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.02423, test err=0.333
# Trial 5, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.01305, test err=0.331
# Trial 5, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00865, test err=0.330
# Trial 5, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.00637, test err=0.328
# Trial 5, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00500, test err=0.328
# Trial 5, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00409, test err=0.328
# Trial 6, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.47801, test err=0.829
# Trial 6, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.07544, test err=0.289
# Trial 6, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.02349, test err=0.287
# Trial 6, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.01281, test err=0.287
# Trial 6, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00854, test err=0.287
# Trial 6, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.00631, test err=0.287
# Trial 6, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00496, test err=0.286
# Trial 6, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00406, test err=0.286
# Trial 7, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.45291, test err=0.903
# Trial 7, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.07961, test err=0.327
# Trial 7, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.02421, test err=0.328
# Trial 7, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.01308, test err=0.326
# Trial 7, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00871, test err=0.326
# Trial 7, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.00644, test err=0.325
# Trial 7, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00506, test err=0.325
# Trial 7, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00414, test err=0.325
# Trial 8, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.51268, test err=0.894
# Trial 8, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.08615, test err=0.284
# Trial 8, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.02543, test err=0.281
# Trial 8, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.01355, test err=0.281
# Trial 8, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00894, test err=0.282
# Trial 8, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.00657, test err=0.282
# Trial 8, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00514, test err=0.283
# Trial 8, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00420, test err=0.282
# Trial 9, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.40922, test err=0.895
# Trial 9, Epoch: 1000, V1 model, h=50, lr=0.01000, Loss=0.07453, test err=0.305
# Trial 9, Epoch: 2000, V1 model, h=50, lr=0.01000, Loss=0.02352, test err=0.303
# Trial 9, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.01286, test err=0.303
# Trial 9, Epoch: 4000, V1 model, h=50, lr=0.01000, Loss=0.00858, test err=0.303
# Trial 9, Epoch: 5000, V1 model, h=50, lr=0.01000, Loss=0.00635, test err=0.302
# Trial 9, Epoch: 6000, V1 model, h=50, lr=0.01000, Loss=0.00499, test err=0.302
# Trial 9, Epoch: 7000, V1 model, h=50, lr=0.01000, Loss=0.00409, test err=0.301
# Trial 0, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.34004, test err=0.925
# Trial 0, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.08944, test err=0.324
# Trial 0, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.02495, test err=0.321
# Trial 0, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.01329, test err=0.321
# Trial 0, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00879, test err=0.321
# Trial 0, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.00646, test err=0.320
# Trial 0, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00506, test err=0.320
# Trial 0, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00414, test err=0.320
# Trial 1, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.34176, test err=0.899
# Trial 1, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.09359, test err=0.308
# Trial 1, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.02554, test err=0.310
# Trial 1, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.01350, test err=0.311
# Trial 1, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00889, test err=0.312
# Trial 1, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.00652, test err=0.312
# Trial 1, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00510, test err=0.312
# Trial 1, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00416, test err=0.313
# Trial 2, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.32338, test err=0.918
# Trial 2, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.09498, test err=0.334
# Trial 2, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.02592, test err=0.331
# Trial 2, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.01360, test err=0.329
# Trial 2, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00893, test err=0.330
# Trial 2, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.00654, test err=0.329
# Trial 2, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00511, test err=0.329
# Trial 2, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00417, test err=0.329
# Trial 3, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.29658, test err=0.911
# Trial 3, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.09334, test err=0.310
# Trial 3, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.02579, test err=0.306
# Trial 3, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.01365, test err=0.306
# Trial 3, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00898, test err=0.307
# Trial 3, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.00659, test err=0.307
# Trial 3, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00515, test err=0.307
# Trial 3, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00421, test err=0.306
# Trial 4, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.34989, test err=0.916
# Trial 4, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.08677, test err=0.307
# Trial 4, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.02484, test err=0.306
# Trial 4, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.01330, test err=0.308
# Trial 4, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00880, test err=0.307
# Trial 4, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.00648, test err=0.307
# Trial 4, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00508, test err=0.307
# Trial 4, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00415, test err=0.308
# Trial 5, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.30700, test err=0.894
# Trial 5, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.08484, test err=0.311
# Trial 5, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.02445, test err=0.310
# Trial 5, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.01309, test err=0.310
# Trial 5, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00867, test err=0.309
# Trial 5, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.00638, test err=0.309
# Trial 5, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00500, test err=0.309
# Trial 5, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00409, test err=0.308
# Trial 6, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.32832, test err=0.917
# Trial 6, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.09256, test err=0.313
# Trial 6, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.02581, test err=0.314
# Trial 6, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.01368, test err=0.315
# Trial 6, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00902, test err=0.315
# Trial 6, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.00661, test err=0.314
# Trial 6, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00517, test err=0.314
# Trial 6, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00422, test err=0.314
# Trial 7, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.34620, test err=0.931
# Trial 7, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.09264, test err=0.313
# Trial 7, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.02535, test err=0.313
# Trial 7, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.01339, test err=0.314
# Trial 7, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00881, test err=0.312
# Trial 7, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.00646, test err=0.312
# Trial 7, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00505, test err=0.312
# Trial 7, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00412, test err=0.312
# Trial 8, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.29606, test err=0.840
# Trial 8, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.08648, test err=0.321
# Trial 8, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.02476, test err=0.320
# Trial 8, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.01322, test err=0.320
# Trial 8, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00874, test err=0.319
# Trial 8, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.00643, test err=0.319
# Trial 8, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00503, test err=0.319
# Trial 8, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00411, test err=0.319
# Trial 9, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.36606, test err=0.923
# Trial 9, Epoch: 1000, He model, h=50, lr=0.01000, Loss=0.09020, test err=0.337
# Trial 9, Epoch: 2000, He model, h=50, lr=0.01000, Loss=0.02475, test err=0.332
# Trial 9, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.01309, test err=0.331
# Trial 9, Epoch: 4000, He model, h=50, lr=0.01000, Loss=0.00864, test err=0.331
# Trial 9, Epoch: 5000, He model, h=50, lr=0.01000, Loss=0.00635, test err=0.330
# Trial 9, Epoch: 6000, He model, h=50, lr=0.01000, Loss=0.00497, test err=0.331
# Trial 9, Epoch: 7000, He model, h=50, lr=0.01000, Loss=0.00406, test err=0.330
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.82180, test err=0.928
# Trial 0, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00262, test err=0.307
# Trial 0, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00112, test err=0.304
# Trial 0, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00069, test err=0.304
# Trial 0, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00049, test err=0.305
# Trial 0, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00038, test err=0.305
# Trial 0, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00031, test err=0.305
# Trial 0, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00026, test err=0.305
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.53742, test err=0.857
# Trial 1, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00263, test err=0.301
# Trial 1, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00113, test err=0.301
# Trial 1, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00070, test err=0.301
# Trial 1, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00050, test err=0.301
# Trial 1, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00038, test err=0.300
# Trial 1, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00031, test err=0.301
# Trial 1, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00026, test err=0.299
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.53208, test err=0.891
# Trial 2, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00264, test err=0.320
# Trial 2, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00113, test err=0.319
# Trial 2, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00070, test err=0.319
# Trial 2, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00050, test err=0.319
# Trial 2, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00038, test err=0.319
# Trial 2, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00031, test err=0.318
# Trial 2, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00026, test err=0.319
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.55628, test err=0.868
# Trial 3, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00256, test err=0.308
# Trial 3, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00110, test err=0.306
# Trial 3, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00068, test err=0.305
# Trial 3, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00049, test err=0.304
# Trial 3, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00038, test err=0.304
# Trial 3, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00031, test err=0.303
# Trial 3, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00026, test err=0.303
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.81843, test err=0.896
# Trial 4, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00262, test err=0.327
# Trial 4, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00112, test err=0.325
# Trial 4, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00070, test err=0.325
# Trial 4, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00050, test err=0.323
# Trial 4, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00038, test err=0.323
# Trial 4, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00031, test err=0.323
# Trial 4, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00026, test err=0.322
# Trial 5, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.68641, test err=0.896
# Trial 5, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00267, test err=0.333
# Trial 5, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00114, test err=0.331
# Trial 5, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00070, test err=0.330
# Trial 5, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00050, test err=0.329
# Trial 5, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00039, test err=0.329
# Trial 5, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00031, test err=0.329
# Trial 5, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00026, test err=0.329
# Trial 6, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.57952, test err=0.918
# Trial 6, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00267, test err=0.314
# Trial 6, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00114, test err=0.314
# Trial 6, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00070, test err=0.313
# Trial 6, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00050, test err=0.313
# Trial 6, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00039, test err=0.312
# Trial 6, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00031, test err=0.312
# Trial 6, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00026, test err=0.312
# Trial 7, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.53230, test err=0.888
# Trial 7, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00259, test err=0.292
# Trial 7, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00111, test err=0.292
# Trial 7, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00069, test err=0.293
# Trial 7, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00049, test err=0.293
# Trial 7, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00038, test err=0.293
# Trial 7, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00031, test err=0.293
# Trial 7, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00026, test err=0.293
# Trial 8, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.33857, test err=0.880
# Trial 8, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00264, test err=0.316
# Trial 8, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00113, test err=0.316
# Trial 8, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00070, test err=0.316
# Trial 8, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00050, test err=0.316
# Trial 8, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00039, test err=0.316
# Trial 8, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00031, test err=0.316
# Trial 8, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00026, test err=0.316
# Trial 9, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.52737, test err=0.896
# Trial 9, Epoch: 1000, V1 model, h=50, lr=0.10000, Loss=0.00261, test err=0.294
# Trial 9, Epoch: 2000, V1 model, h=50, lr=0.10000, Loss=0.00113, test err=0.294
# Trial 9, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.00070, test err=0.295
# Trial 9, Epoch: 4000, V1 model, h=50, lr=0.10000, Loss=0.00050, test err=0.295
# Trial 9, Epoch: 5000, V1 model, h=50, lr=0.10000, Loss=0.00039, test err=0.296
# Trial 9, Epoch: 6000, V1 model, h=50, lr=0.10000, Loss=0.00031, test err=0.296
# Trial 9, Epoch: 7000, V1 model, h=50, lr=0.10000, Loss=0.00026, test err=0.296
# Trial 0, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.32752, test err=0.927
# Trial 0, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00263, test err=0.321
# Trial 0, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00113, test err=0.320
# Trial 0, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00070, test err=0.320
# Trial 0, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00050, test err=0.320
# Trial 0, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00039, test err=0.320
# Trial 0, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00031, test err=0.321
# Trial 0, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00026, test err=0.321
# Trial 1, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.37819, test err=0.874
# Trial 1, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00259, test err=0.307
# Trial 1, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00111, test err=0.308
# Trial 1, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00069, test err=0.307
# Trial 1, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00049, test err=0.307
# Trial 1, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00038, test err=0.307
# Trial 1, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00031, test err=0.307
# Trial 1, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00026, test err=0.307
# Trial 2, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.34528, test err=0.927
# Trial 2, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00263, test err=0.307
# Trial 2, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00112, test err=0.307
# Trial 2, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00069, test err=0.307
# Trial 2, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00050, test err=0.308
# Trial 2, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00038, test err=0.308
# Trial 2, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00031, test err=0.308
# Trial 2, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00026, test err=0.308
# Trial 3, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.30549, test err=0.877
# Trial 3, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00267, test err=0.310
# Trial 3, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00114, test err=0.309
# Trial 3, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00070, test err=0.309
# Trial 3, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00050, test err=0.309
# Trial 3, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00039, test err=0.309
# Trial 3, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00031, test err=0.309
# Trial 3, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00026, test err=0.309
# Trial 4, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.36642, test err=0.812
# Trial 4, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00265, test err=0.336
# Trial 4, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00113, test err=0.335
# Trial 4, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00070, test err=0.335
# Trial 4, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00050, test err=0.335
# Trial 4, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00039, test err=0.335
# Trial 4, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00031, test err=0.335
# Trial 4, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00026, test err=0.335
# Trial 5, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.30668, test err=0.812
# Trial 5, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00265, test err=0.318
# Trial 5, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00113, test err=0.317
# Trial 5, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00070, test err=0.317
# Trial 5, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00050, test err=0.317
# Trial 5, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00038, test err=0.317
# Trial 5, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00031, test err=0.317
# Trial 5, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00026, test err=0.317
# Trial 6, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.32307, test err=0.888
# Trial 6, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00267, test err=0.306
# Trial 6, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00114, test err=0.306
# Trial 6, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00070, test err=0.306
# Trial 6, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00050, test err=0.306
# Trial 6, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00039, test err=0.306
# Trial 6, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00031, test err=0.307
# Trial 6, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00026, test err=0.307
# Trial 7, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.32346, test err=0.883
# Trial 7, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00266, test err=0.321
# Trial 7, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00113, test err=0.320
# Trial 7, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00070, test err=0.320
# Trial 7, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00050, test err=0.319
# Trial 7, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00039, test err=0.319
# Trial 7, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00031, test err=0.319
# Trial 7, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00026, test err=0.319
# Trial 8, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.35864, test err=0.855
# Trial 8, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00257, test err=0.317
# Trial 8, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00110, test err=0.318
# Trial 8, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00068, test err=0.318
# Trial 8, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00049, test err=0.318
# Trial 8, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00038, test err=0.317
# Trial 8, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00030, test err=0.317
# Trial 8, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00026, test err=0.317
# Trial 9, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.31350, test err=0.854
# Trial 9, Epoch: 1000, He model, h=50, lr=0.10000, Loss=0.00261, test err=0.322
# Trial 9, Epoch: 2000, He model, h=50, lr=0.10000, Loss=0.00112, test err=0.321
# Trial 9, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.00069, test err=0.321
# Trial 9, Epoch: 4000, He model, h=50, lr=0.10000, Loss=0.00049, test err=0.322
# Trial 9, Epoch: 5000, He model, h=50, lr=0.10000, Loss=0.00038, test err=0.321
# Trial 9, Epoch: 6000, He model, h=50, lr=0.10000, Loss=0.00031, test err=0.321
# Trial 9, Epoch: 7000, He model, h=50, lr=0.10000, Loss=0.00026, test err=0.321
# Trial 0, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.52590, test err=0.888
# Trial 0, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.00016, test err=0.314
# Trial 0, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.00007, test err=0.312
# Trial 0, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.00005, test err=0.312
# Trial 0, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.312
# Trial 0, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.311
# Trial 0, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.311
# Trial 0, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.311
# Trial 1, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.40031, test err=0.708
# Trial 1, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.00017, test err=0.313
# Trial 1, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.00008, test err=0.312
# Trial 1, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.00005, test err=0.312
# Trial 1, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=0.00004, test err=0.312
# Trial 1, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.312
# Trial 1, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.312
# Trial 1, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.311
# Trial 2, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.54863, test err=0.790
# Trial 2, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.00017, test err=0.339
# Trial 2, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.00008, test err=0.338
# Trial 2, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.00005, test err=0.337
# Trial 2, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=0.00004, test err=0.336
# Trial 2, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.336
# Trial 2, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.336
# Trial 2, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.336
# Trial 3, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.52707, test err=0.900
# Trial 3, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.00017, test err=0.303
# Trial 3, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.00008, test err=0.305
# Trial 3, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.00005, test err=0.304
# Trial 3, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=0.00004, test err=0.303
# Trial 3, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.303
# Trial 3, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.303
# Trial 3, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.303
# Trial 4, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.69553, test err=0.864
# Trial 4, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.00016, test err=0.301
# Trial 4, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.00008, test err=0.303
# Trial 4, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.00005, test err=0.303
# Trial 4, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=0.00004, test err=0.304
# Trial 4, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.304
# Trial 4, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.305
# Trial 4, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.305
# Trial 5, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.39447, test err=0.686
# Trial 5, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.00016, test err=0.305
# Trial 5, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.00008, test err=0.304
# Trial 5, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.00005, test err=0.304
# Trial 5, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=0.00004, test err=0.304
# Trial 5, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.304
# Trial 5, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.304
# Trial 5, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.304
# Trial 6, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.49686, test err=0.668
# Trial 6, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.00017, test err=0.327
# Trial 6, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.00008, test err=0.326
# Trial 6, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.00005, test err=0.325
# Trial 6, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.325
# Trial 6, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.325
# Trial 6, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.324
# Trial 6, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.324
# Trial 7, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.69805, test err=0.775
# Trial 7, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.00016, test err=0.310
# Trial 7, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.00008, test err=0.309
# Trial 7, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.00005, test err=0.309
# Trial 7, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.309
# Trial 7, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.309
# Trial 7, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.309
# Trial 7, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.309
# Trial 8, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.34797, test err=0.787
# Trial 8, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.00016, test err=0.325
# Trial 8, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.00007, test err=0.324
# Trial 8, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.00005, test err=0.322
# Trial 8, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.322
# Trial 8, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.322
# Trial 8, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.322
# Trial 8, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.322
# Trial 9, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.62208, test err=0.897
# Trial 9, Epoch: 1000, V1 model, h=50, lr=1.00000, Loss=0.00017, test err=0.308
# Trial 9, Epoch: 2000, V1 model, h=50, lr=1.00000, Loss=0.00008, test err=0.308
# Trial 9, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=0.00005, test err=0.307
# Trial 9, Epoch: 4000, V1 model, h=50, lr=1.00000, Loss=0.00004, test err=0.306
# Trial 9, Epoch: 5000, V1 model, h=50, lr=1.00000, Loss=0.00003, test err=0.306
# Trial 9, Epoch: 6000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.305
# Trial 9, Epoch: 7000, V1 model, h=50, lr=1.00000, Loss=0.00002, test err=0.305
# Trial 0, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.30971, test err=0.795
# Trial 0, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.00015, test err=0.305
# Trial 0, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.00007, test err=0.307
# Trial 0, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.00004, test err=0.308
# Trial 0, Epoch: 4000, He model, h=50, lr=1.00000, Loss=0.00003, test err=0.308
# Trial 0, Epoch: 5000, He model, h=50, lr=1.00000, Loss=0.00003, test err=0.308
# Trial 0, Epoch: 6000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.308
# Trial 0, Epoch: 7000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.308
# Trial 1, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.29037, test err=0.571
# Trial 1, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.00016, test err=0.318
# Trial 1, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.00007, test err=0.318
# Trial 1, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.00005, test err=0.318
# Trial 1, Epoch: 4000, He model, h=50, lr=1.00000, Loss=0.00003, test err=0.317
# Trial 1, Epoch: 5000, He model, h=50, lr=1.00000, Loss=0.00003, test err=0.318
# Trial 1, Epoch: 6000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.318
# Trial 1, Epoch: 7000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.317
# Trial 2, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.30188, test err=0.680
# Trial 2, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.00016, test err=0.326
# Trial 2, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.00007, test err=0.326
# Trial 2, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.00005, test err=0.326
# Trial 2, Epoch: 4000, He model, h=50, lr=1.00000, Loss=0.00003, test err=0.325
# Trial 2, Epoch: 5000, He model, h=50, lr=1.00000, Loss=0.00003, test err=0.325
# Trial 2, Epoch: 6000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.325
# Trial 2, Epoch: 7000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.324
# Trial 3, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.35068, test err=0.656
# Trial 3, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.00016, test err=0.334
# Trial 3, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.00007, test err=0.333
# Trial 3, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.00005, test err=0.333
# Trial 3, Epoch: 4000, He model, h=50, lr=1.00000, Loss=0.00003, test err=0.332
# Trial 3, Epoch: 5000, He model, h=50, lr=1.00000, Loss=0.00003, test err=0.333
# Trial 3, Epoch: 6000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.333
# Trial 3, Epoch: 7000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.332
# Trial 4, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.35682, test err=0.564
# Trial 4, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.00016, test err=0.309
# Trial 4, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.00008, test err=0.310
# Trial 4, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.00005, test err=0.311
# Trial 4, Epoch: 4000, He model, h=50, lr=1.00000, Loss=0.00004, test err=0.311
# Trial 4, Epoch: 5000, He model, h=50, lr=1.00000, Loss=0.00003, test err=0.311
# Trial 4, Epoch: 6000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.311
# Trial 4, Epoch: 7000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.311
# Trial 5, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.31698, test err=0.681
# Trial 5, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.00015, test err=0.314
# Trial 5, Epoch: 2000, He model, h=50, lr=1.00000, Loss=0.00007, test err=0.315
# Trial 5, Epoch: 3000, He model, h=50, lr=1.00000, Loss=0.00005, test err=0.315
# Trial 5, Epoch: 4000, He model, h=50, lr=1.00000, Loss=0.00003, test err=0.316
# Trial 5, Epoch: 5000, He model, h=50, lr=1.00000, Loss=0.00003, test err=0.317
# Trial 5, Epoch: 6000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.317
# Trial 5, Epoch: 7000, He model, h=50, lr=1.00000, Loss=0.00002, test err=0.318
# Trial 6, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.34595, test err=0.673
# Trial 6, Epoch: 1000, He model, h=50, lr=1.00000, Loss=0.00015, test err=0.320
# ...
# Trial 5, Epoch: 1000, He model, h=1000, lr=0.10000, Loss=0.00214, test err=0.311
# Trial 5, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.00096, test err=0.310
# Trial 5, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.00060, test err=0.311
# Trial 5, Epoch: 4000, He model, h=1000, lr=0.10000, Loss=0.00044, test err=0.310
# Trial 5, Epoch: 5000, He model, h=1000, lr=0.10000, Loss=0.00034, test err=0.310
# Trial 5, Epoch: 6000, He model, h=1000, lr=0.10000, Loss=0.00028, test err=0.310
# Trial 5, Epoch: 7000, He model, h=1000, lr=0.10000, Loss=0.00023, test err=0.310
# Trial 6, Epoch: 0, He model, h=1000, lr=0.10000, Loss=2.33279, test err=0.693
# Trial 6, Epoch: 1000, He model, h=1000, lr=0.10000, Loss=0.00211, test err=0.316
# Trial 6, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.00095, test err=0.317
# Trial 6, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.00060, test err=0.318
# Trial 6, Epoch: 4000, He model, h=1000, lr=0.10000, Loss=0.00043, test err=0.318
# Trial 6, Epoch: 5000, He model, h=1000, lr=0.10000, Loss=0.00034, test err=0.318
# Trial 6, Epoch: 6000, He model, h=1000, lr=0.10000, Loss=0.00027, test err=0.317
# Trial 6, Epoch: 7000, He model, h=1000, lr=0.10000, Loss=0.00023, test err=0.317
# Trial 7, Epoch: 0, He model, h=1000, lr=0.10000, Loss=2.27888, test err=0.715
# Trial 7, Epoch: 1000, He model, h=1000, lr=0.10000, Loss=0.00214, test err=0.308
# Trial 7, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.00096, test err=0.309
# Trial 7, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.00061, test err=0.309
# Trial 7, Epoch: 4000, He model, h=1000, lr=0.10000, Loss=0.00044, test err=0.309
# Trial 7, Epoch: 5000, He model, h=1000, lr=0.10000, Loss=0.00034, test err=0.309
# Trial 7, Epoch: 6000, He model, h=1000, lr=0.10000, Loss=0.00028, test err=0.309
# Trial 7, Epoch: 7000, He model, h=1000, lr=0.10000, Loss=0.00023, test err=0.309
# Trial 8, Epoch: 0, He model, h=1000, lr=0.10000, Loss=2.30496, test err=0.720
# Trial 8, Epoch: 1000, He model, h=1000, lr=0.10000, Loss=0.00217, test err=0.313
# Trial 8, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.00097, test err=0.313
# Trial 8, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.00061, test err=0.313
# Trial 8, Epoch: 4000, He model, h=1000, lr=0.10000, Loss=0.00044, test err=0.313
# Trial 8, Epoch: 5000, He model, h=1000, lr=0.10000, Loss=0.00034, test err=0.313
# Trial 8, Epoch: 6000, He model, h=1000, lr=0.10000, Loss=0.00028, test err=0.313
# Trial 8, Epoch: 7000, He model, h=1000, lr=0.10000, Loss=0.00024, test err=0.313
# Trial 9, Epoch: 0, He model, h=1000, lr=0.10000, Loss=2.34680, test err=0.693
# Trial 9, Epoch: 1000, He model, h=1000, lr=0.10000, Loss=0.00215, test err=0.310
# Trial 9, Epoch: 2000, He model, h=1000, lr=0.10000, Loss=0.00096, test err=0.311
# Trial 9, Epoch: 3000, He model, h=1000, lr=0.10000, Loss=0.00061, test err=0.311
# Trial 9, Epoch: 4000, He model, h=1000, lr=0.10000, Loss=0.00044, test err=0.311
# Trial 9, Epoch: 5000, He model, h=1000, lr=0.10000, Loss=0.00034, test err=0.311
# Trial 9, Epoch: 6000, He model, h=1000, lr=0.10000, Loss=0.00028, test err=0.311
# Trial 9, Epoch: 7000, He model, h=1000, lr=0.10000, Loss=0.00023, test err=0.311
# Trial 0, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.45572, test err=0.897
# Trial 0, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.00013, test err=0.325
# Trial 0, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00006, test err=0.323
# Trial 0, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00004, test err=0.321
# Trial 0, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=0.00003, test err=0.320
# Trial 0, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.319
# Trial 0, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.318
# Trial 0, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.317
# Trial 1, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.49790, test err=0.795
# Trial 1, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.00012, test err=0.302
# Trial 1, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00006, test err=0.300
# Trial 1, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00004, test err=0.298
# Trial 1, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=0.00003, test err=0.298
# Trial 1, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.298
# Trial 1, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.298
# Trial 1, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=0.00001, test err=0.297
# Trial 2, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.67598, test err=0.806
# Trial 2, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.00014, test err=0.328
# Trial 2, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00006, test err=0.323
# Trial 2, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00004, test err=0.321
# Trial 2, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=0.00003, test err=0.320
# Trial 2, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.319
# Trial 2, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.318
# Trial 2, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.318
# Trial 3, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.41133, test err=0.891
# Trial 3, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.00013, test err=0.327
# Trial 3, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00006, test err=0.325
# Trial 3, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00004, test err=0.323
# Trial 3, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=0.00003, test err=0.322
# Trial 3, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.321
# Trial 3, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.321
# Trial 3, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.320
# Trial 4, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.64891, test err=0.821
# Trial 4, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.00013, test err=0.292
# Trial 4, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00006, test err=0.289
# Trial 4, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00004, test err=0.287
# Trial 4, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=0.00003, test err=0.286
# Trial 4, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.286
# Trial 4, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.286
# Trial 4, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.286
# Trial 5, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.46929, test err=0.822
# Trial 5, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.00013, test err=0.262
# Trial 5, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00006, test err=0.260
# Trial 5, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00004, test err=0.260
# Trial 5, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=0.00003, test err=0.260
# Trial 5, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.259
# Trial 5, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.259
# Trial 5, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.259
# Trial 6, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.58127, test err=0.721
# Trial 6, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.00013, test err=0.311
# Trial 6, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00006, test err=0.309
# Trial 6, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00004, test err=0.308
# Trial 6, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=0.00003, test err=0.307
# Trial 6, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.308
# Trial 6, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.307
# Trial 6, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.307
# Trial 7, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.71113, test err=0.773
# Trial 7, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.00013, test err=0.265
# Trial 7, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00006, test err=0.263
# Trial 7, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00004, test err=0.263
# Trial 7, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=0.00003, test err=0.263
# Trial 7, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.262
# Trial 7, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.262
# Trial 7, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.262
# Trial 8, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.78541, test err=0.882
# Trial 8, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.00013, test err=0.288
# Trial 8, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00006, test err=0.287
# Trial 8, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00004, test err=0.287
# Trial 8, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=0.00003, test err=0.286
# Trial 8, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.286
# Trial 8, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.286
# Trial 8, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.285
# Trial 9, Epoch: 0, V1 model, h=1000, lr=1.00000, Loss=2.50143, test err=0.847
# Trial 9, Epoch: 1000, V1 model, h=1000, lr=1.00000, Loss=0.00013, test err=0.278
# Trial 9, Epoch: 2000, V1 model, h=1000, lr=1.00000, Loss=0.00006, test err=0.277
# Trial 9, Epoch: 3000, V1 model, h=1000, lr=1.00000, Loss=0.00004, test err=0.275
# Trial 9, Epoch: 4000, V1 model, h=1000, lr=1.00000, Loss=0.00003, test err=0.273
# Trial 9, Epoch: 5000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.273
# Trial 9, Epoch: 6000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.273
# Trial 9, Epoch: 7000, V1 model, h=1000, lr=1.00000, Loss=0.00002, test err=0.272
# Trial 0, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.31443, test err=0.622
# Trial 0, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.00015, test err=0.316
# Trial 0, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00007, test err=0.315
# Trial 0, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00004, test err=0.315
# Trial 0, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.316
# Trial 0, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.315
# Trial 0, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.315
# Trial 0, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.315
# Trial 1, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.24886, test err=0.537
# Trial 1, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.00015, test err=0.305
# Trial 1, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00007, test err=0.306
# Trial 1, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00004, test err=0.306
# Trial 1, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.306
# Trial 1, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.306
# Trial 1, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.306
# Trial 1, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.305
# Trial 2, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.33256, test err=0.627
# Trial 2, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.00015, test err=0.313
# Trial 2, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00007, test err=0.313
# Trial 2, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00005, test err=0.314
# Trial 2, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.314
# Trial 2, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.314
# Trial 2, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.314
# Trial 2, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.314
# Trial 3, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.29880, test err=0.507
# Trial 3, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.00015, test err=0.308
# Trial 3, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00007, test err=0.308
# Trial 3, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00004, test err=0.308
# Trial 3, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.308
# Trial 3, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.308
# Trial 3, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.307
# Trial 3, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.308
# Trial 4, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.29600, test err=0.684
# Trial 4, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.00015, test err=0.311
# Trial 4, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00007, test err=0.313
# Trial 4, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00005, test err=0.313
# Trial 4, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.313
# Trial 4, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.313
# Trial 4, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.313
# Trial 4, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.312
# Trial 5, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.30059, test err=0.643
# Trial 5, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.00015, test err=0.304
# Trial 5, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00007, test err=0.304
# Trial 5, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00005, test err=0.304
# Trial 5, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.304
# Trial 5, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.304
# Trial 5, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.304
# Trial 5, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.304
# Trial 6, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.32775, test err=0.624
# Trial 6, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.00015, test err=0.310
# Trial 6, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00007, test err=0.311
# Trial 6, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00005, test err=0.310
# Trial 6, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.310
# Trial 6, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.310
# Trial 6, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.310
# Trial 6, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.311
# Trial 7, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.32082, test err=0.784
# Trial 7, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.00015, test err=0.310
# Trial 7, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00007, test err=0.310
# Trial 7, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00005, test err=0.310
# Trial 7, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.310
# Trial 7, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.310
# Trial 7, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.310
# Trial 7, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.310
# Trial 8, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.31236, test err=0.516
# Trial 8, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.00015, test err=0.311
# Trial 8, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00007, test err=0.311
# Trial 8, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00005, test err=0.311
# Trial 8, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.312
# Trial 8, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.312
# Trial 8, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.312
# Trial 8, Epoch: 7000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.312
# Trial 9, Epoch: 0, He model, h=1000, lr=1.00000, Loss=2.33686, test err=0.799
# Trial 9, Epoch: 1000, He model, h=1000, lr=1.00000, Loss=0.00015, test err=0.309
# Trial 9, Epoch: 2000, He model, h=1000, lr=1.00000, Loss=0.00007, test err=0.309
# Trial 9, Epoch: 3000, He model, h=1000, lr=1.00000, Loss=0.00005, test err=0.310
# Trial 9, Epoch: 4000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.311
# Trial 9, Epoch: 5000, He model, h=1000, lr=1.00000, Loss=0.00003, test err=0.311
# Trial 9, Epoch: 6000, He model, h=1000, lr=1.00000, Loss=0.00002, test err=0.310

# %% [markdown]
# ## plot results

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

t, l, n_epochs= 5, 2, 7001
models = ['V1', 'He']
h_list = [50, 100, 400, 1000]
lr_list = [1e-3, 1e-2, 1e-1, 1e0]

for h in h_list:
    for lr in lr_list:
        with open('results/initialize_mnist/fewshot_data/clf_t=%0.2f_l=%0.2f.pickle' % (t, l), 'rb') as handle:
            sims = pickle.load(handle)

        fig = plt.figure(figsize=(12, 5))
        plt.suptitle(r'Shallow FFW FC net w/ GD. h=%d, lr=%0.4f, '% (h, lr), fontsize=16)
        
        # loss
        ax = fig.add_subplot(131)
        plt.title('Network loss', fontsize=16)
        for m in models:
            avg_loss = np.mean(sims['loss'][m][h][lr], axis=0)
            std_loss = np.std(sims['loss'][m][h][lr], axis=0)                       
            plt.plot(np.arange(n_epochs), avg_loss, label=m, lw=3)
            plt.fill_between(np.arange(n_epochs), avg_loss - std_loss, avg_loss + std_loss, alpha=0.2)
        plt.xlabel('Epoch', fontsize=20)
        plt.ylabel('Training loss', fontsize=20)
        ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
        plt.yscale('log')
        plt.legend(fontsize=18)
        
        # train err
        ax = fig.add_subplot(132)
        plt.title('Train error', fontsize=16)
        for m in models:
            avg_train_err = np.mean(sims['train_err'][m][h][lr], axis=0)
            std_train_err = np.std(sims['train_err'][m][h][lr], axis=0)
            plt.plot(np.arange(n_epochs), avg_train_err, label=m, lw=3)
            plt.fill_between(np.arange(n_epochs), avg_train_err - std_train_err, avg_train_err + std_train_err,  alpha=0.2)
        
        plt.xlabel('Epoch', fontsize=20)
        plt.ylabel('Training error', fontsize=20)
        ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
        plt.yticks(np.arange(0, 1, 0.2))
        plt.yscale('log')
        plt.legend(fontsize=18)

        # test err
        ax = fig.add_subplot(133)
        plt.title('Test error', fontsize=16)
        for m in models:
            avg_test_err = np.mean(sims['test_err'][m][h][lr], axis=0)
            std_test_err = np.std(sims['test_err'][m][h][lr], axis=0)
            plt.plot(np.arange(n_epochs), avg_test_err, label=m, lw=3)
            plt.fill_between(np.arange(n_epochs), avg_test_err - std_test_err, avg_test_err + std_test_err, alpha=0.2)

        plt.xlabel('Epoch', fontsize=20)
        plt.ylabel('Test error', fontsize=20)
        ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
        plt.yticks(np.arange(0, 1, 0.2))
        plt.yscale('log')
        plt.legend(fontsize=18)

        plt.tight_layout()
        plt.subplots_adjust(top=0.8)    

        print(h, lr)
        plt.savefig('results/initialize_mnist/fewshot_data/init_t=%0.2f_l=%0.2f_h=%d_lr=%0.4f.png' % (t, l, h, lr))
        plt.close()
# Out:
# 50 0.001
# 50 0.01
# 50 0.1
# 50 1.0
# 100 0.001
# 100 0.01
# 100 0.1
# 100 1.0
# 400 0.001
# 400 0.01
# 400 0.1
# 400 1.0
# 1000 0.001
# 1000 0.01
# 1000 0.1
# 1000 1.0

# %%
# !nvidia-smi
# Out:
# Fri Oct 23 07:07:47 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.100      Driver Version: 440.100      CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  TITAN Xp            Off  | 00000000:01:00.0 Off |                  N/A |
# | 53%   83C    P2   177W / 250W |    891MiB / 12196MiB |     98%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  TITAN Xp            Off  | 00000000:02:00.0 Off |                  N/A |
# | 53%   83C    P2   247W / 250W |   1929MiB / 12196MiB |     98%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |    0     21223      C   /home/bpandey/anaconda3/bin/python           879MiB |
# |    1     16725      C   /home/bpandey/anaconda3/bin/python          1917MiB |
# +-----------------------------------------------------------------------------+

# %%
np.random.multivariate_normal((5, 3), np.eye(2))
# Out:
# array([5.1084552 , 3.62522326])

# %%
np.random.uniform(2, 8, (4, 2))
# Out:
# array([[2.37671816, 4.76704288],
#        [6.09796859, 7.535352  ],
#        [3.59056167, 6.16788591],
#        [4.89921963, 7.49935599]])
