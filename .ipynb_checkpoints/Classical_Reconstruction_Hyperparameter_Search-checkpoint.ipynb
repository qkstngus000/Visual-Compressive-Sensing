# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.linalg as la

from src.structured_random_features.src.models.weights import V1_weights

# Packages for fft and fitting data
from scipy import fftpack as fft
from sklearn.linear_model import Lasso

# Package for importing image representation
from PIL import Image, ImageOps

from src.V1_Compress import generate_Y, compress
import pandas as pd
import itertools
import dask
from dask.distributed import Client, progress
import seaborn as sns
import time
import os.path

# %%
## Check if this function is applicable to regular compress sensing
classical_img = Image.open("image/city_part3.png")
classical_img = ImageOps.grayscale(classical_img)
classical_arr = np.asarray(classical_img)
cn, cm = classical_arr.shape
print(cn, cm)
classical_samp_list = [100, 200, 500]
alpha = np.logspace(-3, 3, 7)
rep = np.arange(10)
params = []
results = []

# List to make combination of
search_list = {'repetition': rep,
               'alpha': alpha,
               'classical_samp_list': classical_samp_list
              }



# Get repetition * alpha combination amount of result
for row in itertools.product(*search_list.values()):
    product = dict(zip(search_list.keys(), row))
    rep, alp, classical_samp = product.values()
    
    rand_index = np.random.randint(0, cn * cm, classical_samp)
    classical_Y = classical_arr.flatten()[rand_index]
    classical_Y = classical_Y.reshape(classical_samp, 1)

    # Generate C matrix
    C = np.eye(cn * cm)[rand_index, :] * np.sqrt(cn * cm) # 여기서 C 매트릭스를 스케일 해도 결과값이 안달라지는데 교수에게 물어보기
    C3D = C.reshape(classical_samp, cn, cm)
    theta, classical_reform, s = compress(C3D, classical_Y, alp)
    
    error = np.linalg.norm(classical_arr - classical_reform, 'fro') / np.sqrt(cm*cn)
    
    params.append({'classical_samp' : classical_samp,
                   'alpha' : alp,
                   'repetition' : rep,
                   'error' : error
                  })
    results.append({'s' : s,
                    'theta' : theta,
                    'reform' : classical_reform,
                   })
# Out:
# 30 30
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 43.721509990941776, tolerance: 24.826875
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 59.61233632245509, tolerance: 46.14853550000001
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 153.57557837193707, tolerance: 117.26312220000001
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 61.09360849696416, tolerance: 28.026636
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98.94201946655238, tolerance: 43.386999499999995
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 152.90620731327977, tolerance: 110.54007420000002
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.516078804439225, tolerance: 27.005875
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 67.8538546205373, tolerance: 46.769231999999995
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 138.73805193098252, tolerance: 114.54649820000002
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 75.64109399683919, tolerance: 24.888916000000002
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 102.15605040234726, tolerance: 50.9661395
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 211.98270687453186, tolerance: 132.7615752
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.086496641187104, tolerance: 22.086170999999997
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38.39615507400911, tolerance: 21.440490999999998
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 64.73274289694866, tolerance: 48.7011955
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 153.67697216045804, tolerance: 118.11839420000003
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 58.534617999487295, tolerance: 22.065016
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 127.90262980401708, tolerance: 48.5318355
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 177.12470598690058, tolerance: 117.57362719999999
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29.298247911037283, tolerance: 20.085544000000006
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 36.5329364564826, tolerance: 24.288091
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 78.59635918841212, tolerance: 47.93375
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 171.62792759238005, tolerance: 126.24809499999998
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 73.4260029271101, tolerance: 21.892675
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 146.11529085923888, tolerance: 46.727952
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 164.302958905279, tolerance: 124.07079580000001
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.354857033429326, tolerance: 23.732663999999996
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62.92156665516318, tolerance: 40.4719755
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 139.81652764182377, tolerance: 122.8688198
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 56.40429580747662, tolerance: 25.745124
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 116.14242134411721, tolerance: 41.8119955
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 241.91338551714847, tolerance: 118.85073980000001
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.94854621046984, tolerance: 28.507036
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41.494706057803754, tolerance: 25.290200000000002
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 74.70750125407542, tolerance: 49.942142000000004
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 159.14093807659629, tolerance: 121.47228079999998
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62.7587040124743, tolerance: 22.882956
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 98.30080716273453, tolerance: 42.325232
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 203.29054200592063, tolerance: 118.06794880000002
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 32.50865930795958, tolerance: 22.346784
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 81.6447219622678, tolerance: 50.335687500000006
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 199.55314490815945, tolerance: 128.15001180000002
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 67.27718873436503, tolerance: 24.789764
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 107.40057389355043, tolerance: 51.80219950000001
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 193.79508487469758, tolerance: 121.6019608
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.18776393106001, tolerance: 23.420416
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.28288296759831, tolerance: 24.884304000000004
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 82.50227454992505, tolerance: 52.466975500000004
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 166.70783916823024, tolerance: 115.5886088
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 65.70741831034736, tolerance: 25.086451000000004
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 48.869778122905124, tolerance: 46.6747995
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 202.38278183891617, tolerance: 121.08049499999998
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.17962794941194, tolerance: 24.670275
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.81113301009766, tolerance: 20.542904000000004
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 62.30086636409265, tolerance: 41.62779200000001
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 161.57475550965475, tolerance: 104.12641520000001
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 59.97966411813613, tolerance: 28.464691000000006
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 81.1378174713942, tolerance: 40.16975
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 227.02412683772633, tolerance: 132.6987168
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 42.17731151822708, tolerance: 28.500536
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 65.26094387118636, tolerance: 44.32721550000001
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 188.12426772113125, tolerance: 119.74115580000003
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 45.46592785971252, tolerance: 20.068796
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 85.85789086653094, tolerance: 42.761139500000006
#   model = cd_fast.enet_coordinate_descent(

# %%
params
# Out:
# [{'classical_samp': 100,
#   'alpha': 0.001,
#   'repetition': 0,
#   'error': 143.6717030767985},
#  {'classical_samp': 200,
#   'alpha': 0.001,
#   'repetition': 0,
#   'error': 143.5876692098642},
#  {'classical_samp': 500,
#   'alpha': 0.001,
#   'repetition': 0,
#   'error': 143.5117236633597},
#  {'classical_samp': 100,
#   'alpha': 0.01,
#   'repetition': 0,
#   'error': 143.69408220357002},
#  {'classical_samp': 200,
#   'alpha': 0.01,
#   'repetition': 0,
#   'error': 143.66163375276244},
#  {'classical_samp': 500,
#   'alpha': 0.01,
#   'repetition': 0,
#   'error': 143.51305183269645},
#  {'classical_samp': 100,
#   'alpha': 0.1,
#   'repetition': 0,
#   'error': 143.72612337330264},
#  {'classical_samp': 200,
#   'alpha': 0.1,
#   'repetition': 0,
#   'error': 143.66177487546076},
#  {'classical_samp': 500,
#   'alpha': 0.1,
#   'repetition': 0,
#   'error': 143.53751534734326},
#  {'classical_samp': 100,
#   'alpha': 1.0,
#   'repetition': 0,
#   'error': 143.72965205245245},
#  {'classical_samp': 200,
#   'alpha': 1.0,
#   'repetition': 0,
#   'error': 143.70697749776235},
#  {'classical_samp': 500,
#   'alpha': 1.0,
#   'repetition': 0,
#   'error': 143.56743932138534},
#  {'classical_samp': 100,
#   'alpha': 10.0,
#   'repetition': 0,
#   'error': 143.8114275800028},
#  {'classical_samp': 200,
#   'alpha': 10.0,
#   'repetition': 0,
#   'error': 143.84989167119065},
#  {'classical_samp': 500,
#   'alpha': 10.0,
#   'repetition': 0,
#   'error': 143.83863507159094},
#  {'classical_samp': 100,
#   'alpha': 100.0,
#   'repetition': 0,
#   'error': 143.8869849723888},
#  {'classical_samp': 200,
#   'alpha': 100.0,
#   'repetition': 0,
#   'error': 143.8869849723888},
#  {'classical_samp': 500,
#   'alpha': 100.0,
#   'repetition': 0,
#   'error': 143.8869849723888},
#  {'classical_samp': 100,
#   'alpha': 1000.0,
#   'repetition': 0,
#   'error': 143.8869849723888},
#  {'classical_samp': 200,
#   'alpha': 1000.0,
#   'repetition': 0,
#   'error': 143.8869849723888},
#  {'classical_samp': 500,
#   'alpha': 1000.0,
#   'repetition': 0,
#   'error': 143.8869849723888},
#  {'classical_samp': 100,
#   'alpha': 0.001,
#   'repetition': 1,
#   'error': 143.6222443705646},
#  {'classical_samp': 200,
#   'alpha': 0.001,
#   'repetition': 1,
#   'error': 143.61721012504776},
#  {'classical_samp': 500,
#   'alpha': 0.001,
#   'repetition': 1,
#   'error': 143.48575841807732},
#  {'classical_samp': 100,
#   'alpha': 0.01,
#   'repetition': 1,
#   'error': 143.74668234580642},
#  {'classical_samp': 200,
#   'alpha': 0.01,
#   'repetition': 1,
#   'error': 143.64043916580667},
#  {'classical_samp': 500,
#   'alpha': 0.01,
#   'repetition': 1,
#   'error': 143.48865736966587},
#  {'classical_samp': 100,
#   'alpha': 0.1,
#   'repetition': 1,
#   'error': 143.79308837348327},
#  {'classical_samp': 200,
#   'alpha': 0.1,
#   'repetition': 1,
#   'error': 143.67267616296164},
#  {'classical_samp': 500,
#   'alpha': 0.1,
#   'repetition': 1,
#   'error': 143.52624940434072},
#  {'classical_samp': 100,
#   'alpha': 1.0,
#   'repetition': 1,
#   'error': 143.79518806550257},
#  {'classical_samp': 200,
#   'alpha': 1.0,
#   'repetition': 1,
#   'error': 143.66660590564973},
#  {'classical_samp': 500,
#   'alpha': 1.0,
#   'repetition': 1,
#   'error': 143.58329337393855},
#  {'classical_samp': 100,
#   'alpha': 10.0,
#   'repetition': 1,
#   'error': 143.81974270715708},
#  {'classical_samp': 200,
#   'alpha': 10.0,
#   'repetition': 1,
#   'error': 143.81434538543664},
#  {'classical_samp': 500,
#   'alpha': 10.0,
#   'repetition': 1,
#   'error': 143.8480770979132},
#  {'classical_samp': 100,
#   'alpha': 100.0,
#   'repetition': 1,
#   'error': 143.8869849723888},
#  {'classical_samp': 200,
#   'alpha': 100.0,
#   'repetition': 1,
#   'error': 143.8869849723888},
#  {'classical_samp': 500,
#   'alpha': 100.0,
#   'repetition': 1,
#   'error': 143.8869849723888},
#  {'classical_samp': 100,
#   'alpha': 1000.0,
#   'repetition': 1,
#   'error': 143.8869849723888},
#  {'classical_samp': 200,
#   'alpha': 1000.0,
#   'repetition': 1,
#   'error': 143.8869849723888},
#  {'classical_samp': 500,
#   'alpha': 1000.0,
#   'repetition': 1,
#   'error': 143.8869849723888},
#  {'classical_samp': 100,
#   'alpha': 0.001,
#   'repetition': 2,
#   'error': 143.68511973354805},
#  {'classical_samp': 200,
#   'alpha': 0.001,
#   'repetition': 2,
#   'error': 143.5555526575474},
#  {'classical_samp': 500,
#   'alpha': 0.001,
#   'repetition': 2,
#   'error': 143.50609470273943},
#  {'classical_samp': 100,
#   'alpha': 0.01,
#   'repetition': 2,
#   'error': 143.74508115490954},
#  {'classical_samp': 200,
#   'alpha': 0.01,
#   'repetition': 2,
#   'error': 143.6766576981372},
#  {'classical_samp': 500,
#   'alpha': 0.01,
#   'repetition': 2,
#   'error': 143.50104470682672},
#  {'classical_samp': 100,
#   'alpha': 0.1,
#   'repetition': 2,
#   'error': 143.81810688112472},
#  {'classical_samp': 200,
#   'alpha': 0.1,
#   'repetition': 2,
#   'error': 143.668221111884},
#  {'classical_samp': 500,
#   'alpha': 0.1,
#   'repetition': 2,
#   'error': 143.498852269499},
#  {'classical_samp': 100,
#   'alpha': 1.0,
#   'repetition': 2,
#   'error': 143.7446964350639},
#  {'classical_samp': 200,
#   'alpha': 1.0,
#   'repetition': 2,
#   'error': 143.64274821408202},
#  {'classical_samp': 500,
#   'alpha': 1.0,
#   'repetition': 2,
#   'error': 143.5809189925934},
#  {'classical_samp': 100,
#   'alpha': 10.0,
#   'repetition': 2,
#   'error': 143.8282129410046},
#  {'classical_samp': 200,
#   'alpha': 10.0,
#   'repetition': 2,
#   'error': 143.84308042910095},
#  {'classical_samp': 500,
#   'alpha': 10.0,
#   'repetition': 2,
#   'error': 143.8241537554002},
#  {'classical_samp': 100,
#   'alpha': 100.0,
#   'repetition': 2,
#   'error': 143.8869849723888},
#  {'classical_samp': 200,
#   'alpha': 100.0,
#   'repetition': 2,
#   'error': 143.8869849723888},
#  {'classical_samp': 500,
#   'alpha': 100.0,
#   'repetition': 2,
#   'error': 143.8869849723888},
#  {'classical_samp': 100,
#   'alpha': 1000.0,
#   'repetition': 2,
#   'error': 143.8869849723888},
#  {'classical_samp': 200,
#   'alpha': 1000.0,
#   'repetition': 2,
#   'error': 143.8869849723888},
#  {'classical_samp': 500,
#   'alpha': 1000.0,
#   'repetition': 2,
#   'error': 143.8869849723888},
#  {'classical_samp': 100,
#   'alpha': 0.001,
#   'repetition': 3,
#   'error': 143.64089064845604},
#  {'classical_samp': 200,
#   'alpha': 0.001,
#   'repetition': 3,
#   'error': 143.5959903064373},
#  {'classical_samp': 500,
#   'alpha': 0.001,
#   'repetition': 3,
#   'error': 143.47057107995988},
#  {'classical_samp': 100,
#   'alpha': 0.01,
#   'repetition': 3,
#   'error': 143.76101337264703},
#  {'classical_samp': 200,
#   'alpha': 0.01,
#   'repetition': 3,
#   'error': 143.6890322947478},
#  {'classical_samp': 500,
#   'alpha': 0.01,
#   'repetition': 3,
#   'error': 143.49527293937174},
#  {'classical_samp': 100,
#   'alpha': 0.1,
#   'repetition': 3,
#   'error': 143.76942655725097},
#  {'classical_samp': 200,
#   'alpha': 0.1,
#   'repetition': 3,
#   'error': 143.657423221655},
#  {'classical_samp': 500,
#   'alpha': 0.1,
#   'repetition': 3,
#   'error': 143.5191512572698},
#  {'classical_samp': 100,
#   'alpha': 1.0,
#   'repetition': 3,
#   'error': 143.72950153737034},
#  {'classical_samp': 200,
#   'alpha': 1.0,
#   'repetition': 3,
#   'error': 143.73273053335032},
#  {'classical_samp': 500,
#   'alpha': 1.0,
#   'repetition': 3,
#   'error': 143.57126551233654},
#  {'classical_samp': 100,
#   'alpha': 10.0,
#   'repetition': 3,
#   'error': 143.85060439007265},
#  {'classical_samp': 200,
#   'alpha': 10.0,
#   'repetition': 3,
#   'error': 143.82244789140665},
#  {'classical_samp': 500,
#   'alpha': 10.0,
#   'repetition': 3,
#   'error': 143.83003440331922},
#  {'classical_samp': 100,
#   'alpha': 100.0,
#   'repetition': 3,
#   'error': 143.8869849723888},
#  {'classical_samp': 200,
#   'alpha': 100.0,
#   'repetition': 3,
#   'error': 143.8869849723888},
#  {'classical_samp': 500,
#   'alpha': 100.0,
#   'repetition': 3,
#   'error': 143.8869849723888},
#  {'classical_samp': 100,
#   'alpha': 1000.0,
#   'repetition': 3,
#   'error': 143.8869849723888},
#  {'classical_samp': 200,
#   'alpha': 1000.0,
#   'repetition': 3,
#   'error': 143.8869849723888},
#  {'classical_samp': 500,
#   'alpha': 1000.0,
#   'repetition': 3,
#   'error': 143.8869849723888},
#  {'classical_samp': 100,
#   'alpha': 0.001,
#   'repetition': 4,
#   'error': 143.658538827675},
#  {'classical_samp': 200,
#   'alpha': 0.001,
#   'repetition': 4,
#   'error': 143.62060219014242},
#  {'classical_samp': 500,
#   'alpha': 0.001,
#   'repetition': 4,
#   'error': 143.48591243824418},
#  {'classical_samp': 100,
#   'alpha': 0.01,
#   'repetition': 4,
#   'error': 143.70563493743194},
#  {'classical_samp': 200,
#   'alpha': 0.01,
#   'repetition': 4,
#   'error': 143.65238184477903},
#  {'classical_samp': 500,
#   'alpha': 0.01,
#   'repetition': 4,
#   'error': 143.5044915305741},
#  {'classical_samp': 100,
#   'alpha': 0.1,
#   'repetition': 4,
#   'error': 143.7149522490993},
#  {'classical_samp': 200,
#   'alpha': 0.1,
#   'repetition': 4,
#   'error': 143.63360185157552},
#  {'classical_samp': 500,
#   'alpha': 0.1,
#   'repetition': 4,
#   'error': 143.5398004891328},
#  {'classical_samp': 100,
#   'alpha': 1.0,
#   'repetition': 4,
#   'error': 143.708880873425},
#  {'classical_samp': 200,
#   'alpha': 1.0,
#   'repetition': 4,
#   'error': 143.70305739208058},
#  {'classical_samp': 500,
#   'alpha': 1.0,
#   'repetition': 4,
#   'error': 143.56831436017742},
#  {'classical_samp': 100,
#   'alpha': 10.0,
#   'repetition': 4,
#   'error': 143.8162868230167},
#  {'classical_samp': 200,
#   'alpha': 10.0,
#   'repetition': 4,
#   'error': 143.83849329900417},
#  {'classical_samp': 500,
#   'alpha': 10.0,
#   'repetition': 4,
#   'error': 143.85588822670096},
#  {'classical_samp': 100,
#   'alpha': 100.0,
#   'repetition': 4,
#   'error': 143.8869849723888},
#  {'classical_samp': 200,
#   'alpha': 100.0,
#   'repetition': 4,
#   'error': 143.8869849723888},
#  {'classical_samp': 500,
#   'alpha': 100.0,
#   'repetition': 4,
#   'error': 143.8869849723888},
#  {'classical_samp': 100,
#   'alpha': 1000.0,
#   'repetition': 4,
#   'error': 143.8869849723888},
#  {'classical_samp': 200,
#   'alpha': 1000.0,
#   'repetition': 4,
#   'error': 143.8869849723888},
#  {'classical_samp': 500,
#   'alpha': 1000.0,
#   'repetition': 4,
#   'error': 143.8869849723888},
#  {'classical_samp': 100,
#   'alpha': 0.001,
#   'repetition': 5,
#   'error': 143.66211180470083},
#  {'classical_samp': 200,
#   'alpha': 0.001,
#   'repetition': 5,
#   'error': 143.57632350511278},
#  {'classical_samp': 500,
#   'alpha': 0.001,
#   'repetition': 5,
#   'error': 143.488183789713},
#  {'classical_samp': 100,
#   'alpha': 0.01,
#   'repetition': 5,
#   'error': 143.71569870983566},
#  {'classical_samp': 200,
#   'alpha': 0.01,
#   'repetition': 5,
#   'error': 143.64974479790533},
#  {'classical_samp': 500,
#   'alpha': 0.01,
#   'repetition': 5,
#   'error': 143.51105265014613},
#  {'classical_samp': 100,
#   'alpha': 0.1,
#   'repetition': 5,
#   'error': 143.7532235403455},
#  {'classical_samp': 200,
#   'alpha': 0.1,
#   'repetition': 5,
#   'error': 143.6423081393991},
#  {'classical_samp': 500,
#   'alpha': 0.1,
#   'repetition': 5,
#   'error': 143.52628007164498},
#  {'classical_samp': 100,
#   'alpha': 1.0,
#   'repetition': 5,
#   'error': 143.7952740614748},
#  {'classical_samp': 200,
#   'alpha': 1.0,
#   'repetition': 5,
#   'error': 143.65182674536536},
#  {'classical_samp': 500,
#   'alpha': 1.0,
#   'repetition': 5,
#   'error': 143.5642103389103},
#  {'classical_samp': 100,
#   'alpha': 10.0,
#   'repetition': 5,
#   'error': 143.82774148769715},
#  {'classical_samp': 200,
#   'alpha': 10.0,
#   'repetition': 5,
#   'error': 143.83667762937435},
#  {'classical_samp': 500,
#   'alpha': 10.0,
#   'repetition': 5,
#   'error': 143.83006211559703},
#  {'classical_samp': 100,
#   'alpha': 100.0,
#   'repetition': 5,
#   'error': 143.8869849723888},
#  {'classical_samp': 200,
#   'alpha': 100.0,
#   'repetition': 5,
#   'error': 143.8869849723888},
#  {'classical_samp': 500,
#   'alpha': 100.0,
#   'repetition': 5,
#   'error': 143.8869849723888},
#  {'classical_samp': 100,
#   'alpha': 1000.0,
#   'repetition': 5,
#   'error': 143.8869849723888},
#  {'classical_samp': 200,
#   'alpha': 1000.0,
#   'repetition': 5,
#   'error': 143.8869849723888},
#  {'classical_samp': 500,
#   'alpha': 1000.0,
#   'repetition': 5,
#   'error': 143.8869849723888},
#  {'classical_samp': 100,
#   'alpha': 0.001,
#   'repetition': 6,
#   'error': 143.6646907785974},
#  {'classical_samp': 200,
#   'alpha': 0.001,
#   'repetition': 6,
#   'error': 143.58360562803625},
#  {'classical_samp': 500,
#   'alpha': 0.001,
#   'repetition': 6,
#   'error': 143.47953737578365},
#  {'classical_samp': 100,
#   'alpha': 0.01,
#   'repetition': 6,
#   'error': 143.71774981643244},
#  {'classical_samp': 200,
#   'alpha': 0.01,
#   'repetition': 6,
#   'error': 143.59778464777926},
#  {'classical_samp': 500,
#   'alpha': 0.01,
#   'repetition': 6,
#   'error': 143.5176598533353},
#  {'classical_samp': 100,
#   'alpha': 0.1,
#   'repetition': 6,
#   'error': 143.80675638787395},
#  {'classical_samp': 200,
#   'alpha': 0.1,
#   'repetition': 6,
#   'error': 143.66607719268583},
#  {'classical_samp': 500,
#   'alpha': 0.1,
#   'repetition': 6,
#   'error': 143.50683065535932},
#  {'classical_samp': 100,
#   'alpha': 1.0,
#   'repetition': 6,
#   'error': 143.81193860552622},
#  {'classical_samp': 200,
#   'alpha': 1.0,
#   'repetition': 6,
#   'error': 143.66528396074577},
#  {'classical_samp': 500,
#   'alpha': 1.0,
#   'repetition': 6,
#   'error': 143.55329387796635},
#  {'classical_samp': 100,
#   'alpha': 10.0,
#   'repetition': 6,
#   'error': 143.8435447144555},
#  {'classical_samp': 200,
#   'alpha': 10.0,
#   'repetition': 6,
#   'error': 143.82145410767276},
#  {'classical_samp': 500,
#   'alpha': 10.0,
#   'repetition': 6,
#   'error': 143.81929578368099},
#  {'classical_samp': 100,
#   'alpha': 100.0,
#   'repetition': 6,
#   'error': 143.8869849723888},
#  {'classical_samp': 200,
#   'alpha': 100.0,
#   'repetition': 6,
#   'error': 143.8869849723888},
#  {'classical_samp': 500,
#   'alpha': 100.0,
#   'repetition': 6,
#   'error': 143.8869849723888},
#  {'classical_samp': 100,
#   'alpha': 1000.0,
#   'repetition': 6,
#   'error': 143.8869849723888},
#  {'classical_samp': 200,
#   'alpha': 1000.0,
#   'repetition': 6,
#   'error': 143.8869849723888},
#  {'classical_samp': 500,
#   'alpha': 1000.0,
#   'repetition': 6,
#   'error': 143.8869849723888},
#  {'classical_samp': 100,
#   'alpha': 0.001,
#   'repetition': 7,
#   'error': 143.69359619220558},
#  {'classical_samp': 200,
#   'alpha': 0.001,
#   'repetition': 7,
#   'error': 143.58352381864128},
#  {'classical_samp': 500,
#   'alpha': 0.001,
#   'repetition': 7,
#   'error': 143.50476881268006},
#  {'classical_samp': 100,
#   'alpha': 0.01,
#   'repetition': 7,
#   'error': 143.7403088350722},
#  {'classical_samp': 200,
#   'alpha': 0.01,
#   'repetition': 7,
#   'error': 143.60668808440965},
#  {'classical_samp': 500,
#   'alpha': 0.01,
#   'repetition': 7,
#   'error': 143.5146270195555},
#  {'classical_samp': 100,
#   'alpha': 0.1,
#   'repetition': 7,
#   'error': 143.75991919185796},
#  {'classical_samp': 200,
#   'alpha': 0.1,
#   'repetition': 7,
#   'error': 143.6754788442727},
#  {'classical_samp': 500,
#   'alpha': 0.1,
#   'repetition': 7,
#   'error': 143.49634103700132},
#  {'classical_samp': 100,
#   'alpha': 1.0,
#   'repetition': 7,
#   'error': 143.79484548177618},
#  {'classical_samp': 200,
#   'alpha': 1.0,
#   'repetition': 7,
#   'error': 143.6932003842462},
#  {'classical_samp': 500,
#   'alpha': 1.0,
#   'repetition': 7,
#   'error': 143.56696121285677},
#  {'classical_samp': 100,
#   'alpha': 10.0,
#   'repetition': 7,
#   'error': 143.80938002801187},
#  {'classical_samp': 200,
#   'alpha': 10.0,
#   'repetition': 7,
#   'error': 143.87710211914475},
#  {'classical_samp': 500,
#   'alpha': 10.0,
#   'repetition': 7,
#   'error': 143.8454145050557},
#  {'classical_samp': 100,
#   'alpha': 100.0,
#   'repetition': 7,
#   'error': 143.8869849723888},
#  {'classical_samp': 200,
#   'alpha': 100.0,
#   'repetition': 7,
#   'error': 143.8869849723888},
#  {'classical_samp': 500,
#   'alpha': 100.0,
#   'repetition': 7,
#   'error': 143.8869849723888},
#  {'classical_samp': 100,
#   'alpha': 1000.0,
#   'repetition': 7,
#   'error': 143.8869849723888},
#  {'classical_samp': 200,
#   'alpha': 1000.0,
#   'repetition': 7,
#   'error': 143.8869849723888},
#  {'classical_samp': 500,
#   'alpha': 1000.0,
#   'repetition': 7,
#   'error': 143.8869849723888},
#  {'classical_samp': 100,
#   'alpha': 0.001,
#   'repetition': 8,
#   'error': 143.65921270759608},
#  {'classical_samp': 200,
#   'alpha': 0.001,
#   'repetition': 8,
#   'error': 143.6071948057407},
#  {'classical_samp': 500,
#   'alpha': 0.001,
#   'repetition': 8,
#   'error': 143.52781615873917},
#  {'classical_samp': 100,
#   'alpha': 0.01,
#   'repetition': 8,
#   'error': 143.691162089082},
#  {'classical_samp': 200,
#   'alpha': 0.01,
#   'repetition': 8,
#   'error': 143.6607117599232},
#  {'classical_samp': 500,
#   'alpha': 0.01,
#   'repetition': 8,
#   'error': 143.50613186131642},
#  {'classical_samp': 100,
#   'alpha': 0.1,
#   'repetition': 8,
#   'error': 143.7479173252477},
#  {'classical_samp': 200,
#   'alpha': 0.1,
#   'repetition': 8,
#   'error': 143.6768151551359},
#  {'classical_samp': 500,
#   'alpha': 0.1,
#   'repetition': 8,
#   'error': 143.52265151207274},
#  {'classical_samp': 100,
#   'alpha': 1.0,
#   'repetition': 8,
#   'error': 143.79634010302502},
#  {'classical_samp': 200,
#   'alpha': 1.0,
#   'repetition': 8,
#   'error': 143.69721536618584},
#  {'classical_samp': 500,
#   'alpha': 1.0,
#   'repetition': 8,
#   'error': 143.55718867717752},
#  {'classical_samp': 100,
#   'alpha': 10.0,
#   'repetition': 8,
#   'error': 143.8045377242562},
#  {'classical_samp': 200,
#   'alpha': 10.0,
#   'repetition': 8,
#   'error': 143.8244142924665},
#  {'classical_samp': 500,
#   'alpha': 10.0,
#   'repetition': 8,
#   'error': 143.83802865716913},
#  {'classical_samp': 100,
#   'alpha': 100.0,
#   'repetition': 8,
#   'error': 143.8869849723888},
#  {'classical_samp': 200,
#   'alpha': 100.0,
#   'repetition': 8,
#   'error': 143.8869849723888},
#  {'classical_samp': 500,
#   'alpha': 100.0,
#   'repetition': 8,
#   'error': 143.8869849723888},
#  {'classical_samp': 100,
#   'alpha': 1000.0,
#   'repetition': 8,
#   'error': 143.8869849723888},
#  {'classical_samp': 200,
#   'alpha': 1000.0,
#   'repetition': 8,
#   'error': 143.8869849723888},
#  {'classical_samp': 500,
#   'alpha': 1000.0,
#   'repetition': 8,
#   'error': 143.8869849723888},
#  {'classical_samp': 100,
#   'alpha': 0.001,
#   'repetition': 9,
#   'error': 143.65058763399216},
#  {'classical_samp': 200,
#   'alpha': 0.001,
#   'repetition': 9,
#   'error': 143.63962473046442},
#  {'classical_samp': 500,
#   'alpha': 0.001,
#   'repetition': 9,
#   'error': 143.49738759852738},
#  {'classical_samp': 100,
#   'alpha': 0.01,
#   'repetition': 9,
#   'error': 143.74888806073898},
#  {'classical_samp': 200,
#   'alpha': 0.01,
#   'repetition': 9,
#   'error': 143.66143963696487},
#  {'classical_samp': 500,
#   'alpha': 0.01,
#   'repetition': 9,
#   'error': 143.52217739659616},
#  {'classical_samp': 100,
#   'alpha': 0.1,
#   'repetition': 9,
#   'error': 143.81204029797948},
#  {'classical_samp': 200,
#   'alpha': 0.1,
#   'repetition': 9,
#   'error': 143.66286207370618},
#  {'classical_samp': 500,
#   'alpha': 0.1,
#   'repetition': 9,
#   'error': 143.51691913614184},
#  {'classical_samp': 100,
#   'alpha': 1.0,
#   'repetition': 9,
#   'error': 143.75390990309137},
#  {'classical_samp': 200,
#   'alpha': 1.0,
#   'repetition': 9,
#   'error': 143.68077571301535},
#  {'classical_samp': 500,
#   'alpha': 1.0,
#   'repetition': 9,
#   'error': 143.60534423970165},
#  {'classical_samp': 100,
#   'alpha': 10.0,
#   'repetition': 9,
#   'error': 143.82425048765737},
#  {'classical_samp': 200,
#   'alpha': 10.0,
#   'repetition': 9,
#   'error': 143.81680143158968},
#  {'classical_samp': 500,
#   'alpha': 10.0,
#   'repetition': 9,
#   'error': 143.86055771754795},
#  {'classical_samp': 100,
#   'alpha': 100.0,
#   'repetition': 9,
#   'error': 143.8869849723888},
#  {'classical_samp': 200,
#   'alpha': 100.0,
#   'repetition': 9,
#   'error': 143.8869849723888},
#  {'classical_samp': 500,
#   'alpha': 100.0,
#   'repetition': 9,
#   'error': 143.8869849723888},
#  {'classical_samp': 100,
#   'alpha': 1000.0,
#   'repetition': 9,
#   'error': 143.8869849723888},
#  {'classical_samp': 200,
#   'alpha': 1000.0,
#   'repetition': 9,
#   'error': 143.8869849723888},
#  {'classical_samp': 500,
#   'alpha': 1000.0,
#   'repetition': 9,
#   'error': 143.8869849723888}]

# %%
save_path = os.path.join('./result/city_part3/Classical/')

classical_param_df = pd.DataFrame(params)
classical_param_df.to_csv(os.path.join(save_path, "Classical_Param_" + "_".join(str.split(time.ctime().replace(":", "_"))) + ".csv"))

# %%
classical_img = Image.open("image/tree_part1.jpg")
classical_img = ImageOps.grayscale(classical_img)
classical_arr = np.asarray(classical_img)
plt.imshow(classical_arr, vmin = 0, vmax=255)
plt.axis('off')
plt.show()

# %%
## Check if this function is applicable to regular compress sensing
classical_img = Image.open("image/tree_part1.jpg")
classical_img = ImageOps.grayscale(classical_img)
classical_arr = np.asarray(classical_img)
cn, cm = classical_arr.shape
print(cn, cm)
classical_samp_list = [100, 200, 500] #np.floor (cn * cm * 0.20).astype(int)
# Out:
# 30 30

# %%
alpha_list = np.logspace(-3, 3, 7)

for classical_samp in classical_samp_list:
    print('sample at: ', classical_samp)
    for alp in alpha_list:
        # Generate random indexes and find corresponding y value for each index
        rand_index = np.random.permutation(cn * cm)[:classical_samp]
        classical_Y = classical_arr.flatten()[rand_index]
        classical_Y = classical_Y.reshape(classical_samp, 1)

        # Generate C matrix
        C = np.eye(cn * cm)[rand_index, :]# * np.sqrt(cn * cm)
        C3D = C.reshape(classical_samp, cn, cm)
        theta, classical_reform, s = compress(C3D, classical_Y, alp)

        plt.imshow(classical_reform)
        plt.title("Recon.(alp: " + str(alp) + ")")
        plt.show()
# Out:
# sample at:  100
# C:\Users\qkstn\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 61.259901844875216, tolerance: 29.130224000000002
#   model = cd_fast.enet_coordinate_descent(
# sample at:  200
# sample at:  500

# %%
rand_index = np.random.permutation(cn * cm)[:500]
classical_Y = classical_arr.flatten()[rand_index]
classical_Y = classical_Y.reshape(500, 1)

# Generate C matrix
C = np.eye(cn * cm)[rand_index, :] * np.sqrt(cn * cm)
classical_Y = classical_Y * np.sqrt(cn * cm)
C3D = C.reshape(500, cn, cm)
theta, classical_reform, s = compress(C3D, classical_Y, 300)

# %%
plt.imshow(classical_reform, vmin = 0, vmax = 255)
#plt.clim((0, 255))
plt.title("Recon.(alp: 0.003)")
plt.show()

# %%
classical_arr
# Out:
# array([[213, 210, 216, 216, 206, 208, 216, 214, 193, 216, 233, 178, 196,
#         141, 117, 134, 176, 112, 167, 160, 186, 213, 190, 177, 203, 182,
#         195, 202, 185, 180],
#        [220, 206, 204, 208, 208, 214, 215, 204, 228, 227, 203, 159, 174,
#         142,  93,  95, 115, 122, 144, 163, 181, 158, 205, 163, 165, 193,
#         201, 190, 187, 179],
#        [207, 195, 196, 203, 207, 214, 216, 204, 199, 184, 145, 131, 164,
#         171, 115, 105,  70, 102, 101, 117, 125,  86, 147, 109, 143, 204,
#         196, 176, 195, 194],
#        [190, 187, 197, 202, 195, 195, 197, 189, 192, 160, 111,  75, 106,
#         124, 100, 101, 108,  96,  96,  93,  93, 100,  99, 117, 146, 189,
#         174, 170, 192, 203],
#        [198, 194, 200, 202, 190, 180, 169, 152, 183, 172, 167, 112, 129,
#         108,  94,  87, 131, 104,  95, 106, 100, 141, 101, 168, 148, 165,
#         169, 191, 177, 191],
#        [214, 202, 202, 204, 195, 182, 160, 132, 101, 116, 157, 112, 124,
#          88,  79,  67,  91, 105,  71, 105, 101, 119, 101, 162, 147, 162,
#         192, 225, 169, 180],
#        [213, 207, 209, 202, 176, 155, 138, 119, 107, 109, 124,  82,  88,
#          88,  95,  95,  63, 105,  68,  83, 104,  97,  93, 121, 131, 160,
#         186.86144151, 194.87918029, 200.86235086, 192.21201349,
#         180.49233995, 182.4717602 ],
#        [211.02327683, 203.94801233, 162.62194427, 187.6350552 ,
#         190.64216168, 181.00487203, 165.12294952, 179.50714042,
#         190.0106653 , 182.86407779, 185.72000009, 165.36910408,
#         195.86619619, 159.50085185,  97.64056737,  83.10608769,
#         107.11384608, 124.12231509, 147.44739108, 195.28553119,
#         198.15135875, 180.02636516, 182.54556416, 202.37311198,
#         199.1265583 , 188.18925437, 190.96319798, 184.77294407,
#         196.07829834, 200.75072391],
#        [199.16100853, 193.84292797, 178.31392255, 194.88003259,
#         199.15163404, 198.01075461, 173.10454117, 192.11078726,
#         196.05594628, 171.47425981, 183.07872325, 179.18618985,
#         186.32466561, 174.30101505, 145.89563752, 111.35679491,
#          79.52673923, 139.9396975 , 192.64650764, 192.1578511 ,
#         189.01501125, 172.63278179, 192.6276314 , 192.96016339,
#         207.79774724, 196.2800274 , 179.09259791, 185.84896841,
#         182.3975327 , 191.74035086],
#        [201.23850723, 176.51355005, 200.29491634, 199.61311846,
#         204.25156   , 203.00653928, 199.57427258, 184.23548975,
#         213.89291637, 197.61392845, 170.831147  , 197.71941096,
#         184.16997991, 162.06826751, 154.30432701, 136.54407908,
#          64.58189128, 177.83884638, 213.33394435, 162.59057622,
#         187.47297273, 180.7351955 , 184.02411613, 200.45437416,
#         197.67439816, 182.88385889, 199.43347302, 195.10618322,
#         196.06222942, 196.88189553],
#        [200.74175989, 197.54622651, 203.01622642, 205.79445279,
#         197.19366054, 195.20750006, 201.23719642, 184.11942454,
#         197.66496905, 189.5048589 , 151.82397095, 181.22769751,
#         180.42799006, 159.74049325, 185.78561712, 129.29432458,
#          58.34815332, 176.78510454, 180.21297777, 178.69881408,
#         203.30942187, 200.34540165, 186.55681301, 204.13701973,
#         191.4574282 , 197.3728751 , 202.73231532, 205.76991763,
#         187.3517462 , 192.1755411 ],
#        [188.4248148 , 214.15133923, 194.08855183, 183.29668845,
#         175.01530346, 198.95382671, 194.7171732 , 198.33051639,
#         187.20982188, 198.93133718, 185.65624171, 185.39304791,
#         160.50866007, 159.3560216 , 158.45274326, 124.26535495,
#          58.40650397, 160.28263459, 184.00174228, 199.46393603,
#         196.56849027, 201.72606365, 191.68026554, 199.20365467,
#         180.50775912, 191.34473938, 201.93554297, 214.29027126,
#         201.71376944, 202.44841538],
#        [183.33095463, 226.1366037 , 197.37073342, 169.74078314,
#         201.67330404, 197.48773023, 202.96534625, 176.16689918,
#         199.77488935, 193.11819468, 205.72592239, 203.48030388,
#         174.74426568, 157.28486467, 198.05667036, 143.73573382,
#          45.73066926, 155.61345971, 201.91254523, 153.38297315,
#         184.00203686, 181.63482088, 200.85831331, 205.81153258,
#         197.49380168, 199.84127844, 203.66631182, 195.34740581,
#         207.87847996, 199.25784996]])

# %%
error = np.linalg.norm(classical_arr - classical_reform, 'fro') / np.sqrt(cm*cn)
error
# Out:
# 145.18033624372387

# %%
np.linalg.norm(classical_arr, 'fro') / np.sqrt(cm*cn)
# Out:
# 145.78164036210686
