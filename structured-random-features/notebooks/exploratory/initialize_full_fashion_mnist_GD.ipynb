# %% [markdown]
# Initialize shallow feedforward fully-connected network with V1 type weights and classify __full fashion mnist__ dataset using __Gradient descent__.

# %%
import numpy as np
import numpy.linalg as la
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from data_fns import load_fashion_mnist
from estimator import classical_weights, V1_inspired_weights, V1_weights_multiple_scales
import pickle

# %%
torch.cuda.set_device(0)
train, train_labels, test, test_labels = load_fashion_mnist('./data/fashion_mnist/')
X_train = torch.from_numpy(train).float().to('cuda')
X_test = torch.from_numpy(test).float().to('cuda')
y_train = torch.from_numpy(train_labels).long().to('cuda')
y_test = torch.from_numpy(test_labels).long().to('cuda')
n, d = X_train.shape

# %%
class V1_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(V1_inspired_weights(hidden_size, d, t=3.1, l=1.1, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class He_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class RF_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(classical_weights(hidden_size, d, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)

# %%
def predict(model, X):
    return model(X).data.max(1)[1]

def error(model, X, y):
    y_pred = predict(model, X)
    accuracy = 1.0 * torch.sum(y_pred == y) / len(y)
    return 1 - accuracy

# %%
V1_model = V1_net(100, 2/d)
RF_model = RF_net(100, 2/d)
He_model= He_net(100, 2/d)
print('V1', torch.mean(torch.norm(V1_model.fc1.weight.data, dim=1)))
print('He', torch.mean(torch.norm(He_model.fc1.weight.data, dim=1)))
print('RF', torch.mean(torch.norm(RF_model.fc1.weight.data, dim=1)))
w = torch.mean(torch.norm(RF_model.fc1.weight.data, dim=1))
# Out:
# V1 tensor(1.4302)
# He tensor(1.4124)
# RF tensor(1.4158)

# %%
n_trials, n_epochs = 10, 3001
models = {'V1': V1_net, 'He': He_net}
h_list = [50, 100, 400, 1000]
lr_list = [1e-3, 1e-2, 1e-1, 1e0]

train_err = {m: {h: {lr: np.zeros((n_trials, n_epochs)) for lr in lr_list} for h in h_list} for m in models.keys()}
test_err = {m: {h: {lr: np.zeros((n_trials, n_epochs)) for lr in lr_list} for h in h_list} for m in models.keys()}
loss_list = {m: {h: {lr: np.zeros((n_trials, n_epochs)) for lr in lr_list} for h in h_list} for m in models.keys()}

# %%
scale = 2/d
t, l = 3.1, 1.1
loss_func = nn.CrossEntropyLoss()

for h in h_list:
    for lr in lr_list:
        for m, network in models.items():
            for i in range(n_trials):
                model = network(h, scale).to('cuda')
                optim = torch.optim.SGD(model.parameters(), lr=lr)
                for j in range(n_epochs):
                    optim.zero_grad()
                    loss = loss_func(model(X_train), y_train)
                    loss.backward()
                    optim.step()

                    train_err[m][h][lr][i, j] = error(model, X_train, y_train)
                    test_err[m][h][lr][i, j] = error(model, X_test, y_test)
                    loss_list[m][h][lr][i, j] = loss.data

                    if (j % 600 == 0):
                        print('Trial %d, Epoch: %d, %s model, h=%d, lr=%0.5f, Loss=%0.5f, test err=%0.3f' % (i,j, m, h, lr, loss.data, 
                                                                                                  test_err[m][h][lr][i, j]))
results = {'test_err': test_err, 'train_err': train_err, 'loss': loss_list}
with open('results/initialize_fashion_mnist/full_data/clf_t=%0.3f_l=%0.3f.pickle' % (t, l), 'wb') as handle:
    pickle.dump(results, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.42892, test err=0.928
# Trial 0, Epoch: 600, V1 model, h=50, lr=0.00100, Loss=1.82315, test err=0.515
# Trial 0, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=1.50792, test err=0.381
# Trial 0, Epoch: 1800, V1 model, h=50, lr=0.00100, Loss=1.28619, test err=0.342
# Trial 0, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=1.13752, test err=0.328
# Trial 0, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.03627, test err=0.317
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.75773, test err=0.897
# Trial 1, Epoch: 600, V1 model, h=50, lr=0.00100, Loss=1.81020, test err=0.606
# Trial 1, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=1.49468, test err=0.411
# Trial 1, Epoch: 1800, V1 model, h=50, lr=0.00100, Loss=1.28757, test err=0.369
# Trial 1, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=1.15126, test err=0.350
# Trial 1, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.05788, test err=0.337
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.45106, test err=0.934
# Trial 2, Epoch: 600, V1 model, h=50, lr=0.00100, Loss=1.88796, test err=0.526
# Trial 2, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=1.55010, test err=0.391
# Trial 2, Epoch: 1800, V1 model, h=50, lr=0.00100, Loss=1.31730, test err=0.374
# Trial 2, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=1.17294, test err=0.359
# Trial 2, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.07839, test err=0.343
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.35777, test err=0.880
# Trial 3, Epoch: 600, V1 model, h=50, lr=0.00100, Loss=1.74245, test err=0.538
# Trial 3, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=1.43619, test err=0.404
# Trial 3, Epoch: 1800, V1 model, h=50, lr=0.00100, Loss=1.23803, test err=0.367
# Trial 3, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=1.11101, test err=0.351
# Trial 3, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.02528, test err=0.341
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.41332, test err=0.941
# Trial 4, Epoch: 600, V1 model, h=50, lr=0.00100, Loss=2.02044, test err=0.717
# Trial 4, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=1.70923, test err=0.500
# Trial 4, Epoch: 1800, V1 model, h=50, lr=0.00100, Loss=1.44976, test err=0.429
# Trial 4, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=1.27297, test err=0.389
# Trial 4, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.15340, test err=0.371
# Trial 5, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.44586, test err=0.895
# Trial 5, Epoch: 600, V1 model, h=50, lr=0.00100, Loss=1.84362, test err=0.575
# Trial 5, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=1.51119, test err=0.420
# Trial 5, Epoch: 1800, V1 model, h=50, lr=0.00100, Loss=1.29136, test err=0.364
# Trial 5, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=1.14870, test err=0.345
# Trial 5, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.05218, test err=0.334
# Trial 6, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.43107, test err=0.873
# Trial 6, Epoch: 600, V1 model, h=50, lr=0.00100, Loss=1.71620, test err=0.475
# Trial 6, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=1.40619, test err=0.393
# Trial 6, Epoch: 1800, V1 model, h=50, lr=0.00100, Loss=1.22433, test err=0.373
# Trial 6, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=1.10927, test err=0.361
# Trial 6, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.03014, test err=0.348
# Trial 7, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.51515, test err=0.859
# Trial 7, Epoch: 600, V1 model, h=50, lr=0.00100, Loss=1.67260, test err=0.471
# Trial 7, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=1.39720, test err=0.386
# Trial 7, Epoch: 1800, V1 model, h=50, lr=0.00100, Loss=1.22610, test err=0.361
# Trial 7, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=1.10974, test err=0.346
# Trial 7, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.02732, test err=0.335
# Trial 8, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.45269, test err=0.778
# Trial 8, Epoch: 600, V1 model, h=50, lr=0.00100, Loss=1.81283, test err=0.530
# Trial 8, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=1.48124, test err=0.394
# Trial 8, Epoch: 1800, V1 model, h=50, lr=0.00100, Loss=1.27012, test err=0.374
# Trial 8, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=1.13581, test err=0.356
# Trial 8, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.04534, test err=0.346
# Trial 9, Epoch: 0, V1 model, h=50, lr=0.00100, Loss=2.29171, test err=0.898
# Trial 9, Epoch: 600, V1 model, h=50, lr=0.00100, Loss=1.91832, test err=0.583
# Trial 9, Epoch: 1200, V1 model, h=50, lr=0.00100, Loss=1.63212, test err=0.470
# Trial 9, Epoch: 1800, V1 model, h=50, lr=0.00100, Loss=1.39019, test err=0.392
# Trial 9, Epoch: 2400, V1 model, h=50, lr=0.00100, Loss=1.21923, test err=0.367
# Trial 9, Epoch: 3000, V1 model, h=50, lr=0.00100, Loss=1.10210, test err=0.356
# Trial 0, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.30650, test err=0.830
# Trial 0, Epoch: 600, He model, h=50, lr=0.00100, Loss=2.04027, test err=0.552
# Trial 0, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.76268, test err=0.419
# Trial 0, Epoch: 1800, He model, h=50, lr=0.00100, Loss=1.49811, test err=0.376
# Trial 0, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.29822, test err=0.360
# Trial 0, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.15873, test err=0.346
# Trial 1, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.34065, test err=0.899
# Trial 1, Epoch: 600, He model, h=50, lr=0.00100, Loss=2.02220, test err=0.609
# Trial 1, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.73906, test err=0.501
# Trial 1, Epoch: 1800, He model, h=50, lr=0.00100, Loss=1.49014, test err=0.392
# Trial 1, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.30357, test err=0.375
# Trial 1, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.17126, test err=0.366
# Trial 2, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.33836, test err=0.901
# Trial 2, Epoch: 600, He model, h=50, lr=0.00100, Loss=1.95238, test err=0.555
# Trial 2, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.64108, test err=0.424
# Trial 2, Epoch: 1800, He model, h=50, lr=0.00100, Loss=1.40304, test err=0.394
# Trial 2, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.23741, test err=0.369
# Trial 2, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.12052, test err=0.355
# Trial 3, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.30280, test err=0.877
# Trial 3, Epoch: 600, He model, h=50, lr=0.00100, Loss=2.09368, test err=0.757
# Trial 3, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.88501, test err=0.458
# Trial 3, Epoch: 1800, He model, h=50, lr=0.00100, Loss=1.65262, test err=0.387
# Trial 3, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.44608, test err=0.367
# Trial 3, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.28521, test err=0.357
# Trial 4, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.31412, test err=0.924
# Trial 4, Epoch: 600, He model, h=50, lr=0.00100, Loss=2.00838, test err=0.589
# Trial 4, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.71827, test err=0.413
# Trial 4, Epoch: 1800, He model, h=50, lr=0.00100, Loss=1.47214, test err=0.379
# Trial 4, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.28934, test err=0.362
# Trial 4, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.15735, test err=0.352
# Trial 5, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.33002, test err=0.883
# Trial 5, Epoch: 600, He model, h=50, lr=0.00100, Loss=2.02295, test err=0.558
# Trial 5, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.72803, test err=0.450
# Trial 5, Epoch: 1800, He model, h=50, lr=0.00100, Loss=1.47459, test err=0.389
# Trial 5, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.28472, test err=0.360
# Trial 5, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.15040, test err=0.346
# Trial 6, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.33805, test err=0.844
# Trial 6, Epoch: 600, He model, h=50, lr=0.00100, Loss=2.00382, test err=0.664
# Trial 6, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.71430, test err=0.474
# Trial 6, Epoch: 1800, He model, h=50, lr=0.00100, Loss=1.46814, test err=0.398
# Trial 6, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.28573, test err=0.363
# Trial 6, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.15707, test err=0.347
# Trial 7, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.37265, test err=0.972
# Trial 7, Epoch: 600, He model, h=50, lr=0.00100, Loss=2.01331, test err=0.624
# Trial 7, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.71769, test err=0.428
# Trial 7, Epoch: 1800, He model, h=50, lr=0.00100, Loss=1.47311, test err=0.390
# Trial 7, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.29445, test err=0.366
# Trial 7, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.16699, test err=0.353
# Trial 8, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.33469, test err=0.882
# Trial 8, Epoch: 600, He model, h=50, lr=0.00100, Loss=2.03915, test err=0.547
# Trial 8, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.73828, test err=0.436
# Trial 8, Epoch: 1800, He model, h=50, lr=0.00100, Loss=1.46354, test err=0.381
# Trial 8, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.26782, test err=0.361
# Trial 8, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.13532, test err=0.349
# Trial 9, Epoch: 0, He model, h=50, lr=0.00100, Loss=2.28497, test err=0.902
# Trial 9, Epoch: 600, He model, h=50, lr=0.00100, Loss=1.95961, test err=0.516
# Trial 9, Epoch: 1200, He model, h=50, lr=0.00100, Loss=1.66431, test err=0.400
# Trial 9, Epoch: 1800, He model, h=50, lr=0.00100, Loss=1.41676, test err=0.373
# Trial 9, Epoch: 2400, He model, h=50, lr=0.00100, Loss=1.24152, test err=0.360
# Trial 9, Epoch: 3000, He model, h=50, lr=0.00100, Loss=1.12140, test err=0.354
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.69783, test err=0.832
# Trial 0, Epoch: 600, V1 model, h=50, lr=0.01000, Loss=0.82869, test err=0.303
# Trial 0, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.68751, test err=0.256
# Trial 0, Epoch: 1800, V1 model, h=50, lr=0.01000, Loss=0.61981, test err=0.229
# Trial 0, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.57670, test err=0.212
# Trial 0, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.54623, test err=0.200
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.49067, test err=0.914
# Trial 1, Epoch: 600, V1 model, h=50, lr=0.01000, Loss=0.86107, test err=0.308
# Trial 1, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.70398, test err=0.256
# Trial 1, Epoch: 1800, V1 model, h=50, lr=0.01000, Loss=0.62955, test err=0.227
# Trial 1, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.58288, test err=0.208
# Trial 1, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.55013, test err=0.195
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.36930, test err=0.898
# Trial 2, Epoch: 600, V1 model, h=50, lr=0.01000, Loss=0.83214, test err=0.289
# Trial 2, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.68622, test err=0.248
# Trial 2, Epoch: 1800, V1 model, h=50, lr=0.01000, Loss=0.62041, test err=0.226
# Trial 2, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.57838, test err=0.211
# Trial 2, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.54818, test err=0.201
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.66469, test err=0.933
# Trial 3, Epoch: 600, V1 model, h=50, lr=0.01000, Loss=0.83280, test err=0.300
# Trial 3, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.68750, test err=0.249
# Trial 3, Epoch: 1800, V1 model, h=50, lr=0.01000, Loss=0.61921, test err=0.224
# Trial 3, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.57618, test err=0.208
# Trial 3, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.54607, test err=0.199
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.72883, test err=0.900
# Trial 4, Epoch: 600, V1 model, h=50, lr=0.01000, Loss=0.84069, test err=0.289
# Trial 4, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.69556, test err=0.255
# Trial 4, Epoch: 1800, V1 model, h=50, lr=0.01000, Loss=0.62924, test err=0.230
# Trial 4, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.58532, test err=0.214
# Trial 4, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.55371, test err=0.203
# Trial 5, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.49158, test err=0.924
# Trial 5, Epoch: 600, V1 model, h=50, lr=0.01000, Loss=0.82012, test err=0.279
# Trial 5, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.66536, test err=0.238
# Trial 5, Epoch: 1800, V1 model, h=50, lr=0.01000, Loss=0.59780, test err=0.215
# Trial 5, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.55620, test err=0.200
# Trial 5, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.52759, test err=0.189
# Trial 6, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.37161, test err=0.938
# Trial 6, Epoch: 600, V1 model, h=50, lr=0.01000, Loss=0.83891, test err=0.308
# Trial 6, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.69600, test err=0.252
# Trial 6, Epoch: 1800, V1 model, h=50, lr=0.01000, Loss=0.62253, test err=0.221
# Trial 6, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.57640, test err=0.205
# Trial 6, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.54526, test err=0.194
# Trial 7, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.65569, test err=0.935
# Trial 7, Epoch: 600, V1 model, h=50, lr=0.01000, Loss=0.82014, test err=0.300
# Trial 7, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.68165, test err=0.250
# Trial 7, Epoch: 1800, V1 model, h=50, lr=0.01000, Loss=0.61376, test err=0.225
# Trial 7, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.57120, test err=0.209
# Trial 7, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.54130, test err=0.199
# Trial 8, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.45099, test err=0.868
# Trial 8, Epoch: 600, V1 model, h=50, lr=0.01000, Loss=0.83070, test err=0.293
# Trial 8, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.68997, test err=0.252
# Trial 8, Epoch: 1800, V1 model, h=50, lr=0.01000, Loss=0.62059, test err=0.226
# Trial 8, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.57598, test err=0.207
# Trial 8, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.54488, test err=0.198
# Trial 9, Epoch: 0, V1 model, h=50, lr=0.01000, Loss=2.37427, test err=0.852
# Trial 9, Epoch: 600, V1 model, h=50, lr=0.01000, Loss=0.81254, test err=0.290
# Trial 9, Epoch: 1200, V1 model, h=50, lr=0.01000, Loss=0.68119, test err=0.248
# Trial 9, Epoch: 1800, V1 model, h=50, lr=0.01000, Loss=0.61662, test err=0.222
# Trial 9, Epoch: 2400, V1 model, h=50, lr=0.01000, Loss=0.57483, test err=0.206
# Trial 9, Epoch: 3000, V1 model, h=50, lr=0.01000, Loss=0.54526, test err=0.195
# Trial 0, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.38091, test err=0.967
# Trial 0, Epoch: 600, He model, h=50, lr=0.01000, Loss=0.86740, test err=0.308
# Trial 0, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.69781, test err=0.253
# Trial 0, Epoch: 1800, He model, h=50, lr=0.01000, Loss=0.61892, test err=0.223
# Trial 0, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.57199, test err=0.206
# Trial 0, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.54089, test err=0.195
# Trial 1, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.34464, test err=0.919
# Trial 1, Epoch: 600, He model, h=50, lr=0.01000, Loss=0.88395, test err=0.314
# Trial 1, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.70809, test err=0.257
# Trial 1, Epoch: 1800, He model, h=50, lr=0.01000, Loss=0.62745, test err=0.223
# Trial 1, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.57835, test err=0.206
# Trial 1, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.54578, test err=0.196
# Trial 2, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.34718, test err=0.852
# Trial 2, Epoch: 600, He model, h=50, lr=0.01000, Loss=0.86289, test err=0.303
# Trial 2, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.69909, test err=0.246
# Trial 2, Epoch: 1800, He model, h=50, lr=0.01000, Loss=0.62173, test err=0.218
# Trial 2, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.57453, test err=0.204
# Trial 2, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.54270, test err=0.192
# Trial 3, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.36306, test err=0.923
# Trial 3, Epoch: 600, He model, h=50, lr=0.01000, Loss=0.86833, test err=0.314
# Trial 3, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.69131, test err=0.251
# Trial 3, Epoch: 1800, He model, h=50, lr=0.01000, Loss=0.61232, test err=0.216
# Trial 3, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.56577, test err=0.203
# Trial 3, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.53545, test err=0.192
# Trial 4, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.35271, test err=0.901
# Trial 4, Epoch: 600, He model, h=50, lr=0.01000, Loss=0.88330, test err=0.319
# Trial 4, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.70368, test err=0.255
# Trial 4, Epoch: 1800, He model, h=50, lr=0.01000, Loss=0.62087, test err=0.221
# Trial 4, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.57094, test err=0.205
# Trial 4, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.53786, test err=0.193
# Trial 5, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.32693, test err=0.950
# Trial 5, Epoch: 600, He model, h=50, lr=0.01000, Loss=0.86672, test err=0.313
# Trial 5, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.69716, test err=0.257
# Trial 5, Epoch: 1800, He model, h=50, lr=0.01000, Loss=0.61857, test err=0.224
# Trial 5, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.57071, test err=0.208
# Trial 5, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.53869, test err=0.197
# Trial 6, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.29773, test err=0.948
# Trial 6, Epoch: 600, He model, h=50, lr=0.01000, Loss=0.89956, test err=0.328
# Trial 6, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.71051, test err=0.257
# Trial 6, Epoch: 1800, He model, h=50, lr=0.01000, Loss=0.62482, test err=0.224
# Trial 6, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.57517, test err=0.206
# Trial 6, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.54294, test err=0.193
# Trial 7, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.32706, test err=0.907
# Trial 7, Epoch: 600, He model, h=50, lr=0.01000, Loss=0.86572, test err=0.305
# Trial 7, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.69360, test err=0.246
# Trial 7, Epoch: 1800, He model, h=50, lr=0.01000, Loss=0.61532, test err=0.217
# Trial 7, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.56804, test err=0.201
# Trial 7, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.53694, test err=0.192
# Trial 8, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.37453, test err=0.904
# Trial 8, Epoch: 600, He model, h=50, lr=0.01000, Loss=0.86967, test err=0.306
# Trial 8, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.70031, test err=0.255
# Trial 8, Epoch: 1800, He model, h=50, lr=0.01000, Loss=0.62327, test err=0.228
# Trial 8, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.57590, test err=0.211
# Trial 8, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.54379, test err=0.200
# Trial 9, Epoch: 0, He model, h=50, lr=0.01000, Loss=2.34966, test err=0.928
# Trial 9, Epoch: 600, He model, h=50, lr=0.01000, Loss=0.86920, test err=0.305
# Trial 9, Epoch: 1200, He model, h=50, lr=0.01000, Loss=0.69682, test err=0.253
# Trial 9, Epoch: 1800, He model, h=50, lr=0.01000, Loss=0.61898, test err=0.219
# Trial 9, Epoch: 2400, He model, h=50, lr=0.01000, Loss=0.57247, test err=0.201
# Trial 9, Epoch: 3000, He model, h=50, lr=0.01000, Loss=0.54160, test err=0.191
# Trial 0, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.72817, test err=0.813
# Trial 0, Epoch: 600, V1 model, h=50, lr=0.10000, Loss=0.49087, test err=0.181
# Trial 0, Epoch: 1200, V1 model, h=50, lr=0.10000, Loss=0.42613, test err=0.160
# Trial 0, Epoch: 1800, V1 model, h=50, lr=0.10000, Loss=0.39064, test err=0.153
# Trial 0, Epoch: 2400, V1 model, h=50, lr=0.10000, Loss=0.36544, test err=0.145
# Trial 0, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.35093, test err=0.142
# Trial 1, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.57481, test err=0.777
# Trial 1, Epoch: 600, V1 model, h=50, lr=0.10000, Loss=0.48998, test err=0.178
# Trial 1, Epoch: 1200, V1 model, h=50, lr=0.10000, Loss=0.43860, test err=0.165
# Trial 1, Epoch: 1800, V1 model, h=50, lr=0.10000, Loss=0.39129, test err=0.151
# Trial 1, Epoch: 2400, V1 model, h=50, lr=0.10000, Loss=0.37116, test err=0.149
# Trial 1, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.35492, test err=0.144
# Trial 2, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.28220, test err=0.805
# Trial 2, Epoch: 600, V1 model, h=50, lr=0.10000, Loss=0.48927, test err=0.182
# Trial 2, Epoch: 1200, V1 model, h=50, lr=0.10000, Loss=0.43556, test err=0.167
# Trial 2, Epoch: 1800, V1 model, h=50, lr=0.10000, Loss=0.38780, test err=0.150
# Trial 2, Epoch: 2400, V1 model, h=50, lr=0.10000, Loss=0.36775, test err=0.145
# Trial 2, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.34979, test err=0.141
# Trial 3, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.54715, test err=0.835
# Trial 3, Epoch: 600, V1 model, h=50, lr=0.10000, Loss=0.48815, test err=0.184
# Trial 3, Epoch: 1200, V1 model, h=50, lr=0.10000, Loss=0.42057, test err=0.162
# Trial 3, Epoch: 1800, V1 model, h=50, lr=0.10000, Loss=0.38889, test err=0.152
# Trial 3, Epoch: 2400, V1 model, h=50, lr=0.10000, Loss=0.36249, test err=0.145
# Trial 3, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.34619, test err=0.141
# Trial 4, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.47962, test err=0.789
# Trial 4, Epoch: 600, V1 model, h=50, lr=0.10000, Loss=0.49986, test err=0.187
# Trial 4, Epoch: 1200, V1 model, h=50, lr=0.10000, Loss=0.43231, test err=0.165
# Trial 4, Epoch: 1800, V1 model, h=50, lr=0.10000, Loss=0.40517, test err=0.155
# Trial 4, Epoch: 2400, V1 model, h=50, lr=0.10000, Loss=0.37936, test err=0.150
# Trial 4, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.36451, test err=0.145
# Trial 5, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.58984, test err=0.684
# Trial 5, Epoch: 600, V1 model, h=50, lr=0.10000, Loss=0.48858, test err=0.184
# Trial 5, Epoch: 1200, V1 model, h=50, lr=0.10000, Loss=0.42384, test err=0.162
# Trial 5, Epoch: 1800, V1 model, h=50, lr=0.10000, Loss=0.38813, test err=0.150
# Trial 5, Epoch: 2400, V1 model, h=50, lr=0.10000, Loss=0.36267, test err=0.144
# Trial 5, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.34624, test err=0.139
# Trial 6, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.52868, test err=0.814
# Trial 6, Epoch: 600, V1 model, h=50, lr=0.10000, Loss=0.49161, test err=0.185
# Trial 6, Epoch: 1200, V1 model, h=50, lr=0.10000, Loss=0.42607, test err=0.163
# Trial 6, Epoch: 1800, V1 model, h=50, lr=0.10000, Loss=0.38810, test err=0.151
# Trial 6, Epoch: 2400, V1 model, h=50, lr=0.10000, Loss=0.36806, test err=0.145
# Trial 6, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.35084, test err=0.142
# Trial 7, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.53105, test err=0.772
# Trial 7, Epoch: 600, V1 model, h=50, lr=0.10000, Loss=0.49651, test err=0.184
# Trial 7, Epoch: 1200, V1 model, h=50, lr=0.10000, Loss=0.43214, test err=0.165
# Trial 7, Epoch: 1800, V1 model, h=50, lr=0.10000, Loss=0.39378, test err=0.151
# Trial 7, Epoch: 2400, V1 model, h=50, lr=0.10000, Loss=0.37449, test err=0.148
# Trial 7, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.35339, test err=0.140
# Trial 8, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.63978, test err=0.882
# Trial 8, Epoch: 600, V1 model, h=50, lr=0.10000, Loss=0.49930, test err=0.185
# Trial 8, Epoch: 1200, V1 model, h=50, lr=0.10000, Loss=0.42658, test err=0.163
# Trial 8, Epoch: 1800, V1 model, h=50, lr=0.10000, Loss=0.38972, test err=0.152
# Trial 8, Epoch: 2400, V1 model, h=50, lr=0.10000, Loss=0.36767, test err=0.146
# Trial 8, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.35001, test err=0.140
# Trial 9, Epoch: 0, V1 model, h=50, lr=0.10000, Loss=2.43396, test err=0.861
# Trial 9, Epoch: 600, V1 model, h=50, lr=0.10000, Loss=0.48896, test err=0.183
# Trial 9, Epoch: 1200, V1 model, h=50, lr=0.10000, Loss=0.42519, test err=0.162
# Trial 9, Epoch: 1800, V1 model, h=50, lr=0.10000, Loss=0.38735, test err=0.150
# Trial 9, Epoch: 2400, V1 model, h=50, lr=0.10000, Loss=0.36389, test err=0.143
# Trial 9, Epoch: 3000, V1 model, h=50, lr=0.10000, Loss=0.34782, test err=0.139
# Trial 0, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.41988, test err=0.884
# Trial 0, Epoch: 600, He model, h=50, lr=0.10000, Loss=0.48995, test err=0.186
# Trial 0, Epoch: 1200, He model, h=50, lr=0.10000, Loss=0.42469, test err=0.164
# Trial 0, Epoch: 1800, He model, h=50, lr=0.10000, Loss=0.39079, test err=0.155
# Trial 0, Epoch: 2400, He model, h=50, lr=0.10000, Loss=0.36617, test err=0.146
# Trial 0, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.34961, test err=0.141
# Trial 1, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.38519, test err=0.890
# Trial 1, Epoch: 600, He model, h=50, lr=0.10000, Loss=0.47986, test err=0.178
# Trial 1, Epoch: 1200, He model, h=50, lr=0.10000, Loss=0.41982, test err=0.158
# Trial 1, Epoch: 1800, He model, h=50, lr=0.10000, Loss=0.39118, test err=0.154
# Trial 1, Epoch: 2400, He model, h=50, lr=0.10000, Loss=0.37043, test err=0.145
# Trial 1, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.35526, test err=0.142
# Trial 2, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.33441, test err=0.886
# Trial 2, Epoch: 600, He model, h=50, lr=0.10000, Loss=0.49410, test err=0.182
# Trial 2, Epoch: 1200, He model, h=50, lr=0.10000, Loss=0.42875, test err=0.163
# Trial 2, Epoch: 1800, He model, h=50, lr=0.10000, Loss=0.39230, test err=0.153
# Trial 2, Epoch: 2400, He model, h=50, lr=0.10000, Loss=0.37202, test err=0.148
# Trial 2, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.35450, test err=0.143
# Trial 3, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.32203, test err=0.832
# Trial 3, Epoch: 600, He model, h=50, lr=0.10000, Loss=0.48589, test err=0.183
# Trial 3, Epoch: 1200, He model, h=50, lr=0.10000, Loss=0.42633, test err=0.164
# Trial 3, Epoch: 1800, He model, h=50, lr=0.10000, Loss=0.39408, test err=0.157
# Trial 3, Epoch: 2400, He model, h=50, lr=0.10000, Loss=0.37249, test err=0.150
# Trial 3, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.35226, test err=0.142
# Trial 4, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.35953, test err=0.869
# Trial 4, Epoch: 600, He model, h=50, lr=0.10000, Loss=0.48685, test err=0.181
# Trial 4, Epoch: 1200, He model, h=50, lr=0.10000, Loss=0.42082, test err=0.163
# Trial 4, Epoch: 1800, He model, h=50, lr=0.10000, Loss=0.39488, test err=0.156
# Trial 4, Epoch: 2400, He model, h=50, lr=0.10000, Loss=0.36908, test err=0.145
# Trial 4, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.35005, test err=0.142
# Trial 5, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.38463, test err=0.902
# Trial 5, Epoch: 600, He model, h=50, lr=0.10000, Loss=0.48255, test err=0.180
# Trial 5, Epoch: 1200, He model, h=50, lr=0.10000, Loss=0.42032, test err=0.160
# Trial 5, Epoch: 1800, He model, h=50, lr=0.10000, Loss=0.38680, test err=0.151
# Trial 5, Epoch: 2400, He model, h=50, lr=0.10000, Loss=0.36517, test err=0.146
# Trial 5, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.35139, test err=0.142
# Trial 6, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.33447, test err=0.860
# Trial 6, Epoch: 600, He model, h=50, lr=0.10000, Loss=0.48673, test err=0.181
# Trial 6, Epoch: 1200, He model, h=50, lr=0.10000, Loss=0.43121, test err=0.165
# Trial 6, Epoch: 1800, He model, h=50, lr=0.10000, Loss=0.40082, test err=0.153
# Trial 6, Epoch: 2400, He model, h=50, lr=0.10000, Loss=0.38021, test err=0.148
# Trial 6, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.36318, test err=0.143
# Trial 7, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.31160, test err=0.835
# Trial 7, Epoch: 600, He model, h=50, lr=0.10000, Loss=0.48498, test err=0.182
# Trial 7, Epoch: 1200, He model, h=50, lr=0.10000, Loss=0.42519, test err=0.163
# Trial 7, Epoch: 1800, He model, h=50, lr=0.10000, Loss=0.39292, test err=0.152
# Trial 7, Epoch: 2400, He model, h=50, lr=0.10000, Loss=0.37007, test err=0.146
# Trial 7, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.35256, test err=0.141
# Trial 8, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.33212, test err=0.837
# Trial 8, Epoch: 600, He model, h=50, lr=0.10000, Loss=0.48479, test err=0.180
# Trial 8, Epoch: 1200, He model, h=50, lr=0.10000, Loss=0.42049, test err=0.161
# Trial 8, Epoch: 1800, He model, h=50, lr=0.10000, Loss=0.39268, test err=0.151
# Trial 8, Epoch: 2400, He model, h=50, lr=0.10000, Loss=0.36927, test err=0.147
# Trial 8, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.35578, test err=0.144
# Trial 9, Epoch: 0, He model, h=50, lr=0.10000, Loss=2.34960, test err=0.898
# Trial 9, Epoch: 600, He model, h=50, lr=0.10000, Loss=0.48997, test err=0.185
# Trial 9, Epoch: 1200, He model, h=50, lr=0.10000, Loss=0.43708, test err=0.170
# Trial 9, Epoch: 1800, He model, h=50, lr=0.10000, Loss=0.39449, test err=0.154
# Trial 9, Epoch: 2400, He model, h=50, lr=0.10000, Loss=0.37182, test err=0.148
# Trial 9, Epoch: 3000, He model, h=50, lr=0.10000, Loss=0.35387, test err=0.141
# Trial 0, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.60663, test err=0.808
# Trial 0, Epoch: 600, V1 model, h=50, lr=1.00000, Loss=1.73018, test err=0.721
# Trial 0, Epoch: 1200, V1 model, h=50, lr=1.00000, Loss=1.21608, test err=0.533
# Trial 0, Epoch: 1800, V1 model, h=50, lr=1.00000, Loss=2.12124, test err=0.805
# Trial 0, Epoch: 2400, V1 model, h=50, lr=1.00000, Loss=2.18275, test err=0.781
# Trial 0, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=2.07511, test err=0.809
# Trial 1, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.55530, test err=0.691
# Trial 1, Epoch: 600, V1 model, h=50, lr=1.00000, Loss=1.97021, test err=0.822
# Trial 1, Epoch: 1200, V1 model, h=50, lr=1.00000, Loss=1.95844, test err=0.802
# Trial 1, Epoch: 1800, V1 model, h=50, lr=1.00000, Loss=2.30232, test err=0.900
# Trial 1, Epoch: 2400, V1 model, h=50, lr=1.00000, Loss=2.30246, test err=0.900
# Trial 1, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=2.30249, test err=0.900
# Trial 2, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.62077, test err=0.823
# Trial 2, Epoch: 600, V1 model, h=50, lr=1.00000, Loss=0.93937, test err=0.504
# Trial 2, Epoch: 1200, V1 model, h=50, lr=1.00000, Loss=0.64034, test err=0.261
# Trial 2, Epoch: 1800, V1 model, h=50, lr=1.00000, Loss=1.33434, test err=0.516
# Trial 2, Epoch: 2400, V1 model, h=50, lr=1.00000, Loss=1.94135, test err=0.820
# Trial 2, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=1.52743, test err=0.614
# Trial 3, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.49685, test err=0.887
# Trial 3, Epoch: 600, V1 model, h=50, lr=1.00000, Loss=1.15981, test err=0.459
# Trial 3, Epoch: 1200, V1 model, h=50, lr=1.00000, Loss=3.23278, test err=0.838
# Trial 3, Epoch: 1800, V1 model, h=50, lr=1.00000, Loss=2.30264, test err=0.900
# Trial 3, Epoch: 2400, V1 model, h=50, lr=1.00000, Loss=1.80346, test err=0.778
# Trial 3, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=1.96261, test err=0.783
# Trial 4, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.71795, test err=0.814
# Trial 4, Epoch: 600, V1 model, h=50, lr=1.00000, Loss=2.13424, test err=0.708
# Trial 4, Epoch: 1200, V1 model, h=50, lr=1.00000, Loss=2.07076, test err=0.670
# Trial 4, Epoch: 1800, V1 model, h=50, lr=1.00000, Loss=0.71124, test err=0.268
# Trial 4, Epoch: 2400, V1 model, h=50, lr=1.00000, Loss=0.99903, test err=0.422
# Trial 4, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=1.68651, test err=0.709
# Trial 5, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.30108, test err=0.885
# Trial 5, Epoch: 600, V1 model, h=50, lr=1.00000, Loss=0.64127, test err=0.277
# Trial 5, Epoch: 1200, V1 model, h=50, lr=1.00000, Loss=2.67273, test err=0.799
# Trial 5, Epoch: 1800, V1 model, h=50, lr=1.00000, Loss=1.76753, test err=0.769
# Trial 5, Epoch: 2400, V1 model, h=50, lr=1.00000, Loss=2.17620, test err=0.775
# Trial 5, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=2.13044, test err=0.861
# Trial 6, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.50701, test err=0.812
# Trial 6, Epoch: 600, V1 model, h=50, lr=1.00000, Loss=1.60457, test err=0.661
# Trial 6, Epoch: 1200, V1 model, h=50, lr=1.00000, Loss=1.80144, test err=0.790
# Trial 6, Epoch: 1800, V1 model, h=50, lr=1.00000, Loss=2.38595, test err=0.899
# Trial 6, Epoch: 2400, V1 model, h=50, lr=1.00000, Loss=2.30220, test err=0.898
# Trial 6, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=2.37282, test err=0.900
# Trial 7, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.56270, test err=0.900
# Trial 7, Epoch: 600, V1 model, h=50, lr=1.00000, Loss=2.29464, test err=0.893
# Trial 7, Epoch: 1200, V1 model, h=50, lr=1.00000, Loss=2.29165, test err=0.900
# Trial 7, Epoch: 1800, V1 model, h=50, lr=1.00000, Loss=2.12157, test err=0.888
# Trial 7, Epoch: 2400, V1 model, h=50, lr=1.00000, Loss=2.30251, test err=0.900
# Trial 7, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=2.30252, test err=0.900
# Trial 8, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.55864, test err=0.613
# Trial 8, Epoch: 600, V1 model, h=50, lr=1.00000, Loss=0.96554, test err=0.382
# Trial 8, Epoch: 1200, V1 model, h=50, lr=1.00000, Loss=1.75083, test err=0.729
# Trial 8, Epoch: 1800, V1 model, h=50, lr=1.00000, Loss=1.78099, test err=0.617
# Trial 8, Epoch: 2400, V1 model, h=50, lr=1.00000, Loss=1.29229, test err=0.524
# Trial 8, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=2.71595, test err=0.868
# Trial 9, Epoch: 0, V1 model, h=50, lr=1.00000, Loss=2.61347, test err=0.777
# Trial 9, Epoch: 600, V1 model, h=50, lr=1.00000, Loss=2.17295, test err=0.808
# Trial 9, Epoch: 1200, V1 model, h=50, lr=1.00000, Loss=1.44041, test err=0.645
# Trial 9, Epoch: 1800, V1 model, h=50, lr=1.00000, Loss=1.68657, test err=0.714
# Trial 9, Epoch: 2400, V1 model, h=50, lr=1.00000, Loss=2.29830, test err=0.895
# Trial 9, Epoch: 3000, V1 model, h=50, lr=1.00000, Loss=2.30236, test err=0.900
# Trial 0, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.30574, test err=0.866
# Trial 0, Epoch: 600, He model, h=50, lr=1.00000, Loss=2.18766, test err=0.812
# Trial 0, Epoch: 1200, He model, h=50, lr=1.00000, Loss=2.30242, test err=0.899
# Trial 0, Epoch: 1800, He model, h=50, lr=1.00000, Loss=2.30250, test err=0.900
# Trial 0, Epoch: 2400, He model, h=50, lr=1.00000, Loss=2.30256, test err=0.900
# Trial 0, Epoch: 3000, He model, h=50, lr=1.00000, Loss=2.30249, test err=0.900
# Trial 1, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.34449, test err=0.610
# Trial 1, Epoch: 600, He model, h=50, lr=1.00000, Loss=2.30254, test err=0.900
# Trial 1, Epoch: 1200, He model, h=50, lr=1.00000, Loss=2.30246, test err=0.900
# Trial 1, Epoch: 1800, He model, h=50, lr=1.00000, Loss=2.30257, test err=0.900
# Trial 1, Epoch: 2400, He model, h=50, lr=1.00000, Loss=2.30480, test err=0.900
# Trial 1, Epoch: 3000, He model, h=50, lr=1.00000, Loss=1.81069, test err=0.806
# Trial 2, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.34643, test err=0.728
# Trial 2, Epoch: 600, He model, h=50, lr=1.00000, Loss=2.30071, test err=0.888
# Trial 2, Epoch: 1200, He model, h=50, lr=1.00000, Loss=2.30257, test err=0.900
# Trial 2, Epoch: 1800, He model, h=50, lr=1.00000, Loss=2.30256, test err=0.900
# Trial 2, Epoch: 2400, He model, h=50, lr=1.00000, Loss=2.40815, test err=0.900
# Trial 2, Epoch: 3000, He model, h=50, lr=1.00000, Loss=1.96137, test err=0.801
# Trial 3, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.32376, test err=0.711
# Trial 3, Epoch: 600, He model, h=50, lr=1.00000, Loss=2.27925, test err=0.870
# Trial 3, Epoch: 1200, He model, h=50, lr=1.00000, Loss=2.30245, test err=0.900
# Trial 3, Epoch: 1800, He model, h=50, lr=1.00000, Loss=1.28630, test err=0.539
# Trial 3, Epoch: 2400, He model, h=50, lr=1.00000, Loss=2.30238, test err=0.900
# Trial 3, Epoch: 3000, He model, h=50, lr=1.00000, Loss=2.30281, test err=0.900
# Trial 4, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.33646, test err=0.647
# Trial 4, Epoch: 600, He model, h=50, lr=1.00000, Loss=2.42597, test err=0.900
# Trial 4, Epoch: 1200, He model, h=50, lr=1.00000, Loss=2.30158, test err=0.900
# Trial 4, Epoch: 1800, He model, h=50, lr=1.00000, Loss=2.30255, test err=0.901
# Trial 4, Epoch: 2400, He model, h=50, lr=1.00000, Loss=2.30254, test err=0.900
# Trial 4, Epoch: 3000, He model, h=50, lr=1.00000, Loss=2.30157, test err=0.900
# Trial 5, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.34484, test err=0.889
# Trial 5, Epoch: 600, He model, h=50, lr=1.00000, Loss=2.03226, test err=0.783
# Trial 5, Epoch: 1200, He model, h=50, lr=1.00000, Loss=2.23533, test err=0.806
# Trial 5, Epoch: 1800, He model, h=50, lr=1.00000, Loss=2.30255, test err=0.901
# Trial 5, Epoch: 2400, He model, h=50, lr=1.00000, Loss=2.30255, test err=0.900
# Trial 5, Epoch: 3000, He model, h=50, lr=1.00000, Loss=2.30253, test err=0.901
# Trial 6, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.31970, test err=0.738
# Trial 6, Epoch: 600, He model, h=50, lr=1.00000, Loss=1.83961, test err=0.768
# Trial 6, Epoch: 1200, He model, h=50, lr=1.00000, Loss=2.29980, test err=0.898
# Trial 6, Epoch: 1800, He model, h=50, lr=1.00000, Loss=2.30226, test err=0.901
# Trial 6, Epoch: 2400, He model, h=50, lr=1.00000, Loss=2.30236, test err=0.900
# Trial 6, Epoch: 3000, He model, h=50, lr=1.00000, Loss=2.30267, test err=0.900
# Trial 7, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.37306, test err=0.854
# Trial 7, Epoch: 600, He model, h=50, lr=1.00000, Loss=2.29333, test err=0.894
# Trial 7, Epoch: 1200, He model, h=50, lr=1.00000, Loss=2.30260, test err=0.900
# Trial 7, Epoch: 1800, He model, h=50, lr=1.00000, Loss=2.19673, test err=0.840
# Trial 7, Epoch: 2400, He model, h=50, lr=1.00000, Loss=2.28850, test err=0.891
# Trial 7, Epoch: 3000, He model, h=50, lr=1.00000, Loss=1.87702, test err=0.800
# Trial 8, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.30565, test err=0.703
# Trial 8, Epoch: 600, He model, h=50, lr=1.00000, Loss=2.41290, test err=0.900
# Trial 8, Epoch: 1200, He model, h=50, lr=1.00000, Loss=2.30252, test err=0.900
# Trial 8, Epoch: 1800, He model, h=50, lr=1.00000, Loss=2.30164, test err=0.897
# Trial 8, Epoch: 2400, He model, h=50, lr=1.00000, Loss=2.30259, test err=0.900
# Trial 8, Epoch: 3000, He model, h=50, lr=1.00000, Loss=1.82740, test err=0.800
# Trial 9, Epoch: 0, He model, h=50, lr=1.00000, Loss=2.31503, test err=0.785
# Trial 9, Epoch: 600, He model, h=50, lr=1.00000, Loss=2.27937, test err=0.816
# Trial 9, Epoch: 1200, He model, h=50, lr=1.00000, Loss=2.30530, test err=0.900
# Trial 9, Epoch: 1800, He model, h=50, lr=1.00000, Loss=2.30243, test err=0.900
# Trial 9, Epoch: 2400, He model, h=50, lr=1.00000, Loss=2.30256, test err=0.900
# Trial 9, Epoch: 3000, He model, h=50, lr=1.00000, Loss=2.30254, test err=0.901
# Trial 0, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.51514, test err=0.906
# Trial 0, Epoch: 600, V1 model, h=100, lr=0.00100, Loss=1.50896, test err=0.396
# Trial 0, Epoch: 1200, V1 model, h=100, lr=0.00100, Loss=1.20996, test err=0.355
# Trial 0, Epoch: 1800, V1 model, h=100, lr=0.00100, Loss=1.06072, test err=0.337
# Trial 0, Epoch: 2400, V1 model, h=100, lr=0.00100, Loss=0.97180, test err=0.326
# Trial 0, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.91250, test err=0.315
# Trial 1, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.38455, test err=0.898
# Trial 1, Epoch: 600, V1 model, h=100, lr=0.00100, Loss=1.52279, test err=0.413
# Trial 1, Epoch: 1200, V1 model, h=100, lr=0.00100, Loss=1.22388, test err=0.357
# Trial 1, Epoch: 1800, V1 model, h=100, lr=0.00100, Loss=1.07578, test err=0.337
# Trial 1, Epoch: 2400, V1 model, h=100, lr=0.00100, Loss=0.98560, test err=0.322
# Trial 1, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.92346, test err=0.308
# Trial 2, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.41419, test err=0.841
# Trial 2, Epoch: 600, V1 model, h=100, lr=0.00100, Loss=1.52042, test err=0.439
# Trial 2, Epoch: 1200, V1 model, h=100, lr=0.00100, Loss=1.21920, test err=0.361
# Trial 2, Epoch: 1800, V1 model, h=100, lr=0.00100, Loss=1.06416, test err=0.331
# Trial 2, Epoch: 2400, V1 model, h=100, lr=0.00100, Loss=0.97104, test err=0.315
# Trial 2, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.90845, test err=0.300
# Trial 3, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.64513, test err=0.938
# Trial 3, Epoch: 600, V1 model, h=100, lr=0.00100, Loss=1.66366, test err=0.440
# Trial 3, Epoch: 1200, V1 model, h=100, lr=0.00100, Loss=1.32324, test err=0.375
# Trial 3, Epoch: 1800, V1 model, h=100, lr=0.00100, Loss=1.13551, test err=0.338
# Trial 3, Epoch: 2400, V1 model, h=100, lr=0.00100, Loss=1.02052, test err=0.316
# Trial 3, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.94358, test err=0.302
# Trial 4, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.39177, test err=0.842
# Trial 4, Epoch: 600, V1 model, h=100, lr=0.00100, Loss=1.66195, test err=0.486
# Trial 4, Epoch: 1200, V1 model, h=100, lr=0.00100, Loss=1.34257, test err=0.376
# Trial 4, Epoch: 1800, V1 model, h=100, lr=0.00100, Loss=1.15867, test err=0.352
# Trial 4, Epoch: 2400, V1 model, h=100, lr=0.00100, Loss=1.04414, test err=0.337
# Trial 4, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.96711, test err=0.328
# Trial 5, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.49830, test err=0.863
# Trial 5, Epoch: 600, V1 model, h=100, lr=0.00100, Loss=1.46406, test err=0.407
# Trial 5, Epoch: 1200, V1 model, h=100, lr=0.00100, Loss=1.16648, test err=0.349
# Trial 5, Epoch: 1800, V1 model, h=100, lr=0.00100, Loss=1.01941, test err=0.320
# Trial 5, Epoch: 2400, V1 model, h=100, lr=0.00100, Loss=0.93178, test err=0.303
# Trial 5, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.87310, test err=0.290
# Trial 6, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.36053, test err=0.935
# Trial 6, Epoch: 600, V1 model, h=100, lr=0.00100, Loss=1.62554, test err=0.439
# Trial 6, Epoch: 1200, V1 model, h=100, lr=0.00100, Loss=1.30029, test err=0.373
# Trial 6, Epoch: 1800, V1 model, h=100, lr=0.00100, Loss=1.12435, test err=0.349
# Trial 6, Epoch: 2400, V1 model, h=100, lr=0.00100, Loss=1.01858, test err=0.340
# Trial 6, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.94808, test err=0.330
# Trial 7, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.31917, test err=0.860
# Trial 7, Epoch: 600, V1 model, h=100, lr=0.00100, Loss=1.53482, test err=0.434
# Trial 7, Epoch: 1200, V1 model, h=100, lr=0.00100, Loss=1.25196, test err=0.371
# Trial 7, Epoch: 1800, V1 model, h=100, lr=0.00100, Loss=1.10057, test err=0.343
# Trial 7, Epoch: 2400, V1 model, h=100, lr=0.00100, Loss=1.00643, test err=0.325
# Trial 7, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.94106, test err=0.311
# Trial 8, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.51190, test err=0.905
# Trial 8, Epoch: 600, V1 model, h=100, lr=0.00100, Loss=1.54408, test err=0.433
# Trial 8, Epoch: 1200, V1 model, h=100, lr=0.00100, Loss=1.24815, test err=0.361
# Trial 8, Epoch: 1800, V1 model, h=100, lr=0.00100, Loss=1.08854, test err=0.338
# Trial 8, Epoch: 2400, V1 model, h=100, lr=0.00100, Loss=0.99060, test err=0.321
# Trial 8, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.92425, test err=0.308
# Trial 9, Epoch: 0, V1 model, h=100, lr=0.00100, Loss=2.43757, test err=0.944
# Trial 9, Epoch: 600, V1 model, h=100, lr=0.00100, Loss=1.65493, test err=0.436
# Trial 9, Epoch: 1200, V1 model, h=100, lr=0.00100, Loss=1.33094, test err=0.371
# Trial 9, Epoch: 1800, V1 model, h=100, lr=0.00100, Loss=1.15250, test err=0.349
# Trial 9, Epoch: 2400, V1 model, h=100, lr=0.00100, Loss=1.04286, test err=0.336
# Trial 9, Epoch: 3000, V1 model, h=100, lr=0.00100, Loss=0.96821, test err=0.326
# Trial 0, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.37241, test err=0.916
# Trial 0, Epoch: 600, He model, h=100, lr=0.00100, Loss=2.02493, test err=0.577
# Trial 0, Epoch: 1200, He model, h=100, lr=0.00100, Loss=1.72626, test err=0.418
# Trial 0, Epoch: 1800, He model, h=100, lr=0.00100, Loss=1.46440, test err=0.373
# Trial 0, Epoch: 2400, He model, h=100, lr=0.00100, Loss=1.27231, test err=0.358
# Trial 0, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.13927, test err=0.349
# Trial 1, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.32033, test err=0.874
# Trial 1, Epoch: 600, He model, h=100, lr=0.00100, Loss=1.91969, test err=0.539
# Trial 1, Epoch: 1200, He model, h=100, lr=0.00100, Loss=1.59793, test err=0.451
# Trial 1, Epoch: 1800, He model, h=100, lr=0.00100, Loss=1.35684, test err=0.372
# Trial 1, Epoch: 2400, He model, h=100, lr=0.00100, Loss=1.19405, test err=0.357
# Trial 1, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.08279, test err=0.347
# Trial 2, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.31446, test err=0.884
# Trial 2, Epoch: 600, He model, h=100, lr=0.00100, Loss=1.97183, test err=0.525
# Trial 2, Epoch: 1200, He model, h=100, lr=0.00100, Loss=1.65669, test err=0.414
# Trial 2, Epoch: 1800, He model, h=100, lr=0.00100, Loss=1.40422, test err=0.368
# Trial 2, Epoch: 2400, He model, h=100, lr=0.00100, Loss=1.22841, test err=0.354
# Trial 2, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.10802, test err=0.345
# Trial 3, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.32807, test err=0.912
# Trial 3, Epoch: 600, He model, h=100, lr=0.00100, Loss=1.97995, test err=0.473
# Trial 3, Epoch: 1200, He model, h=100, lr=0.00100, Loss=1.66218, test err=0.384
# Trial 3, Epoch: 1800, He model, h=100, lr=0.00100, Loss=1.40217, test err=0.372
# Trial 3, Epoch: 2400, He model, h=100, lr=0.00100, Loss=1.22312, test err=0.355
# Trial 3, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.10240, test err=0.345
# Trial 4, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.32594, test err=0.924
# Trial 4, Epoch: 600, He model, h=100, lr=0.00100, Loss=1.96558, test err=0.492
# Trial 4, Epoch: 1200, He model, h=100, lr=0.00100, Loss=1.64597, test err=0.374
# Trial 4, Epoch: 1800, He model, h=100, lr=0.00100, Loss=1.39774, test err=0.353
# Trial 4, Epoch: 2400, He model, h=100, lr=0.00100, Loss=1.22564, test err=0.344
# Trial 4, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.10715, test err=0.338
# Trial 5, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.33630, test err=0.842
# Trial 5, Epoch: 600, He model, h=100, lr=0.00100, Loss=1.93244, test err=0.540
# Trial 5, Epoch: 1200, He model, h=100, lr=0.00100, Loss=1.60663, test err=0.383
# Trial 5, Epoch: 1800, He model, h=100, lr=0.00100, Loss=1.36731, test err=0.354
# Trial 5, Epoch: 2400, He model, h=100, lr=0.00100, Loss=1.20606, test err=0.343
# Trial 5, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.09503, test err=0.338
# Trial 6, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.31335, test err=0.858
# Trial 6, Epoch: 600, He model, h=100, lr=0.00100, Loss=1.92516, test err=0.434
# Trial 6, Epoch: 1200, He model, h=100, lr=0.00100, Loss=1.60857, test err=0.384
# Trial 6, Epoch: 1800, He model, h=100, lr=0.00100, Loss=1.35989, test err=0.357
# Trial 6, Epoch: 2400, He model, h=100, lr=0.00100, Loss=1.19315, test err=0.345
# Trial 6, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.08157, test err=0.337
# Trial 7, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.26489, test err=0.884
# Trial 7, Epoch: 600, He model, h=100, lr=0.00100, Loss=1.97595, test err=0.541
# Trial 7, Epoch: 1200, He model, h=100, lr=0.00100, Loss=1.68626, test err=0.420
# Trial 7, Epoch: 1800, He model, h=100, lr=0.00100, Loss=1.43849, test err=0.373
# Trial 7, Epoch: 2400, He model, h=100, lr=0.00100, Loss=1.25727, test err=0.358
# Trial 7, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.13079, test err=0.350
# Trial 8, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.30707, test err=0.906
# Trial 8, Epoch: 600, He model, h=100, lr=0.00100, Loss=1.98627, test err=0.526
# Trial 8, Epoch: 1200, He model, h=100, lr=0.00100, Loss=1.68360, test err=0.412
# Trial 8, Epoch: 1800, He model, h=100, lr=0.00100, Loss=1.43753, test err=0.378
# Trial 8, Epoch: 2400, He model, h=100, lr=0.00100, Loss=1.26234, test err=0.362
# Trial 8, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.13928, test err=0.353
# Trial 9, Epoch: 0, He model, h=100, lr=0.00100, Loss=2.35713, test err=0.899
# Trial 9, Epoch: 600, He model, h=100, lr=0.00100, Loss=1.92604, test err=0.497
# Trial 9, Epoch: 1200, He model, h=100, lr=0.00100, Loss=1.61026, test err=0.391
# Trial 9, Epoch: 1800, He model, h=100, lr=0.00100, Loss=1.36498, test err=0.364
# Trial 9, Epoch: 2400, He model, h=100, lr=0.00100, Loss=1.19821, test err=0.355
# Trial 9, Epoch: 3000, He model, h=100, lr=0.00100, Loss=1.08565, test err=0.347
# Trial 0, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.36034, test err=0.894
# Trial 0, Epoch: 600, V1 model, h=100, lr=0.01000, Loss=0.81526, test err=0.291
# Trial 0, Epoch: 1200, V1 model, h=100, lr=0.01000, Loss=0.67164, test err=0.239
# Trial 0, Epoch: 1800, V1 model, h=100, lr=0.01000, Loss=0.60127, test err=0.212
# Trial 0, Epoch: 2400, V1 model, h=100, lr=0.01000, Loss=0.55580, test err=0.196
# Trial 0, Epoch: 3000, V1 model, h=100, lr=0.01000, Loss=0.52508, test err=0.186
# Trial 1, Epoch: 0, V1 model, h=100, lr=0.01000, Loss=2.73536, test err=0.909
# Trial 1, Epoch: 600, V1 model, h=100, lr=0.01000, Loss=0.78398, test err=0.280
# Trial 1, Epoch: 1200, V1 model, h=100, lr=0.01000, Loss=0.65481, test err=0.232
# Trial 1, Epoch: 1800, V1 model, h=100, lr=0.01000, Loss=0.59146, test err=0.210
# Trial 1, Epoch: 2400, V1 model, h=100, lr=0.01000, Loss=0.55117, test err=0.197
# ...
# Trial 3, Epoch: 2400, V1 model, h=400, lr=0.00100, Loss=0.78905, test err=0.267
# Trial 3, Epoch: 3000, V1 model, h=400, lr=0.00100, Loss=0.75161, test err=0.257
# Trial 4, Epoch: 0, V1 model, h=400, lr=0.00100, Loss=2.53858, test err=0.978
# Trial 4, Epoch: 600, V1 model, h=400, lr=0.00100, Loss=1.09962, test err=0.338
# Trial 4, Epoch: 1200, V1 model, h=400, lr=0.00100, Loss=0.90833, test err=0.311
# Trial 4, Epoch: 1800, V1 model, h=400, lr=0.00100, Loss=0.82416, test err=0.284
# Trial 4, Epoch: 2400, V1 model, h=400, lr=0.00100, Loss=0.77315, test err=0.265
# Trial 4, Epoch: 3000, V1 model, h=400, lr=0.00100, Loss=0.73736, test err=0.253
# Trial 5, Epoch: 0, V1 model, h=400, lr=0.00100, Loss=2.53798, test err=0.947
# Trial 5, Epoch: 600, V1 model, h=400, lr=0.00100, Loss=1.15532, test err=0.346
# Trial 5, Epoch: 1200, V1 model, h=400, lr=0.00100, Loss=0.95064, test err=0.312
# Trial 5, Epoch: 1800, V1 model, h=400, lr=0.00100, Loss=0.85822, test err=0.292
# Trial 5, Epoch: 2400, V1 model, h=400, lr=0.00100, Loss=0.80199, test err=0.279
# Trial 5, Epoch: 3000, V1 model, h=400, lr=0.00100, Loss=0.76255, test err=0.265
# Trial 6, Epoch: 0, V1 model, h=400, lr=0.00100, Loss=2.47095, test err=0.931
# Trial 6, Epoch: 600, V1 model, h=400, lr=0.00100, Loss=1.08827, test err=0.333
# Trial 6, Epoch: 1200, V1 model, h=400, lr=0.00100, Loss=0.90563, test err=0.297
# Trial 6, Epoch: 1800, V1 model, h=400, lr=0.00100, Loss=0.82450, test err=0.275
# Trial 6, Epoch: 2400, V1 model, h=400, lr=0.00100, Loss=0.77486, test err=0.262
# Trial 6, Epoch: 3000, V1 model, h=400, lr=0.00100, Loss=0.73981, test err=0.253
# Trial 7, Epoch: 0, V1 model, h=400, lr=0.00100, Loss=2.60501, test err=0.937
# Trial 7, Epoch: 600, V1 model, h=400, lr=0.00100, Loss=1.08434, test err=0.338
# Trial 7, Epoch: 1200, V1 model, h=400, lr=0.00100, Loss=0.90485, test err=0.303
# Trial 7, Epoch: 1800, V1 model, h=400, lr=0.00100, Loss=0.82503, test err=0.284
# Trial 7, Epoch: 2400, V1 model, h=400, lr=0.00100, Loss=0.77658, test err=0.275
# Trial 7, Epoch: 3000, V1 model, h=400, lr=0.00100, Loss=0.74250, test err=0.267
# Trial 8, Epoch: 0, V1 model, h=400, lr=0.00100, Loss=2.39820, test err=0.852
# Trial 8, Epoch: 600, V1 model, h=400, lr=0.00100, Loss=1.12152, test err=0.343
# Trial 8, Epoch: 1200, V1 model, h=400, lr=0.00100, Loss=0.92526, test err=0.317
# Trial 8, Epoch: 1800, V1 model, h=400, lr=0.00100, Loss=0.83765, test err=0.294
# Trial 8, Epoch: 2400, V1 model, h=400, lr=0.00100, Loss=0.78440, test err=0.275
# Trial 8, Epoch: 3000, V1 model, h=400, lr=0.00100, Loss=0.74697, test err=0.262
# Trial 9, Epoch: 0, V1 model, h=400, lr=0.00100, Loss=2.41587, test err=0.933
# Trial 9, Epoch: 600, V1 model, h=400, lr=0.00100, Loss=1.13476, test err=0.329
# Trial 9, Epoch: 1200, V1 model, h=400, lr=0.00100, Loss=0.92941, test err=0.293
# Trial 9, Epoch: 1800, V1 model, h=400, lr=0.00100, Loss=0.83777, test err=0.273
# Trial 9, Epoch: 2400, V1 model, h=400, lr=0.00100, Loss=0.78271, test err=0.260
# Trial 9, Epoch: 3000, V1 model, h=400, lr=0.00100, Loss=0.74449, test err=0.250
# Trial 0, Epoch: 0, He model, h=400, lr=0.00100, Loss=2.35321, test err=0.856
# Trial 0, Epoch: 600, He model, h=400, lr=0.00100, Loss=1.73206, test err=0.384
# Trial 0, Epoch: 1200, He model, h=400, lr=0.00100, Loss=1.37179, test err=0.346
# Trial 0, Epoch: 1800, He model, h=400, lr=0.00100, Loss=1.15976, test err=0.333
# Trial 0, Epoch: 2400, He model, h=400, lr=0.00100, Loss=1.03131, test err=0.315
# Trial 0, Epoch: 3000, He model, h=400, lr=0.00100, Loss=0.94741, test err=0.300
# Trial 1, Epoch: 0, He model, h=400, lr=0.00100, Loss=2.35794, test err=0.898
# Trial 1, Epoch: 600, He model, h=400, lr=0.00100, Loss=1.72148, test err=0.385
# Trial 1, Epoch: 1200, He model, h=400, lr=0.00100, Loss=1.36740, test err=0.351
# Trial 1, Epoch: 1800, He model, h=400, lr=0.00100, Loss=1.16278, test err=0.340
# Trial 1, Epoch: 2400, He model, h=400, lr=0.00100, Loss=1.03851, test err=0.328
# Trial 1, Epoch: 3000, He model, h=400, lr=0.00100, Loss=0.95640, test err=0.313
# Trial 2, Epoch: 0, He model, h=400, lr=0.00100, Loss=2.27926, test err=0.899
# Trial 2, Epoch: 600, He model, h=400, lr=0.00100, Loss=1.67262, test err=0.364
# Trial 2, Epoch: 1200, He model, h=400, lr=0.00100, Loss=1.32229, test err=0.342
# Trial 2, Epoch: 1800, He model, h=400, lr=0.00100, Loss=1.12331, test err=0.332
# Trial 2, Epoch: 2400, He model, h=400, lr=0.00100, Loss=1.00390, test err=0.316
# Trial 2, Epoch: 3000, He model, h=400, lr=0.00100, Loss=0.92580, test err=0.299
# Trial 3, Epoch: 0, He model, h=400, lr=0.00100, Loss=2.34724, test err=0.892
# Trial 3, Epoch: 600, He model, h=400, lr=0.00100, Loss=1.74702, test err=0.412
# Trial 3, Epoch: 1200, He model, h=400, lr=0.00100, Loss=1.38795, test err=0.358
# Trial 3, Epoch: 1800, He model, h=400, lr=0.00100, Loss=1.17403, test err=0.340
# Trial 3, Epoch: 2400, He model, h=400, lr=0.00100, Loss=1.04359, test err=0.324
# Trial 3, Epoch: 3000, He model, h=400, lr=0.00100, Loss=0.95765, test err=0.310
# Trial 4, Epoch: 0, He model, h=400, lr=0.00100, Loss=2.31002, test err=0.861
# Trial 4, Epoch: 600, He model, h=400, lr=0.00100, Loss=1.67851, test err=0.394
# Trial 4, Epoch: 1200, He model, h=400, lr=0.00100, Loss=1.33416, test err=0.352
# Trial 4, Epoch: 1800, He model, h=400, lr=0.00100, Loss=1.13786, test err=0.335
# Trial 4, Epoch: 2400, He model, h=400, lr=0.00100, Loss=1.01861, test err=0.319
# Trial 4, Epoch: 3000, He model, h=400, lr=0.00100, Loss=0.93966, test err=0.304
# Trial 5, Epoch: 0, He model, h=400, lr=0.00100, Loss=2.43379, test err=0.943
# Trial 5, Epoch: 600, He model, h=400, lr=0.00100, Loss=1.74215, test err=0.397
# Trial 5, Epoch: 1200, He model, h=400, lr=0.00100, Loss=1.37076, test err=0.351
# Trial 5, Epoch: 1800, He model, h=400, lr=0.00100, Loss=1.15312, test err=0.331
# Trial 5, Epoch: 2400, He model, h=400, lr=0.00100, Loss=1.02281, test err=0.317
# Trial 5, Epoch: 3000, He model, h=400, lr=0.00100, Loss=0.93831, test err=0.303
# Trial 6, Epoch: 0, He model, h=400, lr=0.00100, Loss=2.34886, test err=0.906
# Trial 6, Epoch: 600, He model, h=400, lr=0.00100, Loss=1.76508, test err=0.375
# Trial 6, Epoch: 1200, He model, h=400, lr=0.00100, Loss=1.38972, test err=0.339
# Trial 6, Epoch: 1800, He model, h=400, lr=0.00100, Loss=1.16699, test err=0.327
# Trial 6, Epoch: 2400, He model, h=400, lr=0.00100, Loss=1.03424, test err=0.316
# Trial 6, Epoch: 3000, He model, h=400, lr=0.00100, Loss=0.94848, test err=0.302
# Trial 7, Epoch: 0, He model, h=400, lr=0.00100, Loss=2.31159, test err=0.870
# Trial 7, Epoch: 600, He model, h=400, lr=0.00100, Loss=1.70789, test err=0.382
# Trial 7, Epoch: 1200, He model, h=400, lr=0.00100, Loss=1.35724, test err=0.353
# Trial 7, Epoch: 1800, He model, h=400, lr=0.00100, Loss=1.15198, test err=0.343
# Trial 7, Epoch: 2400, He model, h=400, lr=0.00100, Loss=1.02731, test err=0.329
# Trial 7, Epoch: 3000, He model, h=400, lr=0.00100, Loss=0.94540, test err=0.311
# Trial 8, Epoch: 0, He model, h=400, lr=0.00100, Loss=2.30429, test err=0.845
# Trial 8, Epoch: 600, He model, h=400, lr=0.00100, Loss=1.67874, test err=0.396
# Trial 8, Epoch: 1200, He model, h=400, lr=0.00100, Loss=1.33100, test err=0.349
# Trial 8, Epoch: 1800, He model, h=400, lr=0.00100, Loss=1.13450, test err=0.331
# Trial 8, Epoch: 2400, He model, h=400, lr=0.00100, Loss=1.01553, test err=0.316
# Trial 8, Epoch: 3000, He model, h=400, lr=0.00100, Loss=0.93652, test err=0.302
# Trial 9, Epoch: 0, He model, h=400, lr=0.00100, Loss=2.31242, test err=0.943
# Trial 9, Epoch: 600, He model, h=400, lr=0.00100, Loss=1.69607, test err=0.363
# Trial 9, Epoch: 1200, He model, h=400, lr=0.00100, Loss=1.33151, test err=0.336
# Trial 9, Epoch: 1800, He model, h=400, lr=0.00100, Loss=1.12328, test err=0.324
# Trial 9, Epoch: 2400, He model, h=400, lr=0.00100, Loss=1.00013, test err=0.310
# Trial 9, Epoch: 3000, He model, h=400, lr=0.00100, Loss=0.92044, test err=0.295
# Trial 0, Epoch: 0, V1 model, h=400, lr=0.01000, Loss=2.44959, test err=0.881
# Trial 0, Epoch: 600, V1 model, h=400, lr=0.01000, Loss=0.64615, test err=0.225
# Trial 0, Epoch: 1200, V1 model, h=400, lr=0.01000, Loss=0.56488, test err=0.200
# Trial 0, Epoch: 1800, V1 model, h=400, lr=0.01000, Loss=0.52359, test err=0.186
# Trial 0, Epoch: 2400, V1 model, h=400, lr=0.01000, Loss=0.49679, test err=0.178
# Trial 0, Epoch: 3000, V1 model, h=400, lr=0.01000, Loss=0.47730, test err=0.172
# Trial 1, Epoch: 0, V1 model, h=400, lr=0.01000, Loss=2.58675, test err=0.898
# Trial 1, Epoch: 600, V1 model, h=400, lr=0.01000, Loss=0.64089, test err=0.221
# Trial 1, Epoch: 1200, V1 model, h=400, lr=0.01000, Loss=0.55876, test err=0.196
# Trial 1, Epoch: 1800, V1 model, h=400, lr=0.01000, Loss=0.51757, test err=0.183
# Trial 1, Epoch: 2400, V1 model, h=400, lr=0.01000, Loss=0.49127, test err=0.175
# Trial 1, Epoch: 3000, V1 model, h=400, lr=0.01000, Loss=0.47238, test err=0.169
# Trial 2, Epoch: 0, V1 model, h=400, lr=0.01000, Loss=2.49843, test err=0.876
# Trial 2, Epoch: 600, V1 model, h=400, lr=0.01000, Loss=0.64678, test err=0.226
# Trial 2, Epoch: 1200, V1 model, h=400, lr=0.01000, Loss=0.56307, test err=0.200
# Trial 2, Epoch: 1800, V1 model, h=400, lr=0.01000, Loss=0.52136, test err=0.185
# Trial 2, Epoch: 2400, V1 model, h=400, lr=0.01000, Loss=0.49423, test err=0.177
# Trial 2, Epoch: 3000, V1 model, h=400, lr=0.01000, Loss=0.47448, test err=0.172
# Trial 3, Epoch: 0, V1 model, h=400, lr=0.01000, Loss=2.48965, test err=0.890
# Trial 3, Epoch: 600, V1 model, h=400, lr=0.01000, Loss=0.64886, test err=0.228
# Trial 3, Epoch: 1200, V1 model, h=400, lr=0.01000, Loss=0.56815, test err=0.201
# Trial 3, Epoch: 1800, V1 model, h=400, lr=0.01000, Loss=0.52549, test err=0.187
# Trial 3, Epoch: 2400, V1 model, h=400, lr=0.01000, Loss=0.49758, test err=0.181
# Trial 3, Epoch: 3000, V1 model, h=400, lr=0.01000, Loss=0.47750, test err=0.174
# Trial 4, Epoch: 0, V1 model, h=400, lr=0.01000, Loss=2.41047, test err=0.864
# Trial 4, Epoch: 600, V1 model, h=400, lr=0.01000, Loss=0.64681, test err=0.226
# Trial 4, Epoch: 1200, V1 model, h=400, lr=0.01000, Loss=0.56368, test err=0.200
# Trial 4, Epoch: 1800, V1 model, h=400, lr=0.01000, Loss=0.52217, test err=0.188
# Trial 4, Epoch: 2400, V1 model, h=400, lr=0.01000, Loss=0.49553, test err=0.179
# Trial 4, Epoch: 3000, V1 model, h=400, lr=0.01000, Loss=0.47618, test err=0.173
# Trial 5, Epoch: 0, V1 model, h=400, lr=0.01000, Loss=2.45335, test err=0.771
# Trial 5, Epoch: 600, V1 model, h=400, lr=0.01000, Loss=0.65233, test err=0.234
# Trial 5, Epoch: 1200, V1 model, h=400, lr=0.01000, Loss=0.56519, test err=0.203
# Trial 5, Epoch: 1800, V1 model, h=400, lr=0.01000, Loss=0.52130, test err=0.188
# Trial 5, Epoch: 2400, V1 model, h=400, lr=0.01000, Loss=0.49311, test err=0.179
# Trial 5, Epoch: 3000, V1 model, h=400, lr=0.01000, Loss=0.47284, test err=0.172
# Trial 6, Epoch: 0, V1 model, h=400, lr=0.01000, Loss=2.32441, test err=0.836
# Trial 6, Epoch: 600, V1 model, h=400, lr=0.01000, Loss=0.64875, test err=0.223
# Trial 6, Epoch: 1200, V1 model, h=400, lr=0.01000, Loss=0.56247, test err=0.197
# Trial 6, Epoch: 1800, V1 model, h=400, lr=0.01000, Loss=0.51932, test err=0.184
# Trial 6, Epoch: 2400, V1 model, h=400, lr=0.01000, Loss=0.49225, test err=0.177
# Trial 6, Epoch: 3000, V1 model, h=400, lr=0.01000, Loss=0.47304, test err=0.171
# Trial 7, Epoch: 0, V1 model, h=400, lr=0.01000, Loss=2.56540, test err=0.859
# Trial 7, Epoch: 600, V1 model, h=400, lr=0.01000, Loss=0.64727, test err=0.231
# Trial 7, Epoch: 1200, V1 model, h=400, lr=0.01000, Loss=0.56525, test err=0.199
# Trial 7, Epoch: 1800, V1 model, h=400, lr=0.01000, Loss=0.52368, test err=0.189
# Trial 7, Epoch: 2400, V1 model, h=400, lr=0.01000, Loss=0.49687, test err=0.182
# Trial 7, Epoch: 3000, V1 model, h=400, lr=0.01000, Loss=0.47760, test err=0.174
# Trial 8, Epoch: 0, V1 model, h=400, lr=0.01000, Loss=2.73477, test err=0.971
# Trial 8, Epoch: 600, V1 model, h=400, lr=0.01000, Loss=0.64950, test err=0.229
# Trial 8, Epoch: 1200, V1 model, h=400, lr=0.01000, Loss=0.56535, test err=0.200
# Trial 8, Epoch: 1800, V1 model, h=400, lr=0.01000, Loss=0.52164, test err=0.187
# Trial 8, Epoch: 2400, V1 model, h=400, lr=0.01000, Loss=0.49347, test err=0.178
# Trial 8, Epoch: 3000, V1 model, h=400, lr=0.01000, Loss=0.47353, test err=0.172
# Trial 9, Epoch: 0, V1 model, h=400, lr=0.01000, Loss=2.42220, test err=0.927
# Trial 9, Epoch: 600, V1 model, h=400, lr=0.01000, Loss=0.65064, test err=0.228
# Trial 9, Epoch: 1200, V1 model, h=400, lr=0.01000, Loss=0.56744, test err=0.201
# Trial 9, Epoch: 1800, V1 model, h=400, lr=0.01000, Loss=0.52447, test err=0.184
# Trial 9, Epoch: 2400, V1 model, h=400, lr=0.01000, Loss=0.49670, test err=0.175
# Trial 9, Epoch: 3000, V1 model, h=400, lr=0.01000, Loss=0.47671, test err=0.171
# Trial 0, Epoch: 0, He model, h=400, lr=0.01000, Loss=2.40184, test err=0.964
# Trial 0, Epoch: 600, He model, h=400, lr=0.01000, Loss=0.74806, test err=0.252
# Trial 0, Epoch: 1200, He model, h=400, lr=0.01000, Loss=0.61932, test err=0.213
# Trial 0, Epoch: 1800, He model, h=400, lr=0.01000, Loss=0.56045, test err=0.193
# Trial 0, Epoch: 2400, He model, h=400, lr=0.01000, Loss=0.52561, test err=0.184
# Trial 0, Epoch: 3000, He model, h=400, lr=0.01000, Loss=0.50214, test err=0.180
# Trial 1, Epoch: 0, He model, h=400, lr=0.01000, Loss=2.33301, test err=0.899
# Trial 1, Epoch: 600, He model, h=400, lr=0.01000, Loss=0.75869, test err=0.258
# Trial 1, Epoch: 1200, He model, h=400, lr=0.01000, Loss=0.62519, test err=0.217
# Trial 1, Epoch: 1800, He model, h=400, lr=0.01000, Loss=0.56465, test err=0.196
# Trial 1, Epoch: 2400, He model, h=400, lr=0.01000, Loss=0.52847, test err=0.186
# Trial 1, Epoch: 3000, He model, h=400, lr=0.01000, Loss=0.50388, test err=0.178
# Trial 2, Epoch: 0, He model, h=400, lr=0.01000, Loss=2.35899, test err=0.930
# Trial 2, Epoch: 600, He model, h=400, lr=0.01000, Loss=0.76296, test err=0.260
# Trial 2, Epoch: 1200, He model, h=400, lr=0.01000, Loss=0.62724, test err=0.217
# Trial 2, Epoch: 1800, He model, h=400, lr=0.01000, Loss=0.56498, test err=0.196
# Trial 2, Epoch: 2400, He model, h=400, lr=0.01000, Loss=0.52822, test err=0.186
# Trial 2, Epoch: 3000, He model, h=400, lr=0.01000, Loss=0.50355, test err=0.180
# Trial 3, Epoch: 0, He model, h=400, lr=0.01000, Loss=2.30878, test err=0.825
# Trial 3, Epoch: 600, He model, h=400, lr=0.01000, Loss=0.75374, test err=0.255
# Trial 3, Epoch: 1200, He model, h=400, lr=0.01000, Loss=0.62208, test err=0.215
# Trial 3, Epoch: 1800, He model, h=400, lr=0.01000, Loss=0.56217, test err=0.195
# Trial 3, Epoch: 2400, He model, h=400, lr=0.01000, Loss=0.52687, test err=0.185
# Trial 3, Epoch: 3000, He model, h=400, lr=0.01000, Loss=0.50301, test err=0.181
# Trial 4, Epoch: 0, He model, h=400, lr=0.01000, Loss=2.35685, test err=0.913
# Trial 4, Epoch: 600, He model, h=400, lr=0.01000, Loss=0.75863, test err=0.259
# Trial 4, Epoch: 1200, He model, h=400, lr=0.01000, Loss=0.62650, test err=0.218
# Trial 4, Epoch: 1800, He model, h=400, lr=0.01000, Loss=0.56500, test err=0.198
# Trial 4, Epoch: 2400, He model, h=400, lr=0.01000, Loss=0.52847, test err=0.189
# Trial 4, Epoch: 3000, He model, h=400, lr=0.01000, Loss=0.50395, test err=0.181
# Trial 5, Epoch: 0, He model, h=400, lr=0.01000, Loss=2.26303, test err=0.829
# Trial 5, Epoch: 600, He model, h=400, lr=0.01000, Loss=0.75466, test err=0.262
# Trial 5, Epoch: 1200, He model, h=400, lr=0.01000, Loss=0.62396, test err=0.217
# Trial 5, Epoch: 1800, He model, h=400, lr=0.01000, Loss=0.56432, test err=0.197
# Trial 5, Epoch: 2400, He model, h=400, lr=0.01000, Loss=0.52876, test err=0.187
# Trial 5, Epoch: 3000, He model, h=400, lr=0.01000, Loss=0.50447, test err=0.180
# Trial 6, Epoch: 0, He model, h=400, lr=0.01000, Loss=2.33108, test err=0.939
# Trial 6, Epoch: 600, He model, h=400, lr=0.01000, Loss=0.75702, test err=0.255
# Trial 6, Epoch: 1200, He model, h=400, lr=0.01000, Loss=0.62463, test err=0.215
# Trial 6, Epoch: 1800, He model, h=400, lr=0.01000, Loss=0.56365, test err=0.198
# Trial 6, Epoch: 2400, He model, h=400, lr=0.01000, Loss=0.52744, test err=0.188
# Trial 6, Epoch: 3000, He model, h=400, lr=0.01000, Loss=0.50297, test err=0.180
# Trial 7, Epoch: 0, He model, h=400, lr=0.01000, Loss=2.32953, test err=0.870

# %% [markdown]
# ## plot results

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

t, l, n_epochs= 3.1, 1.1, 3001
models = ['V1', 'He']
h_list = [50, 100, 400, 1000]
lr_list = [1e-3, 1e-2, 1e-1, 1e0]

for h in h_list:
    for lr in lr_list:
        with open('results/initialize_fashion_mnist/full_data/clf_t=%0.3f_l=%0.3f.pickle' % (t, l), 'rb') as handle:
            sims = pickle.load(handle)

        fig = plt.figure(figsize=(12, 5))
        plt.suptitle(r'Shallow FFW FC net w/ GD. h=%d, lr=%0.4f, '% (h, lr), fontsize=16)
        
        # loss
        ax = fig.add_subplot(131)
        plt.title('Network loss', fontsize=16)
        for m in models:
            avg_loss = np.mean(sims['loss'][m][h][lr], axis=0)
            std_loss = np.std(sims['loss'][m][h][lr], axis=0)                       
            plt.plot(np.arange(n_epochs), avg_loss, label=m, lw=3)
            plt.fill_between(np.arange(n_epochs), avg_loss - std_loss, avg_loss + std_loss, alpha=0.2)
        plt.xlabel('Epoch', fontsize=20)
        plt.ylabel('Training loss', fontsize=20)
        ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
        plt.yscale('log')
        plt.legend(fontsize=18)
        
        # train err
        ax = fig.add_subplot(132)
        plt.title('Train error', fontsize=16)
        for m in models:
            avg_train_err = np.mean(sims['train_err'][m][h][lr], axis=0)
            std_train_err = np.std(sims['train_err'][m][h][lr], axis=0)
            plt.plot(np.arange(n_epochs), avg_train_err, label=m, lw=3)
            plt.fill_between(np.arange(n_epochs), avg_train_err - std_train_err, avg_train_err + std_train_err,  alpha=0.2)
        
        plt.xlabel('Epoch', fontsize=20)
        plt.ylabel('Training error', fontsize=20)
        ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
        plt.yticks(np.arange(0, 1, 0.2))
        plt.yscale('log')
        plt.legend(fontsize=18)

        # test err
        ax = fig.add_subplot(133)
        plt.title('Test error', fontsize=16)
        for m in models:
            avg_test_err = np.mean(sims['test_err'][m][h][lr], axis=0)
            std_test_err = np.std(sims['test_err'][m][h][lr], axis=0)
            plt.plot(np.arange(n_epochs), avg_test_err, label=m, lw=3)
            plt.fill_between(np.arange(n_epochs), avg_test_err - std_test_err, avg_test_err + std_test_err, alpha=0.2)

        plt.xlabel('Epoch', fontsize=20)
        plt.ylabel('Test error', fontsize=20)
        ax.tick_params(axis = 'both', which = 'major', labelsize = 14, width=2, length=6)
        plt.yticks(np.arange(0, 1, 0.2))
        plt.yscale('log')
        plt.legend(fontsize=18)

        plt.tight_layout()
        plt.subplots_adjust(top=0.8)    

        print(h, lr)
        plt.savefig('results/initialize_fashion_mnist/full_data/init_t=%0.2f_l=%0.2f_h=%d_lr=%0.4f.png' % (t, l, h, lr))
        plt.close()
# Out:
# 50 0.001
# 50 0.01
# 50 0.1
# 50 1.0
# 100 0.001
# 100 0.01
# 100 0.1
# 100 1.0
# 400 0.001
# 400 0.01
# 400 0.1
# 400 1.0
# 1000 0.001
# 1000 0.01
# 1000 0.1
# 1000 1.0

# %% [markdown]
# ## Test the speed of training networks on GPUs vs CPU

# %%
import numpy as np
import numpy.linalg as la
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from estimator import classical_weights, V1_inspired_weights
from data_fns import load_fashion_mnist

# %%
train, train_labels, test, test_labels = load_fashion_mnist('./data/fashion_mnist')
X_train = torch.from_numpy(train).float()
X_test = torch.from_numpy(test).float()
y_train = torch.from_numpy(train_labels).long()
y_test = torch.from_numpy(test_labels).long()
n, d = X_train.shape

# %%
class V1_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(V1_inspired_weights(hidden_size, d, t=5, l=2, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class He_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        torch.nn.init.kaiming_normal_(self.fc1.weight)
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
class RF_net(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(classical_weights(hidden_size, d, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)    
    
class V1_net_multiscale(nn.Module):
    def __init__(self, hidden_size, scale):
        super().__init__()
        self.fc1 = nn.Linear(d, hidden_size)
        self.fc1.weight.data = torch.FloatTensor(V1_weights_multiple_scales(hidden_size, d, scale=scale))
        self.output = nn.Linear(hidden_size, 10)
        
    def forward(self, inputs):
        x = torch.relu(self.fc1(inputs))
        return self.output(x)
    
    
def predict(model, X):
    return model(X).data.max(1)[1]

def error(model, X, y):
    y_pred = predict(model, X)
    accuracy = 1.0 * torch.sum(y_pred == y) / len(y)
    return 1 - accuracy

# %%
# %%time
## Run on GPU
X_train_cuda, y_train_cuda = X_train.to('cuda'), y_train.to('cuda')
X_test_cuda, y_test_cuda = X_test.to('cuda'), y_test.to('cuda')

h, lr, scale = 1000, 0.1, 2/d
n_epochs = 2001
model = V1_net(h, scale=scale).to('cuda')
loss_func = nn.CrossEntropyLoss()
optim = torch.optim.SGD(model.parameters(), lr=lr)

test_err_list_V1 = []
for i in range(n_epochs):
    optim.zero_grad()
    loss = loss_func(model(X_train_cuda), y_train_cuda)
    loss.backward()
    optim.step()
    
    train_err = error(model, X_train_cuda, y_train_cuda)
    test_err = error(model, X_test_cuda, y_test_cuda)
    test_err_list_V1.append(test_err)
    
    if (i % 200 == 0):
        print('Epoch: %d, Loss=%0.5f, train_err=%0.5f, test_err=%0.5f' % (i, loss.data, train_err, test_err))

# %%
# %%time
# ## Run on GPU
# X_train_cuda, y_train_cuda = X_train.to('cuda'), y_train.to('cuda')
# X_test_cuda, y_test_cuda = X_test.to('cuda'), y_test.to('cuda')

# h, lr, scale = 500, 0.1, 2/d
# n_epochs = 2001
# model = He_net(h, scale=scale).to('cuda')
# loss_func = nn.CrossEntropyLoss()
# optim = torch.optim.SGD(model.parameters(), lr=lr)

# test_err_list_He = []
# for i in range(n_epochs):
#     optim.zero_grad()
#     loss = loss_func(model(X_train_cuda), y_train_cuda)
#     loss.backward()
#     optim.step()
    
#     train_err = error(model, X_train_cuda, y_train_cuda)
#     test_err = error(model, X_test_cuda, y_test_cuda)
#     test_err_list_He.append(test_err)
    
#     if (i % 200 == 0):
#         print('Epoch: %d, Loss=%0.5f, train_err=%0.5f, test_err=%0.5f' % (i, loss.data, train_err, test_err))

# %%
fig = plt.figure()
plt.plot(np.arange(n_epochs), test_err_list_V1, label='V1')
plt.plot(np.arange(n_epochs), test_err_list_He, label='He')
plt.yscale('log')
plt.legend()

# %%
np.random.multivariate_normal((5, 3), np.eye(2), (100))
